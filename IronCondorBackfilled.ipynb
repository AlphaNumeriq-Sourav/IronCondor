# %%
# -------------------------x-----------------------x---------------------------x---------------------------x---------------------------x---------------------------
# Library Import|
# -------------------------x-----------------------x---------------------------x---------------------------x---------------------------x---------------------------


print('hello')
import pandas as pd


import datetime
import numpy as np
import pandas_ta as ta
import matplotlib.pyplot as plt
import pandas_ta as pta
from datetime import datetime , timedelta , date , time
import MetaTrader5 as mt5 
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import math
import requests
import io
import plotly.express as px
import plotly.graph_objs as go
import plotly
import os
import glob
from calendar import monthrange



# -------------------------x-----------------------x---------------------------x---------------------------x---------------------------x---------------------------
# Option Backtesting BuiltIn Function
# -------------------------x-----------------------x---------------------------x---------------------------x---------------------------x---------------------------

HolidayDateList = [date(2021,1,26),date(2021,3,11), date(2021,3,29), date(2021,4,2), date(2021,4,14), date(2021,4,21), date(2021,5,13), \
    date(2021,7,21), date(2021,8,19), date(2021,9,10), date(2021,10,15), date(2021,11,4) , date(2021,11,5) , date(2021,11,19),\
        date(2022,1,26),date(2022,3,1),date(2022,3,18), date(2022,4,14) , date(2022,4,15) , date(2022,5,3) , date(2022,8,9) , date(2022,8,15),\
            date(2022,8,31) , date(2022,10,5),date(2022,10,24) , date(2022,10,26),date(2022,11,8),\
                date(2020,2,21),date(2020,3,10),date(2020,4,2),date(2020,4,6),date(2020,4,10),date(2020,4,14),date(2020,5,1),date(2020,5,25),\
                    date(2020,10,2),date(2020,11,16),date(2020,11,30),date(2020,12,25)]



'''
Description - Convert Month Number to String Format

Input - MonthNumber (datatype - int)

Returns - MonthString (datatype - str )
'''
def numbers_to_strings(argument):
    switcher = {
        1: "JAN",
        2: "FEB",
        3: "MAR",
        4: "APR",
        5: "MAY",
        6: "JUN",
        7: "JUL",
        8: "AUG",
        9:  "SEP",
        10: "OCT",
        11: "NOV",
        12: "DEC"
        
    
    }
    return switcher.get(argument, "nothing")





'''
Description - Function to Clean the Option Data

Input - Unclean OptionData (datatype - Pandas DataFrame)

Steps Included
- Change The Columns Names.
- Create a datetime column by merging the date and time columns.
- Convert string to datetime for the datetime column in option data.
- Drop the date and Time Column.
- Drop the ContractName Column also.

Returns - Clean Option Data (datatype - Pandas DataFrame )
'''
def data_clean(OptionData):
    try:
        OptionData.columns = ['symbol','datetime', 'time', 'open', 'high', 'low', 'close', 'volume','interest']
        OptionData = OptionData.drop(index=0)
        OptionData['datetime'] = pd.to_datetime(OptionData['datetime'], format='%Y%m%d', errors='coerce')
        OptionData.dropna(subset=['datetime'], inplace=True)

        OptionData['time'] = pd.to_datetime(OptionData['time'], format='%H:%M:%S').dt.time
        # Convert the time column to a string
        OptionData['time'] = OptionData['time'].astype(str)

        # Convert the time column to a timedelta object
        OptionData['time'] = pd.to_timedelta(OptionData['time'])
        OptionData['datetime'] = OptionData['datetime'] + (OptionData['time'])
        OptionData.drop(['symbol'],axis = 1, inplace = True)
        OptionData.drop(['time'],axis = 1, inplace = True)
        OptionData.set_index('datetime', inplace=True)
        
        
    except ValueError:
        OptionData.columns = ['datetime', 'time', 'open', 'high', 'low', 'close', 'volume','interest']
        OptionData = OptionData.drop(index=0)
        OptionData['datetime'] = pd.to_datetime(OptionData['datetime'], format='%Y%m%d', errors='coerce')
        OptionData.dropna(subset=['datetime'], inplace=True)
        
        OptionData['time'] = pd.to_datetime(OptionData['time'], format='%H:%M:%S').dt.time
        # Convert the time column to a string
        OptionData['time'] = OptionData['time'].astype(str)

        # Convert the time column to a timedelta object
        OptionData['time'] = pd.to_timedelta(OptionData['time'])
        OptionData['datetime'] = OptionData['datetime'] + (OptionData['time'])
        OptionData.drop(['time'],axis = 1, inplace = True)
        OptionData.set_index('datetime', inplace=True)
    return OptionData
    
    
    
'''
Description - Function to Get a Option Contract on a Particular Time by passing the Price Parameter
This Function basically Run a Loop Through all the available contract of a particular expiry and then find the contract that is nearest to the price we have given.

Input - Price , CurrentTime , ParticularExpiry , Type(either CE or PE) , Path Of the Yearly Option Data Folder (datatype - float , datetime , str , str , str)

Steps Included :- 
- Get all the Files of a Contract for a Particular Year.
- Sort the files and Get the Contract with a particular Expiry that we have given and also Sort the CE or PE contract given by the user.
- Now loop through all the sorted files and find the price at the particular time we have given.
- Now Find the least distance between the price we have given and list of the price of different contract.
- Return the ContractName with the Least distance with the price we have given

Returns - ContractName , ContractPrice (datatype - str , float )
'''
def getContractBySP(Price,Time,Expiry,Type,path , LastThurs):
    
    ContractName = None
    ContractPrice = None
    files = glob.glob(path + "/*.csv")
    NewFiles = []
    for file in files:
        if LastThurs == False:
            if file.find(Expiry+Type)>=0:
                #print(file)
                NewFiles.append(file)
                
            elif file[-13:-4] == '00'+Expiry+Type:
                NewFiles.append(file)
    #for i in range()
    if Type == 'CE':
        NewFiles.sort(reverse=True)
    else:
        NewFiles.sort(reverse=False)
    dist = 1000
    for file in NewFiles:
        try:
            data = pd.read_csv(file)
            #print(data)
            df = data_clean(data.copy())
            #print(df)
            df = df.loc[Time:]
            if df.index[0].date() != Time.date():
                continue
            if df.index[0] != Time:
                continue
            #print(df)
            if abs(Price-df.iloc[0]['close']) < dist:
                ContractName = data.iloc[0]['Ticker']
                ContractPrice = df.iloc[0]['close']
                dist = abs(Price-df.iloc[0]['close'])
                pass
                #print(ContractName,ContractPrice,dist)

              
                
        except Exception as e:
            pass
        
        
        
    return ContractName , ContractPrice


'''
Description - Function to Get a Option Contract on a Particular Time that is greater than Price we have given
This Function basically Run a Loop Through all the available contract of a particular expiry and then find the contract that is greater than the price we have given.

Input - Price , CurrentTime , ParticularExpiry , Type(either CE or PE) , Path Of the Yearly Option Data Folder (datatype - float , datetime , str , str , str)

Steps Included :- 
- Get all the Files of a Contract for a Particular Year.
- Sort the files and Get the Contract with a particular Expiry that we have given.
- Now loop through all the sorted files and find the price at the particular time we have given.
- Now Find the ContractName that is nearest and greater than the Price we have given
- Return the ContractName with the Least distance with the price we have given

Returns - ContractName , ContractPrice (datatype - str , float )
'''

def getContractGreaterThanSP(Price,Time,Expiry,Type,path):
    
    ContractName = None
    ContractPrice = None
    files = glob.glob(path + "/*.csv")
    NewFiles = []
    for file in files:
        if file.find(Expiry+Type)>=0:
            NewFiles.append(file)

    TotalContract = pd.DataFrame(columns=['CN','CP'])
    for file in NewFiles:
        try:
            data = pd.read_csv(file)
            #print(data)
            df = data_clean(data.copy())
            #print(df)
            df = df.loc[Time:]
            if df.index[0].date() != Time.date():
                continue
            #print(df)
            
            TotalContract.loc[len(TotalContract)] = [data.iloc[0]['Ticker'], df.iloc[0]['close']]
                
        except Exception as e:
            pass
        
    df = TotalContract.sort_values(by='CP').reset_index(drop=True)
    for i in range(len(df)):
        if df.iloc[i]['CP'] > Price:
            ContractName = df.iloc[i]['CN']
            ContractPrice = df.iloc[i]['CP']
            break
        
    return ContractName , ContractPrice



'''
Description - Function to Check IF the Given Date is Last thursday of the month
Input - CurrentTime , OptionFrontWeekExpiry (datatype - datetime , datetime)

Steps Included :- 
- Import calendar library
- find out the last thursday on that month of CurrentTime
- If the day of this lastThursday is matching with Expiry's day then return True else False

Returns - True or False (datatype - boolean )
'''

def checkLastThursday(now,Expiry):
    import calendar
    last_thursday = max(week[-4] for week in calendar.monthcalendar(now.year,
                                                              now.month))
    if last_thursday==Expiry.day:
        return True
    else:
        return False
    
    
    
'''
Description - Function to Change the String Expiry of BankNifty option if that thursday is Holiday
Input - String Expiry  (datatype - str)

Steps Included :- 
- Create a Dictionary Switcher 
- Then use get function to get particular expiry fir that day
Returns - Original String Expiry (datatype - str )
'''
    
def HolidaySwitch(Date):
    switcher = {
        '02APR20' : '01APR20',
        '11MAR21' : '10MAR21',
        '13MAY21' : '12MAY21',
        '19AUG21':'18AUG21',
        '04NOV21' : '03NOV21',
        '14APR22' : '13APR22'
        
    }
    return switcher.get(Date,'nothing')



    

def getSameContractDay(today):
    if today.day == 1:
        TotalMonthDays = monthrange(today.year,today.month-1)[-1]
    else:
        TotalMonthDays = monthrange(today.year,today.month)[-1]
    dayValue = today.day
    today = today - timedelta(1)
    thursday = today+ timedelta((3-today.weekday()) % 7)
    thursday = thursday.day
    
    if TotalMonthDays == 31:
        if thursday == 31:
            thursday = 0
    elif TotalMonthDays == 30:
        if thursday == 30:
            thursday = 0
            
    elif TotalMonthDays == 29:
        if thursday == 29:
            thursday = 0
    elif TotalMonthDays == 28:
        if thursday == 28:
            thursday = 0
            
            
                    
            
    if TotalMonthDays == 31:
        if dayValue != 31:
            result = thursday+1
        else:
            result = 1

    elif TotalMonthDays == 30:
        if dayValue != 30:
            result = thursday + 1
        else:
            result = 1
    elif TotalMonthDays == 29:
        if dayValue != 29:
            result = thursday + 1
        else:
            return 1
    elif TotalMonthDays == 28:
        if dayValue != 28:
            result = thursday + 1
        else:
            result = 1
            
    return result
        
        
'''
Description - Find The Next Month Monthly BankNifty Expiry 
Input - CurrentTime (datatype - datetime)

Steps Included :- 
- Import Calendar
- If Current Month is not equal to 12 then find the last thursday from the calendar of next month
- If Current Month is equal to 12 then find the last thursday from the calendar of next month of the Next Year
Returns - NextMonthly Expiry (datatype - datetime )
'''
    
def FindNextMonthExpiry(today):
    import calendar
    
    if today.month != 12:
        last_thursday = max(week[-4] for week in calendar.monthcalendar(today.year,today.month+1))
        return datetime(today.year , today.month+1, last_thursday,15,15 )
    else:
        last_thursday = max(week[-4] for week in calendar.monthcalendar(today.year+1,1))
        return datetime(today.year+1 , 1, last_thursday,15,15)
      



'''
Description - Check If given Expiry is Last Thursday or not
Input - CurrentTime , Expiry (datatype - datetime)

Steps Included :- 
- Get the Date of Last thursday of the Month of CurrentTime
- If Last thursday day is matching with Given Expiry day return True else False.

Returns - True or False (datatype - boolean )
'''

def checkLastThursdayWithExpiry(now,Expiry):
    import calendar
    last_thursday = max(week[-4] for week in calendar.monthcalendar(now.year,
                                                              now.month))
    if last_thursday==Expiry.day:
        return True
    else:
        return False
    




'''
Description - Function to Clean the Option Data(Backfilled Data Version)

Input - Unclean OptionData (datatype - Pandas DataFrame)

Steps Included
- Change The Columns Names.
- Create a datetime column by merging the date and time columns.
- Convert string to datetime for the datetime column in option data.
- Drop the date and Time Column.
- Drop the ContractName Column also.

Returns - Clean Option Data (datatype - Pandas DataFrame )
'''

def data_clean_backfilled(ce):
    try:
        ce.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','interest' , 'symbol']
        ce['datetime'] = pd.to_datetime(ce['datetime'])
        ce.dropna(subset=['datetime'], inplace=True)
     
        ce.drop(['symbol'],axis = 1, inplace = True)
        ce.set_index('datetime', inplace=True)
        
        
    except ValueError:
        ce.columns = ['datetime', 'time', 'open', 'high', 'low', 'close', 'volume','interest']
        ce = ce.drop(index=0)
        ce['datetime'] = pd.to_datetime(ce['datetime'], format='%Y%m%d', errors='coerce')
        ce.dropna(subset=['datetime'], inplace=True)
        
        ce['time'] = pd.to_datetime(ce['time'], format='%H:%M:%S').dt.time
        # Convert the time column to a string
        ce['time'] = ce['time'].astype(str)

        # Convert the time column to a timedelta object
        ce['time'] = pd.to_timedelta(ce['time'])
        ce['datetime'] = ce['datetime'] + (ce['time'])
        ce.drop(['time'],axis = 1, inplace = True)
        ce.set_index('datetime', inplace=True)
    return ce



'''
Description - Function to Get a Option Contract on a Particular Time by passing the Price Parameter (Backfilled Version)
This Function basically Run a Loop Through all the available contract of a particular expiry and then find the contract that is nearest to the price we have given.

Input - Price , CurrentTime , ParticularExpiry , Type(either CE or PE) , Path Of the Yearly Option Data Folder (datatype - float , datetime , str , str , str)

Steps Included :- 
- Get all the Files of a Contract for a Particular Year.
- Sort the files and Get the Contract with a particular Expiry that we have given and also Sort the CE or PE contract given by the user.
- Now loop through all the sorted files and find the price at the particular time we have given.
- Now Find the least distance between the price we have given and list of the price of different contract.
- Return the ContractName with the Least distance with the price we have given

Returns - ContractName , ContractPrice (datatype - str , float )
'''

    
def getContractBySP_backfilled(Price,Time,Expiry,Type,path , LastThurs):
    
    ContractName = None
    ContractPrice = None
    files = glob.glob(path + "/*.csv")
    NewFiles = []
    for file in files:
        
        if LastThurs == False:
            if file.find(Expiry+Type)>=0:
                #print(file)
                NewFiles.append(file)
                
        elif file[-13:-4] == '00'+Expiry+Type:
            NewFiles.append(file)
    
    #for i in range()
    if Type == 'CE':
        NewFiles.sort(reverse=True)
    else:
        NewFiles.sort(reverse=False)
    dist = 1000
    for file in NewFiles:
        try:
            data = pd.read_csv(file)
            #print(data)
            df = data_clean_backfilled(data.copy())
            #print(df)
            df = df.loc[Time:]
            if df.index[0].date() != Time.date():
                continue
            if df.index[0] != Time:
                continue
            #print(df)
            if abs(Price-df.iloc[0]['close']) < dist:
                ContractName = data.iloc[0]['Ticker']
                ContractPrice = df.iloc[0]['close']
                dist = abs(Price-df.iloc[0]['close'])
                pass
                #print(ContractName,ContractPrice,dist)

              
                
        except Exception as e:
            pass
        
        
        
    return ContractName , ContractPrice


'''
Description - Find Option SL TP Price based on some price in Dollar or Rupees 

Input - OptionEntryPrice , LotSize , SingleLotQuantity , Dollar Price (datatype - float , float , float , float)

Steps Included :- 
- TpPrice = OptionEntryPrice + ((Dollar Price/LotSize) / SingleLotQuantity)

Returns - Target Or SL Price (datatype - float )
'''

def get_Price_point(Price , LotSize , Quantity , Points):
    
    x = Price +  ((Points/LotSize)/Quantity)
    
    return x






# -------------------------x-----------------------x---------------------------x---------------------------x---------------------------x---------------------------
# Strategy Spot Data Import
# -------------------------x-----------------------x---------------------------x---------------------------x---------------------------x---------------------------


# data = pd.read_csv(r'C:\Users\vijay\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\BANKNIFTY.csv', header=None)   
# data = data.drop(index=0)
# data.columns = ['symbol','datetime', 'time', 'open', 'high', 'low', 'close', 'volume','interest']
# data['datetime'] = pd.to_datetime(data['datetime'], format='%Y%m%d')
# data['time'] = pd.to_datetime(data['time'], format='%H:%M:%S').dt.time
# # Convert the time column to a string
# data['time'] = data['time'].astype(str)

# # Convert the time column to a timedelta object
# data['time'] = pd.to_timedelta(data['time'])
# data['datetime'] = data['datetime'] + (data['time'])
# #         #df.drop(columns= [ 'time'], inplace= True)
 

# #data['datetime'] = data['datetime'].map(lambda Date : datetime.strptime(Date , '%Y%m%d %H:%M'))
# data.drop(['symbol'], axis=1, inplace = True)
# data.drop(['time'],axis = 1, inplace = True)
# data.set_index('datetime', inplace=True)

# data



# For Kite Data M1

data = pd.read_csv(r'C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\BANKNIFTYKiteM1.csv', header=None)   
data = data.drop(index=0)
data.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume']
data['datetime'] = pd.to_datetime(data['datetime'])
# Convert the time column to a string
data.set_index('datetime', inplace=True)
data['close'] = data['close'].apply( lambda dt :float(dt))
data['open'] = data['open'].apply( lambda dt :float(dt))
data['high'] = data['high'].apply( lambda dt :float(dt))
data['low'] = data['low'].apply( lambda dt :float(dt))
data



# VIx data
vix = pd.read_csv(r'C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\IndiaVIX.csv', header=None)   
vix = vix.drop(index=0)
vix.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume']
vix['datetime'] = pd.to_datetime(vix['datetime'])
# Convert the time column to a string
vix.set_index('datetime', inplace=True)
vix['close'] = vix['close'].apply( lambda dt :float(dt))
vix['open'] = vix['open'].apply( lambda dt :float(dt))
vix['high'] = vix['high'].apply( lambda dt :float(dt))
vix['low'] = vix['low'].apply( lambda dt :float(dt))
vix




# # For Kite Data Weekly

# dataW1 = pd.read_csv(r'C:\Users\soura\OneDrive\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\BANKNIFTYKiteWeekly.csv', header=None)   
# dataW1 = dataW1.drop(index=0)
# dataW1.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume']
# dataW1.drop(index = len(dataW1),inplace=True)
# dataW1['datetime'] = pd.to_datetime(dataW1['datetime'])
# dataW1.set_index('datetime', inplace=True)
# dataW1['close'] = dataW1['close'].apply( lambda dt :float(dt))
# dataW1['open'] = dataW1['open'].apply( lambda dt :float(dt))
# dataW1['high'] = dataW1['high'].apply( lambda dt :float(dt))
# dataW1['low'] = dataW1['low'].apply( lambda dt :float(dt))




# # For Kite Data Weekly

# dataM30 = pd.read_csv(r'C:\Users\soura\OneDrive\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\BANKNIFTYKiteM30.csv', header=None)   
# dataM30 = dataM30.drop(index=0)
# dataM30.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume']
# dataM30['datetime'] = pd.to_datetime(dataM30['datetime'])
# dataM30.set_index('datetime', inplace=True)
# dataM30['close'] = dataM30['close'].apply( lambda dt :float(dt))
# dataM30['open'] = dataM30['open'].apply( lambda dt :float(dt))
# dataM30['high'] = dataM30['high'].apply( lambda dt :float(dt))
# dataM30['low'] = dataM30['low'].apply( lambda dt :float(dt))



vix
# Out:
# hello
#                       open   high    low  close volume
# datetime
# 2019-12-16 09:15:00  13.30  13.35  12.98  13.19      0
# 2019-12-16 09:16:00  13.19  13.26  12.99  13.01      0
# 2019-12-16 09:17:00  13.01  13.10  12.99  13.07      0
# 2019-12-16 09:18:00  13.06  13.11  13.05  13.07      0
# 2019-12-16 09:19:00  13.07  13.07  13.03  13.03      0
# ...                    ...    ...    ...    ...    ...
# 2023-05-31 15:25:00  11.91  11.92  11.89  11.92      0
# 2023-05-31 15:26:00  11.92  11.95  11.91  11.95      0
# 2023-05-31 15:27:00  11.97  12.02  11.97  12.00      0
# 2023-05-31 15:28:00  12.00  12.02  11.99  12.01      0
# 2023-05-31 15:29:00  12.01  12.06  12.00  12.05      0
#
# [321301 rows x 5 columns]

# %% [markdown]
# ### Base Model

# %%
path = r'C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\2020'

HolidayList = ['02APR20', '11MAR21',
               '13MAY21', '19AUG21', '04NOV21', '14APR22']
NextHolidayList = ['09APR20', '18MAR21',
                   '20MAY21', '00AUG21', '13NOV21', '21APR22']
OrderBasketID = 0
Orders = pd.DataFrame(columns=['entry', 'type', 'entry_time', 'exittime','entry_value', 'exitvalue', 'exit_type', 'SP', 'dd', 'BasketID','ContractName','LS'])
LotSize = 25

today = datetime(2019, 12, 11, 0, 0, 0)


# Strating Date and Ending Date of the backtest
StartingDate = datetime(2020,1,1,9,30)
tdayTime = StartingDate
ENdTime = datetime(2021, 12, 28, 9, 30, 0)
#NoDataAvailableCt = ['12MAR20' , '19MAR20' , '01APR20','MAR20','04JUN20' , '16APR20']
NoDataAvailableCt = ['19MAR20' , 'MAR20' , '01APR20']

LastTradeEndDate = data.index[0] - timedelta(days=1)

DataMisses = 0

while True:
    IsHoliday = False
    tdayTime = tdayTime + timedelta(minutes=1)



    # Set The Starting Date
    if tdayTime <= StartingDate:
        continue


    # Set the back testing End date
    if tdayTime >= ENdTime:
        break
    
    # if tdayTime.date() in [date(2020,3,12) ] :
    #         continue
        
        
    if (tdayTime + timedelta(days=1)).date() in HolidayDateList and (tdayTime + timedelta(days=1)).weekday() == 3:
        IsHoliday = True
        
    
    if tdayTime.date()  in HolidayDateList:
        continue
    
    


    # To change the file path for different years
    if tdayTime >= datetime(2021, 1, 1, 9, 30, 0):
        path = r'C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\2021'
    if tdayTime >= datetime(2022, 1, 1, 9, 30, 0):
        path = r'C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\2022'
        
        
        
        
        
        
    EntryWeekDay = 3
    
    if IsHoliday == True:
        EntryWeekDay = 2
        
    LastThrus = False
    # Enter Only Next Month last contract on this month last thursday
    if ((tdayTime.hour== 10 )and (tdayTime.minute == 00)) and (tdayTime.weekday() == EntryWeekDay):     
        print(tdayTime)
       
            
        

        NextExpiry = tdayTime + timedelta(days = 2)
        NextExpiry = NextExpiry + timedelta((3-NextExpiry.weekday()) % 7)
        #NextExpiry = NextExpiry + timedelta(hours=5.25)
        Expiryyear = NextExpiry.year
        ExpiryMonth = NextExpiry.month
        ExpiryDay = NextExpiry.day
        
        if NextExpiry in HolidayDateList:
            NextExpiry = NextExpiry - timedelta(days=1)
        
        # get the string value of the Expiry
        # if Expiryday is in 1 Digit we will add 0 at first
        if len(str(ExpiryDay)) == 1:
            StrExpiryDay = '0'+str(ExpiryDay)
        else:
            StrExpiryDay = str(ExpiryDay)
        StrExpiryYear = str(Expiryyear)[-2:]
        StrExpiryMonth = numbers_to_strings(ExpiryMonth)
    


        # if the Expiry is the last Expiry of the month we will add 00 at first to find the Contract
        if checkLastThursdayWithExpiry(tdayTime,  NextExpiry):
            StrExpiry = StrExpiryMonth+StrExpiryYear
            LastThrus = True
        else:
            StrExpiry = StrExpiryDay+StrExpiryMonth+StrExpiryYear


        # For Switching the Expiry to Wednesday where Thrusday is a Holiday
        if StrExpiry in HolidayList:
            StrExpiry = HolidaySwitch(StrExpiry)
            NextExpiry = NextExpiry - timedelta(days=1)
            
        
        
        
        CMP = data.loc[tdayTime]['open']
            
       
        
        #Rounding 
        CMP = round(float(CMP)/100)*100
        print(StrExpiry)
        
        if StrExpiry in NoDataAvailableCt:
            continue
        OrderBasketID+=1
        print(LastThrus)
        
        Price = 100
        SELLCEActiveContract , SELLCEActiveContractPrice = getContractBySP(Price, tdayTime, StrExpiry,'CE',path  , LastThrus)
        SELLPEActiveContract , SELLPEActiveContractPrice = getContractBySP(Price, tdayTime, StrExpiry,'PE',path , LastThrus)
        print(SELLCEActiveContract)
        
        BuyPrice = 1/3* (Price)
   
        FirstBuyCEActiveContract , Buy1CEEntryPrice =  getContractBySP(BuyPrice, tdayTime, StrExpiry,'CE',path , LastThrus)
        FirstBuyPEActiveContract , Buy1PEEntryPrice =  getContractBySP(BuyPrice, tdayTime, StrExpiry,'PE',path , LastThrus)

        
        
        try:
            SellCE1 = pd.read_csv(f'{path}\{SELLCEActiveContract}.csv')
            SellCE1 = data_clean(SellCE1)
            SellCE1 = SellCE1.drop(['volume','interest'] , axis =1)
            SellPE1 = pd.read_csv(f'{path}\{SELLPEActiveContract}.csv')
            SellPE1 = data_clean(SellPE1)
            SellPE1 = SellPE1.drop(['volume','interest'] , axis =1)
            
            Buy1CE2 = pd.read_csv(f'{path}\{FirstBuyCEActiveContract}.csv')
            Buy1CE2 = data_clean(Buy1CE2)
            Buy1CE2 = Buy1CE2.drop(['volume','interest'] , axis =1)
            Buy1PE2 = pd.read_csv(f'{path}\{FirstBuyPEActiveContract}.csv')
            Buy1PE2 = data_clean(Buy1PE2)
            Buy1PE2 = Buy1PE2.drop(['volume','interest'] , axis =1)

            
            mdf1 = pd.merge_asof(SellCE1, SellPE1, on='datetime')
            mdf2 = pd.merge_asof(mdf1, Buy1CE2 , on='datetime')
            mdf3 = pd.merge_asof(mdf2, Buy1PE2 , on='datetime')
            CEPEdf = pd.merge_asof(mdf3, data , on='datetime')
            CEPEdf.set_index('datetime', inplace=True)
        except FileNotFoundError:
            print(f'Data is not available in either PE or CE at Data Preprocessing for {tdayTime}')
            continue

        CEPEdf.columns = [f'open{SELLCEActiveContract}', f'high{SELLCEActiveContract}', f'low{SELLCEActiveContract}', f'close{SELLCEActiveContract}',\
            f'open{SELLPEActiveContract}', f'high{SELLPEActiveContract}', f'low{SELLPEActiveContract}', f'close{SELLPEActiveContract}',\
                f'open{FirstBuyCEActiveContract}', f'high{FirstBuyCEActiveContract}',f'low{FirstBuyCEActiveContract}', f'close{FirstBuyCEActiveContract}',\
                    f'open{FirstBuyPEActiveContract}', f'high{FirstBuyPEActiveContract}',f'low{FirstBuyPEActiveContract}', f'close{FirstBuyPEActiveContract}',\
                                'openSpot', 'highSpot' , 'lowSpot' , 'closeSpot' , 'volumeSpot']
        
        
        
        
        # Code To SKip the Baskets where there is Nan Data
        try:
            sample1 = CEPEdf.dropna().loc[tdayTime:]
            if (sample1.index[0] - tdayTime).total_seconds() >= 60 * 60 * 3:
                raise Exception
        except Exception as e:
            print(f'Data is not available in either PE or CE  for {tdayTime}')
            print(f'First Data Available : {CEPEdf.dropna().loc[tdayTime:].index[:5]}')
            print(f'Last Data Available : {CEPEdf.dropna().loc[tdayTime:].index[-5:]}')
            continue
        
        #break
            
        CEPEdf = CEPEdf.loc[tdayTime:]
        CEPEdf = CEPEdf.dropna()
        
        
        
        SELLCEEntryPrice = CEPEdf.iloc[0][f'open{SELLCEActiveContract}']
        SELLPEEntryPrice = CEPEdf.iloc[0][f'open{SELLPEActiveContract}']
        
        Buy1CEEntryPrice = CEPEdf.iloc[0][f'open{FirstBuyCEActiveContract}']
        Buy1PEEntryPrice = CEPEdf.iloc[0][f'open{FirstBuyPEActiveContract}']
        
    
        
        CEEntryTime = CEPEdf.index[0]
        PEEntryTime = CEPEdf.index[0]
        
  
    
        Target = 2500
 
        print(f'Entry at {CEEntryTime} at a SP of {CMP}')
        print(f'Enter First Sell Series CE Contract : {SELLCEActiveContract} Price : {SELLCEEntryPrice} . PE Contract : {SELLPEActiveContract} Price : {SELLPEEntryPrice}')
        print(f'Enter First Buy Series CE Contract : {FirstBuyCEActiveContract} Price : {Buy1CEEntryPrice} . PE Contract : {FirstBuyPEActiveContract} Price : {Buy1PEEntryPrice}')
        
        j = 0
        c = 0
        flagCE = 'NA'
        flagPE = 'NA'
        flag = 0
        
        #break
        while True and j <= len(CEPEdf) -1 :
            
            
            # get The Total Sum Price of all the Open Positions
            SellPnl = 25 * ((SELLCEEntryPrice - CEPEdf.iloc[j][f'close{SELLCEActiveContract}']) + (SELLPEEntryPrice - CEPEdf.iloc[j][f'close{SELLPEActiveContract}']))
            BuyFirstPnl = 25 * ((CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'] - Buy1CEEntryPrice) + (CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'] - Buy1PEEntryPrice) )
            TotalPnl = SellPnl + BuyFirstPnl 
            
            if flag == 1:
                TotalPrice = CEPEdf.iloc[j][f'close{SELLCEActiveContract}'] + CEPEdf.iloc[j][f'close{SELLPEActiveContract}']
                
                if TotalPrice > StopLoss:
                
                    print(f'StopLoss Hit at {CEPEdf.index[j]} .Closed Sell CE Contract : {SELLCEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLCEActiveContract}"]} .Closed Sell PE Contract : {SELLPEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLPEActiveContract}"]}')
                    print(f'Closed Buy CE Contract : {FirstBuyCEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyCEActiveContract}"]} .Closed Buy PE Contract : {FirstBuyPEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyPEActiveContract}"]} \n\n\n\n')
                    
                    # Exit FIrst SELL CE Order
                    try:
                        ddCt = SELLPEEntryPrice - max(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                    except ValueError:
                        ddCt = 0
                    Orders.loc[len(Orders)] = [-1 ,  'CE',  CEEntryTime, CEPEdf.index[j] ,SELLCEEntryPrice ,CEPEdf.iloc[j][f'close{SELLCEActiveContract}'], 'SL', CMP, ddCt , OrderBasketID, SELLCEActiveContract ,1]
                    
                    # Exit First SELL PE Order
                    try:
                        ddCt = SELLPEEntryPrice - max(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                    except ValueError:
                        ddCt = 0
                    Orders.loc[len(Orders)] = [-1 ,  'PE',  PEEntryTime, CEPEdf.index[j] ,SELLPEEntryPrice ,CEPEdf.iloc[j][f'close{SELLPEActiveContract}'], 'SL', CMP, ddCt , OrderBasketID, SELLPEActiveContract,1 ]
                    
        
                    
                    # Exit FirstBuy CE Order
                    try:
                        ddCt = min(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'low{FirstBuyCEActiveContract}']) - Buy1CEEntryPrice
                    except ValueError:
                        ddCt = 0
                    Orders.loc[len(Orders)] = [1 ,  'CE',  CEEntryTime, CEPEdf.index[j] ,Buy1CEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'], 'SL', CMP, ddCt , OrderBasketID, FirstBuyCEActiveContract ,1]
                    
                    
                    # Exit FirstBuy PE Order
                    try:
                        ddCt = min(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'low{FirstBuyPEActiveContract}']) - Buy1PEEntryPrice
                    except ValueError:
                        ddCt = 0
                    Orders.loc[len(Orders)] = [1 ,  'PE',  PEEntryTime, CEPEdf.index[j] ,Buy1PEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'], 'SL', CMP, ddCt , OrderBasketID, FirstBuyPEActiveContract , 1]
                    
            
                    break
            
            
            
            ## CE Adjustment
            if flag == 0 and (0.5 * CEPEdf.iloc[j][f'close{SELLPEActiveContract}']) >= CEPEdf.iloc[j][f'close{SELLCEActiveContract}']:
                AdjustedSELLPrice = 0.8 * CEPEdf.iloc[j][f'close{SELLPEActiveContract}']
                
                AdjustmentTime = CEPEdf.index[j]
                print(f'Adjustment of CE at {AdjustmentTime}')
                
                 # Updating the Orders Data frame
                 
                # Sell Order
                try:
                    ddCE = (SELLCEEntryPrice - max(CEPEdf.loc[CEEntryTime : AdjustmentTime][f'high{SELLCEActiveContract}']))
                except ValueError:
                    ddCE = 0
                # ['entry', 'type', 'entry_time', 'exittime','entry_value', 'exitvalue', 'exit_type', 'SP', 'dd', 'BasketID','ContractName','LS']
                Orders.loc[len(Orders)] = [-1, 'CE', CEEntryTime, AdjustmentTime,SELLCEEntryPrice ,CEPEdf.iloc[j][f'close{SELLCEActiveContract}'], 'Adj', CMP, ddCE, OrderBasketID ,SELLCEActiveContract , 1 ]
                
                # Buy Order
                try:
                    ddCE = (min(CEPEdf.loc[CEEntryTime : AdjustmentTime][f'low{FirstBuyCEActiveContract}']) - Buy1CEEntryPrice)
                except ValueError:
                    ddCE = 0
                Orders.loc[len(Orders)] = [1, 'CE', CEEntryTime, AdjustmentTime,Buy1CEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'], 'Adj', 'UP', ddCE, OrderBasketID, FirstBuyCEActiveContract, 1]
                print(f"Exited SELL Contract : {SELLCEActiveContract} at Price : {CEPEdf.iloc[j][f'close{SELLCEActiveContract}']} and NEW BUY Contract : {FirstBuyCEActiveContract} and Price : {CEPEdf.iloc[j][f'close{SELLCEActiveContract}']}")
                
                
                
                
                NewSELLCEActiveContract , NewSELLCEActiveContractPrice = getContractBySP(AdjustedSELLPrice , AdjustmentTime , StrExpiry , 'CE' , path  , LastThrus)
                AdjustedBUYPrice = 1/3 * NewSELLCEActiveContractPrice
                NewFirstBuyCEActiveContract , NewFirstBuyCEActiveContractPrice= getContractBySP(AdjustedBUYPrice , AdjustmentTime , StrExpiry , 'CE' , path , LastThrus )
                
                
                NewSELLCEdf = data_clean(pd.read_csv(f'{path}\{NewSELLCEActiveContract}.csv'))
                NewSELLCEdf = NewSELLCEdf.drop(['volume','interest'] , axis =1)
                NewBuyCEdf = data_clean(pd.read_csv(f'{path}\{NewFirstBuyCEActiveContract}.csv'))
                NewBuyCEdf = NewBuyCEdf.drop(['volume','interest'] , axis =1)
                
                NewColumns = ['datetime'] + list(CEPEdf.columns) + [f'open{NewSELLCEActiveContract}', f'high{NewSELLCEActiveContract}', f'low{NewSELLCEActiveContract}', f'close{NewSELLCEActiveContract}',\
                f'open{NewFirstBuyCEActiveContract}', f'high{NewFirstBuyCEActiveContract}',f'low{NewFirstBuyCEActiveContract}', f'close{NewFirstBuyCEActiveContract}']
                mdf1 = pd.merge_asof(CEPEdf, NewSELLCEdf, on='datetime')
                CEPEdf = pd.merge_asof(mdf1, NewBuyCEdf, on='datetime')
                CEPEdf.columns = NewColumns
                CEPEdf.set_index('datetime' , inplace=True)
                CEPEdf = CEPEdf.loc[:,~CEPEdf.columns.duplicated()]
                
                CEPEdf = CEPEdf.loc[AdjustmentTime:]
                j = 0
                
                SELLCEActiveContract = NewSELLCEActiveContract
                FirstBuyCEActiveContract = NewFirstBuyCEActiveContract
                SELLCEEntryPrice = CEPEdf.iloc[j][f'open{SELLCEActiveContract}']
                Buy1CEEntryPrice = CEPEdf.iloc[j][f'open{FirstBuyCEActiveContract}']
                print(f'Entered New SELL Contract : {SELLCEActiveContract} at Price : {SELLCEEntryPrice} and NEW BUY Contract : {FirstBuyCEActiveContract} and Price : {Buy1CEEntryPrice}')
                
                
                ## Stoploss Activation Condition:
                if (int(SELLPEActiveContract[9:14]) - int(SELLCEActiveContract[9:14])) >= -100:
                    StopLoss = (SELLCEEntryPrice + CEPEdf.iloc[j][f'open{SELLPEActiveContract}']) * 1.1
                    print(f'Stoploss Created at {CEPEdf.index[j]}')
                    
                    flag = 1
                
            
                CEEntryTime = AdjustmentTime
            
            
            
            ## PE Adjustment
            elif flag == 0 and (0.5 * CEPEdf.iloc[j][f'close{SELLCEActiveContract}']) >= CEPEdf.iloc[j][f'close{SELLPEActiveContract}']:
                AdjustedSELLPrice = 0.8 * CEPEdf.iloc[j][f'close{SELLCEActiveContract}']
                
                AdjustmentTime = CEPEdf.index[j]
                print(f'Adjustment of CE at {AdjustmentTime}')
                
                 # Updating the Orders Data frame
                 
                # Sell Order
                try:
                    ddCE = (SELLPEEntryPrice - max(CEPEdf.loc[PEEntryTime : AdjustmentTime][f'high{SELLPEActiveContract}']))
                except ValueError:
                    ddCE = 0
                Orders.loc[len(Orders)] = [-1, 'PE', PEEntryTime, AdjustmentTime,SELLPEEntryPrice ,CEPEdf.iloc[j][f'close{SELLPEActiveContract}'], 'Adj', CMP, ddCE, OrderBasketID ,SELLPEActiveContract , 1 ]
                
                # Buy Order
                try:
                    ddCE = (min(CEPEdf.loc[PEEntryTime : AdjustmentTime][f'low{FirstBuyPEActiveContract}']) - Buy1PEEntryPrice)
                except ValueError:
                    ddCE = 0
                Orders.loc[len(Orders)] = [1, 'PE', PEEntryTime, AdjustmentTime,Buy1PEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'], 'Adj', 'UP', ddCE, OrderBasketID, FirstBuyPEActiveContract, 1]
                print(f"Exited SELL Contract : {SELLPEActiveContract} at Price : {CEPEdf.iloc[j][f'close{SELLPEActiveContract}']} and NEW BUY Contract : {FirstBuyPEActiveContract} and Price : {CEPEdf.iloc[j][f'close{SELLPEActiveContract}']}")
                
                
                
                NewSELLPEActiveContract , NewSELLPEActiveContractPrice = getContractBySP(AdjustedSELLPrice , AdjustmentTime , StrExpiry , 'PE' , path ,LastThrus )
                AdjustedBUYPrice = 1/3 * NewSELLPEActiveContractPrice
                NewFirstBuyPEActiveContract , NewFirstBuyPEActiveContractPrice= getContractBySP(AdjustedBUYPrice , AdjustmentTime , StrExpiry , 'PE' , path, LastThrus )
                
                
                NewSELLPEdf = data_clean(pd.read_csv(f'{path}\{NewSELLPEActiveContract}.csv'))
                NewSELLPEdf = NewSELLPEdf.drop(['volume','interest'] , axis =1)
                NewBuyPEdf = data_clean(pd.read_csv(f'{path}\{NewFirstBuyPEActiveContract}.csv'))
                NewBuyPEdf = NewBuyPEdf.drop(['volume','interest'] , axis =1)
                
                NewColumns = ['datetime'] + list(CEPEdf.columns) + [f'open{NewSELLPEActiveContract}', f'high{NewSELLPEActiveContract}', f'low{NewSELLPEActiveContract}', f'close{NewSELLPEActiveContract}',\
                f'open{NewFirstBuyPEActiveContract}', f'high{NewFirstBuyPEActiveContract}',f'low{NewFirstBuyPEActiveContract}', f'close{NewFirstBuyPEActiveContract}']
                mdf1 = pd.merge_asof(CEPEdf, NewSELLPEdf, on='datetime')
                CEPEdf = pd.merge_asof(mdf1, NewBuyPEdf, on='datetime')
                CEPEdf.columns = NewColumns
                CEPEdf.set_index('datetime' , inplace=True)
                CEPEdf = CEPEdf.loc[:,~CEPEdf.columns.duplicated()]
                
                CEPEdf = CEPEdf.loc[AdjustmentTime:]
                j = 0
                
                SELLPEActiveContract = NewSELLPEActiveContract
                FirstBuyPEActiveContract = NewFirstBuyPEActiveContract
                SELLPEEntryPrice = CEPEdf.iloc[j][f'open{SELLPEActiveContract}']
                Buy1PEEntryPrice = CEPEdf.iloc[j][f'open{FirstBuyPEActiveContract}']
                print(f'Entered New SELL Contract : {SELLPEActiveContract} at Price : {SELLPEEntryPrice} and NEW BUY Contract : {FirstBuyPEActiveContract} and Price : {Buy1PEEntryPrice}')
                
                
                ## Stoploss Activation Condition:
                if (int(SELLPEActiveContract[9:14]) - int(SELLCEActiveContract[9:14])) >= -100:
                    StopLoss = (SELLCEEntryPrice + CEPEdf.iloc[j][f'open{SELLPEActiveContract}']) * 1.1
                    print(f'Stoploss Created at {CEPEdf.index[j]}')                    
                    flag = 1


                PEEntryTime = AdjustmentTime
            
            
            
            # BreakPoint Above Exit Condition
            if TotalPnl >= Target:
                
                print(f'Target Hit at {CEPEdf.index[j]} .Closed Sell CE Contract : {SELLCEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLCEActiveContract}"]} .Closed Sell PE Contract : {SELLPEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLPEActiveContract}"]}')
                print(f'Closed Buy CE Contract : {FirstBuyCEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyCEActiveContract}"]} .Closed Buy PE Contract : {FirstBuyPEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyPEActiveContract}"]} \n\n\n\n')
                
                # Exit FIrst SELL CE Order
                try:
                    ddCt = SELLPEEntryPrice - max(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [-1 ,  'CE',  CEEntryTime, CEPEdf.index[j] ,SELLCEEntryPrice ,CEPEdf.iloc[j][f'close{SELLCEActiveContract}'], 'BAExit', CMP, ddCt , OrderBasketID, SELLCEActiveContract ,1]
                
                # Exit First SELL PE Order
                try:
                    ddCt = SELLPEEntryPrice - max(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [-1 ,  'PE',  PEEntryTime, CEPEdf.index[j] ,SELLPEEntryPrice ,CEPEdf.iloc[j][f'close{SELLPEActiveContract}'], 'BAExit', CMP, ddCt , OrderBasketID, SELLPEActiveContract,1 ]
                
    
                
                # Exit FirstBuy CE Order
                try:
                    ddCt = min(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'low{FirstBuyCEActiveContract}']) - Buy1CEEntryPrice
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [1 ,  'CE',  CEEntryTime, CEPEdf.index[j] ,Buy1CEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'], 'BAExit', CMP, ddCt , OrderBasketID, FirstBuyCEActiveContract ,1]
                
                
                # Exit FirstBuy PE Order
                try:
                    ddCt = min(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'low{FirstBuyPEActiveContract}']) - Buy1PEEntryPrice
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [1 ,  'PE',  PEEntryTime, CEPEdf.index[j] ,Buy1PEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'], 'BAExit', CMP, ddCt , OrderBasketID, FirstBuyPEActiveContract , 1]
                
           
                break
            
            
        
            
    
       
            
          
            
            
            # Expiry Exit Condition
            if CEPEdf.index[j] >= NextExpiry:
                print(f'Expiry Exit at {CEPEdf.index[j]} .Closed Sell CE Contract : {SELLCEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLCEActiveContract}"]} .Closed Sell PE Contract : {SELLPEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLPEActiveContract}"]}')
                print(f'Closed Buy CE Contract : {FirstBuyCEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyCEActiveContract}"]} .Closed Buy PE Contract : {FirstBuyPEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyPEActiveContract}"]} \n\n\n\n')
                
                # Exit FIrst SELL CE Order
                # Exit FIrst SELL CE Order
                try:
                    ddCt = SELLPEEntryPrice - max(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [-1 ,  'CE',  CEEntryTime, CEPEdf.index[j] ,SELLCEEntryPrice ,CEPEdf.iloc[j][f'close{SELLCEActiveContract}'], 'Exp', CMP, ddCt , OrderBasketID, SELLCEActiveContract ,1]
                
                # Exit First SELL PE Order
                try:
                    ddCt = SELLPEEntryPrice - max(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [-1 ,  'PE',  PEEntryTime, CEPEdf.index[j] ,SELLPEEntryPrice ,CEPEdf.iloc[j][f'close{SELLPEActiveContract}'], 'Exp', CMP, ddCt , OrderBasketID, SELLPEActiveContract,1 ]
                
               
                
                # Exit FirstBuy CE Order
                try:
                    ddCt = min(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'low{FirstBuyCEActiveContract}']) - Buy1CEEntryPrice
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [1 ,  "CE",  CEEntryTime, CEPEdf.index[j] ,Buy1CEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'], 'Exp', CMP, ddCt , OrderBasketID, FirstBuyCEActiveContract ,1]
                
                
                # Exit FirstBuy PE Order
                try:
                    ddCt = min(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'low{FirstBuyPEActiveContract}']) - Buy1PEEntryPrice
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [1 ,  'PE',  PEEntryTime, CEPEdf.index[j] ,Buy1PEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'], 'Exp', CMP, ddCt , OrderBasketID, FirstBuyPEActiveContract , 1]
              
               
                break
               
            
            
        
        

    
            j+=1
                
        # Break For 1 Trade
        #break
# Out:
# 2020-01-02 10:00:00
# 09JAN20
# False
# BANKNIFTY3250009JAN20CE
# Entry at 2020-01-02 10:00:00 at a SP of 32200
# Enter First Sell Series CE Contract : BANKNIFTY3250009JAN20CE Price : 108.55 . PE Contract : BANKNIFTY3190009JAN20PE Price : 94.9
# Enter First Buy Series CE Contract : BANKNIFTY3290009JAN20CE Price : 28.8 . PE Contract : BANKNIFTY3150009JAN20PE Price : 30.5
# Adjustment of CE at 2020-01-02 12:14:00
# Exited SELL Contract : BANKNIFTY3190009JAN20PE at Price : 71.85 and NEW BUY Contract : BANKNIFTY3150009JAN20PE and Price : 71.85
# Entered New SELL Contract : BANKNIFTY3210009JAN20PE at Price : 126.75 and NEW BUY Contract : BANKNIFTY3170009JAN20PE and Price : 42.2
# Adjustment of CE at 2020-01-02 14:23:00
# Exited SELL Contract : BANKNIFTY3210009JAN20PE at Price : 92.9 and NEW BUY Contract : BANKNIFTY3170009JAN20PE and Price : 92.9
# Entered New SELL Contract : BANKNIFTY3230009JAN20PE at Price : 159.4 and NEW BUY Contract : BANKNIFTY3190009JAN20PE and Price : 56.4
# Adjustment of CE at 2020-01-03 09:30:00
# Exited SELL Contract : BANKNIFTY3250009JAN20CE at Price : 119.0 and NEW BUY Contract : BANKNIFTY3290009JAN20CE and Price : 119.0
# Entered New SELL Contract : BANKNIFTY3230009JAN20CE at Price : 216.6 and NEW BUY Contract : BANKNIFTY3270009JAN20CE and Price : 74.65
# Stoploss Created at 2020-01-03 09:30:00
# StopLoss Hit at 2020-01-03 11:10:00 .Closed Sell CE Contract : BANKNIFTY3230009JAN20CE at Price 162.95 .Closed Sell PE Contract : BANKNIFTY3230009JAN20PE at Price 343.0
# Closed Buy CE Contract : BANKNIFTY3270009JAN20CE at Price 51.05 .Closed Buy PE Contract : BANKNIFTY3190009JAN20PE at Price 154.95
#
#
#
#
# 2020-01-09 10:00:00
# 16JAN20
# False
# BANKNIFTY3240016JAN20CE
# Entry at 2020-01-09 10:00:00 at a SP of 31800
# Enter First Sell Series CE Contract : BANKNIFTY3240016JAN20CE Price : 86.5 . PE Contract : BANKNIFTY3110016JAN20PE Price : 97.85
# Enter First Buy Series CE Contract : BANKNIFTY3280016JAN20CE Price : 32.0 . PE Contract : BANKNIFTY3020016JAN20PE Price : 29.35
# Adjustment of CE at 2020-01-09 12:00:00
# Exited SELL Contract : BANKNIFTY3110016JAN20PE at Price : 65.15 and NEW BUY Contract : BANKNIFTY3020016JAN20PE and Price : 65.15
# Entered New SELL Contract : BANKNIFTY3140016JAN20PE at Price : 105.5 and NEW BUY Contract : BANKNIFTY3060016JAN20PE and Price : 32.1
# Adjustment of CE at 2020-01-09 13:27:00
# Exited SELL Contract : BANKNIFTY3140016JAN20PE at Price : 86.55 and NEW BUY Contract : BANKNIFTY3060016JAN20PE and Price : 86.55
# Entered New SELL Contract : BANKNIFTY3170016JAN20PE at Price : 147.0 and NEW BUY Contract : BANKNIFTY3100016JAN20PE and Price : 49.35
# Adjustment of CE at 2020-01-10 10:28:00
# Exited SELL Contract : BANKNIFTY3170016JAN20PE at Price : 97.65 and NEW BUY Contract : BANKNIFTY3100016JAN20PE and Price : 97.65
# Entered New SELL Contract : BANKNIFTY3200016JAN20PE at Price : 184.45 and NEW BUY Contract : BANKNIFTY3140016JAN20PE and Price : 57.25
# Adjustment of CE at 2020-01-10 14:07:00
# Exited SELL Contract : BANKNIFTY3240016JAN20CE at Price : 123.1 and NEW BUY Contract : BANKNIFTY3280016JAN20CE and Price : 123.1
# Entered New SELL Contract : BANKNIFTY3210016JAN20CE at Price : 245.0 and NEW BUY Contract : BANKNIFTY3260016JAN20CE and Price : 81.55
# Stoploss Created at 2020-01-10 14:07:00
# Target Hit at 2020-01-16 09:15:00 .Closed Sell CE Contract : BANKNIFTY3210016JAN20CE at Price 25.0 .Closed Sell PE Contract : BANKNIFTY3200016JAN20PE at Price 155.7
# Closed Buy CE Contract : BANKNIFTY3260016JAN20CE at Price 1.5 .Closed Buy PE Contract : BANKNIFTY3140016JAN20PE at Price 2.7
#
#
#
#
# 2020-01-16 10:00:00
# 23JAN20
# False
# BANKNIFTY3240023JAN20CE
# Entry at 2020-01-16 10:00:00 at a SP of 31900
# Enter First Sell Series CE Contract : BANKNIFTY3240023JAN20CE Price : 114.5 . PE Contract : BANKNIFTY3140023JAN20PE Price : 90.95
# Enter First Buy Series CE Contract : BANKNIFTY3280023JAN20CE Price : 40.05 . PE Contract : BANKNIFTY3090023JAN20PE Price : 33.5
# Adjustment of CE at 2020-01-16 11:00:00
# Exited SELL Contract : BANKNIFTY3240023JAN20CE at Price : 73.0 and NEW BUY Contract : BANKNIFTY3280023JAN20CE and Price : 73.0
# Entered New SELL Contract : BANKNIFTY3220023JAN20CE at Price : 126.3 and NEW BUY Contract : BANKNIFTY3260023JAN20CE and Price : 43.35
# Adjustment of CE at 2020-01-16 13:58:00
# Exited SELL Contract : BANKNIFTY3140023JAN20PE at Price : 76.65 and NEW BUY Contract : BANKNIFTY3090023JAN20PE and Price : 76.65
# Entered New SELL Contract : BANKNIFTY3160023JAN20PE at Price : 126.85 and NEW BUY Contract : BANKNIFTY3110023JAN20PE and Price : 43.05
# Adjustment of CE at 2020-01-17 09:15:00
# Exited SELL Contract : BANKNIFTY3220023JAN20CE at Price : 64.35 and NEW BUY Contract : BANKNIFTY3260023JAN20CE and Price : 64.35
# Entered New SELL Contract : BANKNIFTY3170023JAN20CE at Price : 230.0 and NEW BUY Contract : BANKNIFTY3220023JAN20CE and Price : 70.05
# Stoploss Created at 2020-01-17 09:15:00
# StopLoss Hit at 2020-01-20 14:24:00 .Closed Sell CE Contract : BANKNIFTY3170023JAN20CE at Price 71.0 .Closed Sell PE Contract : BANKNIFTY3160023JAN20PE at Price 505.4
# Closed Buy CE Contract : BANKNIFTY3220023JAN20CE at Price 19.45 .Closed Buy PE Contract : BANKNIFTY3110023JAN20PE at Price 193.55
#
#
#
#
# 2020-01-23 10:00:00
# JAN20
# True
# None
# Data is not available in either PE or CE at Data Preprocessing for 2020-01-23 10:00:00
# 2020-01-30 10:00:00
# 06FEB20
# False
# BANKNIFTY3200006FEB20CE
# Entry at 2020-01-30 10:00:00 at a SP of 30700
# Enter First Sell Series CE Contract : BANKNIFTY3200006FEB20CE Price : 94.0 . PE Contract : BANKNIFTY2960006FEB20PE Price : 107.1
# Enter First Buy Series CE Contract : BANKNIFTY3270006FEB20CE Price : 30.0 . PE Contract : BANKNIFTY2900006FEB20PE Price : 43.3
# Adjustment of CE at 2020-02-01 13:18:00
# Exited SELL Contract : BANKNIFTY3200006FEB20CE at Price : 63.15 and NEW BUY Contract : BANKNIFTY3270006FEB20CE and Price : 63.15
# Entered New SELL Contract : BANKNIFTY3160006FEB20CE at Price : 118.7 and NEW BUY Contract : BANKNIFTY3240006FEB20CE and Price : 40.8
# Adjustment of CE at 2020-02-01 13:27:00
# Exited SELL Contract : BANKNIFTY3160006FEB20CE at Price : 60.05 and NEW BUY Contract : BANKNIFTY3240006FEB20CE and Price : 60.05
# Entered New SELL Contract : BANKNIFTY3110006FEB20CE at Price : 158.9 and NEW BUY Contract : BANKNIFTY3190006FEB20CE and Price : 52.05
# Adjustment of CE at 2020-02-01 13:43:00
# Exited SELL Contract : BANKNIFTY3110006FEB20CE at Price : 90.6 and NEW BUY Contract : BANKNIFTY3190006FEB20CE and Price : 90.6
# Entered New SELL Contract : BANKNIFTY3070006FEB20CE at Price : 194.4 and NEW BUY Contract : BANKNIFTY3140006FEB20CE and Price : 65.6
# Adjustment of CE at 2020-02-01 14:05:00
# Exited SELL Contract : BANKNIFTY2960006FEB20PE at Price : 113.7 and NEW BUY Contract : BANKNIFTY2900006FEB20PE and Price : 113.7
# Entered New SELL Contract : BANKNIFTY2990006FEB20PE at Price : 210.95 and NEW BUY Contract : BANKNIFTY2930006FEB20PE and Price : 75.0
# Adjustment of CE at 2020-02-01 14:41:00
# Exited SELL Contract : BANKNIFTY3070006FEB20CE at Price : 134.35 and NEW BUY Contract : BANKNIFTY3140006FEB20CE and Price : 134.35
# Entered New SELL Contract : BANKNIFTY3040006FEB20CE at Price : 231.7 and NEW BUY Contract : BANKNIFTY3100006FEB20CE and Price : 83.6
# Adjustment of CE at 2020-02-01 15:00:00
# Exited SELL Contract : BANKNIFTY3040006FEB20CE at Price : 153.05 and NEW BUY Contract : BANKNIFTY3100006FEB20CE and Price : 153.05
# Entered New SELL Contract : BANKNIFTY3000006FEB20CE at Price : 322.3 and NEW BUY Contract : BANKNIFTY3070006FEB20CE and Price : 101.8
# Stoploss Created at 2020-02-01 15:00:00
# StopLoss Hit at 2020-02-04 11:17:00 .Closed Sell CE Contract : BANKNIFTY3000006FEB20CE at Price 726.45 .Closed Sell PE Contract : BANKNIFTY2990006FEB20PE at Price 21.65
# Closed Buy CE Contract : BANKNIFTY3070006FEB20CE at Price 195.0 .Closed Buy PE Contract : BANKNIFTY2930006FEB20PE at Price 8.05
#
#
#
#
# 2020-02-06 10:00:00
# 13FEB20
# False
# BANKNIFTY3160013FEB20CE
# Entry at 2020-02-06 10:00:00 at a SP of 31100
# Enter First Sell Series CE Contract : BANKNIFTY3160013FEB20CE Price : 112.35 . PE Contract : BANKNIFTY3050013FEB20PE Price : 102.15
# Enter First Buy Series CE Contract : BANKNIFTY3200013FEB20CE Price : 44.5 . PE Contract : BANKNIFTY3000013FEB20PE Price : 34.9
# Adjustment of CE at 2020-02-06 11:56:00
# Exited SELL Contract : BANKNIFTY3050013FEB20PE at Price : 73.7 and NEW BUY Contract : BANKNIFTY3000013FEB20PE and Price : 73.7
# Entered New SELL Contract : BANKNIFTY3070013FEB20PE at Price : 115.65 and NEW BUY Contract : BANKNIFTY3020013FEB20PE and Price : 40.2
# Adjustment of CE at 2020-02-06 12:41:00
# Exited SELL Contract : BANKNIFTY3070013FEB20PE at Price : 87.15 and NEW BUY Contract : BANKNIFTY3020013FEB20PE and Price : 87.15
# Entered New SELL Contract : BANKNIFTY3090013FEB20PE at Price : 136.0 and NEW BUY Contract : BANKNIFTY3040013FEB20PE and Price : 49.8
# Adjustment of CE at 2020-02-06 13:21:00
# Exited SELL Contract : BANKNIFTY3090013FEB20PE at Price : 102.15 and NEW BUY Contract : BANKNIFTY3040013FEB20PE and Price : 102.15
# Entered New SELL Contract : BANKNIFTY3110013FEB20PE at Price : 156.65 and NEW BUY Contract : BANKNIFTY3050013FEB20PE and Price : 47.2
# Adjustment of CE at 2020-02-07 09:15:00
# Exited SELL Contract : BANKNIFTY3160013FEB20CE at Price : 117.35 and NEW BUY Contract : BANKNIFTY3200013FEB20CE and Price : 117.35
# Entered New SELL Contract : BANKNIFTY3130013FEB20CE at Price : 284.95 and NEW BUY Contract : BANKNIFTY3180013FEB20CE and Price : 83.05
# Adjustment of CE at 2020-02-10 09:22:00
# Exited SELL Contract : BANKNIFTY3130013FEB20CE at Price : 116.45 and NEW BUY Contract : BANKNIFTY3180013FEB20CE and Price : 116.45
# Entered New SELL Contract : BANKNIFTY3110013FEB20CE at Price : 211.4 and NEW BUY Contract : BANKNIFTY3150013FEB20CE and Price : 72.0
# Stoploss Created at 2020-02-10 09:22:00
# Expiry Exit at 2020-02-13 10:00:00 .Closed Sell CE Contract : BANKNIFTY3110013FEB20CE at Price 210.25 .Closed Sell PE Contract : BANKNIFTY3110013FEB20PE at Price 15.75
# Closed Buy CE Contract : BANKNIFTY3150013FEB20CE at Price 15.2 .Closed Buy PE Contract : BANKNIFTY3050013FEB20PE at Price 0.7
#
#
#
#
# 2020-02-13 10:00:00
# 20FEB20
# False
# BANKNIFTY3170020FEB20CE
# Entry at 2020-02-13 10:00:00 at a SP of 31300
# Enter First Sell Series CE Contract : BANKNIFTY3170020FEB20CE Price : 108.45 . PE Contract : BANKNIFTY3080020FEB20PE Price : 85.8
# Enter First Buy Series CE Contract : BANKNIFTY3210020FEB20CE Price : 33.75 . PE Contract : BANKNIFTY3030020FEB20PE Price : 28.0
# Adjustment of CE at 2020-02-14 09:20:00
# Exited SELL Contract : BANKNIFTY3080020FEB20PE at Price : 54.05 and NEW BUY Contract : BANKNIFTY3030020FEB20PE and Price : 54.05
# Entered New SELL Contract : BANKNIFTY3100020FEB20PE at Price : 98.05 and NEW BUY Contract : BANKNIFTY3060020FEB20PE and Price : 33.65
# Adjustment of CE at 2020-02-14 10:50:00
# Exited SELL Contract : BANKNIFTY3170020FEB20CE at Price : 70.05 and NEW BUY Contract : BANKNIFTY3210020FEB20CE and Price : 70.05
# Entered New SELL Contract : BANKNIFTY3150020FEB20CE at Price : 124.95 and NEW BUY Contract : BANKNIFTY3190020FEB20CE and Price : 36.7
# Adjustment of CE at 2020-02-14 10:52:00
# Exited SELL Contract : BANKNIFTY3150020FEB20CE at Price : 97.05 and NEW BUY Contract : BANKNIFTY3190020FEB20CE and Price : 97.05
# Entered New SELL Contract : BANKNIFTY3130020FEB20CE at Price : 172.2 and NEW BUY Contract : BANKNIFTY3170020FEB20CE and Price : 58.15
# Adjustment of CE at 2020-02-14 10:55:00
# Exited SELL Contract : BANKNIFTY3130020FEB20CE at Price : 92.15 and NEW BUY Contract : BANKNIFTY3170020FEB20CE and Price : 92.15
# Entered New SELL Contract : BANKNIFTY3090020FEB20CE at Price : 337.25 and NEW BUY Contract : BANKNIFTY3130020FEB20CE and Price : 142.2
# Stoploss Created at 2020-02-14 10:55:00
# StopLoss Hit at 2020-02-18 09:30:00 .Closed Sell CE Contract : BANKNIFTY3090020FEB20CE at Price 58.75 .Closed Sell PE Contract : BANKNIFTY3100020FEB20PE at Price 560.15
# Closed Buy CE Contract : BANKNIFTY3130020FEB20CE at Price 19.75 .Closed Buy PE Contract : BANKNIFTY3060020FEB20PE at Price 256.2
#
#
#
#
# 2020-02-20 10:00:00
# FEB20
# True
# None
# Data is not available in either PE or CE at Data Preprocessing for 2020-02-20 10:00:00
# 2020-02-27 10:00:00
# 05MAR20
# False
# BANKNIFTY3080005MAR20CE
# Entry at 2020-02-27 10:00:00 at a SP of 30000
# Enter First Sell Series CE Contract : BANKNIFTY3080005MAR20CE Price : 104.0 . PE Contract : BANKNIFTY2910005MAR20PE Price : 99.95
# Enter First Buy Series CE Contract : BANKNIFTY3130005MAR20CE Price : 34.7 . PE Contract : BANKNIFTY2850005MAR20PE Price : 39.7
# Adjustment of CE at 2020-02-27 15:02:00
# Exited SELL Contract : BANKNIFTY2910005MAR20PE at Price : 52.15 and NEW BUY Contract : BANKNIFTY2850005MAR20PE and Price : 52.15
# Entered New SELL Contract : BANKNIFTY2940005MAR20PE at Price : 89.45 and NEW BUY Contract : BANKNIFTY2870005MAR20PE and Price : 29.0
# Adjustment of CE at 2020-02-28 09:17:00
# Exited SELL Contract : BANKNIFTY3080005MAR20CE at Price : 24.3 and NEW BUY Contract : BANKNIFTY3130005MAR20CE and Price : 24.3
# Entered New SELL Contract : BANKNIFTY2980005MAR20CE at Price : 302.0 and NEW BUY Contract : BANKNIFTY3030005MAR20CE and Price : 95.95
# Adjustment of CE at 2020-02-28 09:56:00
# Exited SELL Contract : BANKNIFTY2980005MAR20CE at Price : 196.0 and NEW BUY Contract : BANKNIFTY3030005MAR20CE and Price : 196.0
# Entered New SELL Contract : BANKNIFTY2950005MAR20CE at Price : 333.45 and NEW BUY Contract : BANKNIFTY3020005MAR20CE and Price : 106.15
# Stoploss Created at 2020-02-28 09:56:00
# StopLoss Hit at 2020-02-28 12:17:00 .Closed Sell CE Contract : BANKNIFTY2950005MAR20CE at Price 283.95 .Closed Sell PE Contract : BANKNIFTY2940005MAR20PE at Price 543.9
# Closed Buy CE Contract : BANKNIFTY3020005MAR20CE at Price 90.25 .Closed Buy PE Contract : BANKNIFTY2870005MAR20PE at Price 252.2
#
#
#
#
# 2020-03-05 10:00:00
# 12MAR20
# False
# BANKNIFTY2960012MAR20CE
# Entry at 2020-03-05 10:00:00 at a SP of 28600
# Enter First Sell Series CE Contract : BANKNIFTY2960012MAR20CE Price : 97.95 . PE Contract : BANKNIFTY2740012MAR20PE Price : 118.75
# Enter First Buy Series CE Contract : BANKNIFTY3020012MAR20CE Price : 34.2 . PE Contract : BANKNIFTY2650012MAR20PE Price : 37.5
# Adjustment of CE at 2020-03-05 10:46:00
# Exited SELL Contract : BANKNIFTY2740012MAR20PE at Price : 70.0 and NEW BUY Contract : BANKNIFTY2650012MAR20PE and Price : 70.0
# Entered New SELL Contract : BANKNIFTY2780012MAR20PE at Price : 120.0 and NEW BUY Contract : BANKNIFTY2700012MAR20PE and Price : 47.6
# Adjustment of CE at 2020-03-05 11:30:00
# Exited SELL Contract : BANKNIFTY2780012MAR20PE at Price : 100.55 and NEW BUY Contract : BANKNIFTY2700012MAR20PE and Price : 100.55
# Entered New SELL Contract : BANKNIFTY2820012MAR20PE at Price : 168.4 and NEW BUY Contract : BANKNIFTY2740012MAR20PE and Price : 58.05
# Adjustment of CE at 2020-03-05 13:50:00
# Exited SELL Contract : BANKNIFTY2960012MAR20CE at Price : 106.85 and NEW BUY Contract : BANKNIFTY3020012MAR20CE and Price : 106.85
# Entered New SELL Contract : BANKNIFTY2930012MAR20CE at Price : 195.35 and NEW BUY Contract : BANKNIFTY2990012MAR20CE and Price : 63.6
# Adjustment of CE at 2020-03-06 09:17:00
# Exited SELL Contract : BANKNIFTY2930012MAR20CE at Price : 2.55 and NEW BUY Contract : BANKNIFTY2990012MAR20CE and Price : 2.55
# Entered New SELL Contract : BANKNIFTY2940012MAR20CE at Price : 36.6 and NEW BUY Contract : BANKNIFTY3020012MAR20CE and Price : 9.6
# Adjustment of CE at 2020-03-06 09:18:00
# Exited SELL Contract : BANKNIFTY2940012MAR20CE at Price : 36.95 and NEW BUY Contract : BANKNIFTY3020012MAR20CE and Price : 36.95
# Entered New SELL Contract : BANKNIFTY2920012MAR20CE at Price : 40.1 and NEW BUY Contract : BANKNIFTY3000012MAR20CE and Price : 16.15
# Adjustment of CE at 2020-03-06 09:19:00
# Exited SELL Contract : BANKNIFTY2920012MAR20CE at Price : 41.0 and NEW BUY Contract : BANKNIFTY3000012MAR20CE and Price : 41.0
# Entered New SELL Contract : BANKNIFTY2750012MAR20CE at Price : 602.1 and NEW BUY Contract : BANKNIFTY2920012MAR20CE and Price : 42.5
# Stoploss Created at 2020-03-06 09:19:00
# StopLoss Hit at 2020-03-09 09:39:00 .Closed Sell CE Contract : BANKNIFTY2750012MAR20CE at Price 164.6 .Closed Sell PE Contract : BANKNIFTY2820012MAR20PE at Price 1445.0
# Closed Buy CE Contract : BANKNIFTY2920012MAR20CE at Price 10.7 .Closed Buy PE Contract : BANKNIFTY2740012MAR20PE at Price 789.35
#
#
#
#
# 2020-03-12 10:00:00
# 19MAR20
# 2020-03-19 10:00:00
# MAR20
# 2020-03-26 10:00:00
# 01APR20
# 2020-04-01 10:00:00
# 09APR20
# False
# BANKNIFTY2050009APR20CE
# Entry at 2020-04-01 10:00:00 at a SP of 18600
# Enter First Sell Series CE Contract : BANKNIFTY2050009APR20CE Price : 101.6 . PE Contract : BANKNIFTY1550009APR20PE Price : 89.75
# Enter First Buy Series CE Contract : BANKNIFTY2200009APR20CE Price : 27.8 . PE Contract : BANKNIFTY1400009APR20PE Price : 34.9
# Adjustment of CE at 2020-04-01 11:30:00
# Exited SELL Contract : BANKNIFTY2050009APR20CE at Price : 51.5 and NEW BUY Contract : BANKNIFTY2200009APR20CE and Price : 51.5
# Entered New SELL Contract : BANKNIFTY2000009APR20CE at Price : 92.05 and NEW BUY Contract : BANKNIFTY2100009APR20CE and Price : 34.9
# Adjustment of CE at 2020-04-03 09:15:00
# Exited SELL Contract : BANKNIFTY2000009APR20CE at Price : 51.0 and NEW BUY Contract : BANKNIFTY2100009APR20CE and Price : 51.0
# Entered New SELL Contract : BANKNIFTY1950009APR20CE at Price : 139.45 and NEW BUY Contract : BANKNIFTY2050009APR20CE and Price : 55.0
# Adjustment of CE at 2020-04-03 09:20:00
# Exited SELL Contract : BANKNIFTY1950009APR20CE at Price : 82.15 and NEW BUY Contract : BANKNIFTY2050009APR20CE and Price : 82.15
# Entered New SELL Contract : BANKNIFTY1910009APR20CE at Price : 158.3 and NEW BUY Contract : BANKNIFTY1990009APR20CE and Price : 51.05
# Adjustment of CE at 2020-04-03 14:32:00
# Exited SELL Contract : BANKNIFTY1910009APR20CE at Price : 48.65 and NEW BUY Contract : BANKNIFTY1990009APR20CE and Price : 48.65
# Entered New SELL Contract : BANKNIFTY1860009APR20CE at Price : 85.8 and NEW BUY Contract : BANKNIFTY1960009APR20CE and Price : 28.05
# Adjustment of CE at 2020-04-07 09:22:00
# Exited SELL Contract : BANKNIFTY1550009APR20PE at Price : 27.35 and NEW BUY Contract : BANKNIFTY1400009APR20PE and Price : 27.35
# Entered New SELL Contract : BANKNIFTY1730009APR20PE at Price : 168.85 and NEW BUY Contract : BANKNIFTY1620009APR20PE and Price : 55.15
# Adjustment of CE at 2020-04-07 09:36:00
# Exited SELL Contract : BANKNIFTY1730009APR20PE at Price : 105.55 and NEW BUY Contract : BANKNIFTY1620009APR20PE and Price : 105.55
# Entered New SELL Contract : BANKNIFTY1770009APR20PE at Price : 213.9 and NEW BUY Contract : BANKNIFTY1700009APR20PE and Price : 72.35
# Adjustment of CE at 2020-04-07 10:35:00
# Exited SELL Contract : BANKNIFTY1860009APR20CE at Price : 149.6 and NEW BUY Contract : BANKNIFTY1960009APR20CE and Price : 149.6
# Entered New SELL Contract : BANKNIFTY1820009APR20CE at Price : 290.95 and NEW BUY Contract : BANKNIFTY1890009APR20CE and Price : 100.55
# Adjustment of CE at 2020-04-07 11:25:00
# Exited SELL Contract : BANKNIFTY1770009APR20PE at Price : 197.1 and NEW BUY Contract : BANKNIFTY1700009APR20PE and Price : 197.1
# Entered New SELL Contract : BANKNIFTY1810009APR20PE at Price : 361.75 and NEW BUY Contract : BANKNIFTY1730009APR20PE and Price : 120.1
# Stoploss Created at 2020-04-07 11:25:00
# StopLoss Hit at 2020-04-07 11:26:00 .Closed Sell CE Contract : BANKNIFTY1820009APR20CE at Price 428.95 .Closed Sell PE Contract : BANKNIFTY1810009APR20PE at Price 351.5
# Closed Buy CE Contract : BANKNIFTY1890009APR20CE at Price 154.25 .Closed Buy PE Contract : BANKNIFTY1730009APR20PE at Price 114.0
#
#
#
#
# 2020-04-09 10:00:00
# 16APR20
# False
# BANKNIFTY2250016APR20CE
# Entry at 2020-04-09 10:00:00 at a SP of 19600
# Enter First Sell Series CE Contract : BANKNIFTY2250016APR20CE Price : 85.45 . PE Contract : BANKNIFTY1650016APR20PE Price : 99.0
# Enter First Buy Series CE Contract : BANKNIFTY2400016APR20CE Price : 28.15 . PE Contract : BANKNIFTY1500016APR20PE Price : 33.45
# Adjustment of CE at 2020-04-09 10:59:00
# Exited SELL Contract : BANKNIFTY2250016APR20CE at Price : 53.9 and NEW BUY Contract : BANKNIFTY2400016APR20CE and Price : 53.9
# Entered New SELL Contract : BANKNIFTY2200016APR20CE at Price : 81.75 and NEW BUY Contract : BANKNIFTY2300016APR20CE and Price : 36.25
# Adjustment of CE at 2020-04-09 15:27:00
# Exited SELL Contract : BANKNIFTY1650016APR20PE at Price : 50.15 and NEW BUY Contract : BANKNIFTY1500016APR20PE and Price : 50.15
# Entered New SELL Contract : BANKNIFTY1700016APR20PE at Price : 87.9 and NEW BUY Contract : BANKNIFTY1600016APR20PE and Price : 30.5
# Adjustment of CE at 2020-04-13 09:30:00
# Exited SELL Contract : BANKNIFTY2200016APR20CE at Price : 30.8 and NEW BUY Contract : BANKNIFTY2300016APR20CE and Price : 30.8
# Entered New SELL Contract : BANKNIFTY2150016APR20CE at Price : 64.8 and NEW BUY Contract : BANKNIFTY2250016APR20CE and Price : 17.75
# Adjustment of CE at 2020-04-13 11:39:00
# Exited SELL Contract : BANKNIFTY1700016APR20PE at Price : 38.25 and NEW BUY Contract : BANKNIFTY1600016APR20PE and Price : 38.25
# Entered New SELL Contract : BANKNIFTY1740016APR20PE at Price : 63.0 and NEW BUY Contract : BANKNIFTY1650016APR20PE and Price : 19.9
# Adjustment of CE at 2020-04-15 09:15:00
# Exited SELL Contract : BANKNIFTY1740016APR20PE at Price : 14.65 and NEW BUY Contract : BANKNIFTY1650016APR20PE and Price : 14.65
# Entered New SELL Contract : BANKNIFTY1800016APR20PE at Price : 64.0 and NEW BUY Contract : BANKNIFTY1730016APR20PE and Price : 13.2
# Adjustment of CE at 2020-04-15 09:17:00
# Exited SELL Contract : BANKNIFTY1800016APR20PE at Price : 25.55 and NEW BUY Contract : BANKNIFTY1730016APR20PE and Price : 25.55
# Entered New SELL Contract : BANKNIFTY1830016APR20PE at Price : 50.8 and NEW BUY Contract : BANKNIFTY1760016APR20PE and Price : 19.4
# Adjustment of CE at 2020-04-15 12:51:00
# Exited SELL Contract : BANKNIFTY2150016APR20CE at Price : 13.55 and NEW BUY Contract : BANKNIFTY2250016APR20CE and Price : 13.55
# Entered New SELL Contract : BANKNIFTY2130016APR20CE at Price : 23.8 and NEW BUY Contract : BANKNIFTY2170016APR20CE and Price : 8.65
# Adjustment of CE at 2020-04-15 13:15:00
# Exited SELL Contract : BANKNIFTY2130016APR20CE at Price : 14.05 and NEW BUY Contract : BANKNIFTY2170016APR20CE and Price : 14.05
# Entered New SELL Contract : BANKNIFTY2110016APR20CE at Price : 26.7 and NEW BUY Contract : BANKNIFTY2150016APR20CE and Price : 9.6
# Adjustment of CE at 2020-04-15 13:23:00
# Exited SELL Contract : BANKNIFTY2110016APR20CE at Price : 18.2 and NEW BUY Contract : BANKNIFTY2150016APR20CE and Price : 18.2
# Entered New SELL Contract : BANKNIFTY2090016APR20CE at Price : 29.75 and NEW BUY Contract : BANKNIFTY2130016APR20CE and Price : 10.35
# Adjustment of CE at 2020-04-15 13:45:00
# Exited SELL Contract : BANKNIFTY2090016APR20CE at Price : 20.85 and NEW BUY Contract : BANKNIFTY2130016APR20CE and Price : 20.85
# Entered New SELL Contract : BANKNIFTY2060016APR20CE at Price : 47.3 and NEW BUY Contract : BANKNIFTY2110016APR20CE and Price : 14.05
# Adjustment of CE at 2020-04-15 14:01:00
# Exited SELL Contract : BANKNIFTY2060016APR20CE at Price : 32.65 and NEW BUY Contract : BANKNIFTY2110016APR20CE and Price : 32.65
# Entered New SELL Contract : BANKNIFTY2040016APR20CE at Price : 58.8 and NEW BUY Contract : BANKNIFTY2090016APR20CE and Price : 17.95
# Adjustment of CE at 2020-04-15 14:08:00
# Exited SELL Contract : BANKNIFTY2040016APR20CE at Price : 40.55 and NEW BUY Contract : BANKNIFTY2090016APR20CE and Price : 40.55
# Entered New SELL Contract : BANKNIFTY2010016APR20CE at Price : 86.3 and NEW BUY Contract : BANKNIFTY2060016APR20CE and Price : 27.45
# Adjustment of CE at 2020-04-15 14:10:00
# Exited SELL Contract : BANKNIFTY2010016APR20CE at Price : 61.35 and NEW BUY Contract : BANKNIFTY2060016APR20CE and Price : 61.35
# Entered New SELL Contract : BANKNIFTY1980016APR20CE at Price : 127.25 and NEW BUY Contract : BANKNIFTY2030016APR20CE and Price : 47.3
# Adjustment of CE at 2020-04-15 14:16:00
# Exited SELL Contract : BANKNIFTY1980016APR20CE at Price : 82.65 and NEW BUY Contract : BANKNIFTY2030016APR20CE and Price : 82.65
# Entered New SELL Contract : BANKNIFTY1950016APR20CE at Price : 151.65 and NEW BUY Contract : BANKNIFTY2010016APR20CE and Price : 53.0
# Adjustment of CE at 2020-04-16 09:15:00
# Exited SELL Contract : BANKNIFTY1950016APR20CE at Price : 35.0 and NEW BUY Contract : BANKNIFTY2010016APR20CE and Price : 35.0
# Entered New SELL Contract : BANKNIFTY1930016APR20CE at Price : 210.0 and NEW BUY Contract : BANKNIFTY1960016APR20CE and Price : 91.65
# Adjustment of CE at 2020-04-16 09:19:00
# Exited SELL Contract : BANKNIFTY1930016APR20CE at Price : 47.75 and NEW BUY Contract : BANKNIFTY1960016APR20CE and Price : 47.75
# Entered New SELL Contract : BANKNIFTY1910016APR20CE at Price : 113.25 and NEW BUY Contract : BANKNIFTY1940016APR20CE and Price : 39.3
# Adjustment of CE at 2020-04-16 09:39:00
# Exited SELL Contract : BANKNIFTY1830016APR20PE at Price : 52.7 and NEW BUY Contract : BANKNIFTY1760016APR20PE and Price : 52.7
# Entered New SELL Contract : BANKNIFTY1860016APR20PE at Price : 125.85 and NEW BUY Contract : BANKNIFTY1820016APR20PE and Price : 44.9
# Adjustment of CE at 2020-04-16 09:41:00
# Exited SELL Contract : BANKNIFTY1860016APR20PE at Price : 83.9 and NEW BUY Contract : BANKNIFTY1820016APR20PE and Price : 83.9
# Entered New SELL Contract : BANKNIFTY1900016APR20PE at Price : 230.0 and NEW BUY Contract : BANKNIFTY1850016APR20PE and Price : 78.0
# Stoploss Created at 2020-04-16 09:41:00
# StopLoss Hit at 2020-04-16 09:42:00 .Closed Sell CE Contract : BANKNIFTY1910016APR20CE at Price 205.6 .Closed Sell PE Contract : BANKNIFTY1900016APR20PE at Price 229.1
# Closed Buy CE Contract : BANKNIFTY1940016APR20CE at Price 88.15 .Closed Buy PE Contract : BANKNIFTY1850016APR20PE at Price 73.85
#
#
#
#
# 2020-04-16 10:00:00
# 23APR20
# False
# BANKNIFTY2100023APR20CE
# Entry at 2020-04-16 10:00:00 at a SP of 18900
# Enter First Sell Series CE Contract : BANKNIFTY2100023APR20CE Price : 88.05 . PE Contract : BANKNIFTY1650023APR20PE Price : 85.0
# Enter First Buy Series CE Contract : BANKNIFTY2200023APR20CE Price : 28.0 . PE Contract : BANKNIFTY1550023APR20PE Price : 26.8
# Adjustment of CE at 2020-04-16 11:15:00
# Exited SELL Contract : BANKNIFTY1650023APR20PE at Price : 51.0 and NEW BUY Contract : BANKNIFTY1550023APR20PE and Price : 51.0
# Entered New SELL Contract : BANKNIFTY1700023APR20PE at Price : 97.05 and NEW BUY Contract : BANKNIFTY1600023APR20PE and Price : 30.65
# Adjustment of CE at 2020-04-16 12:24:00
# Exited SELL Contract : BANKNIFTY1700023APR20PE at Price : 73.5 and NEW BUY Contract : BANKNIFTY1600023APR20PE and Price : 73.5
# Entered New SELL Contract : BANKNIFTY1750023APR20PE at Price : 131.25 and NEW BUY Contract : BANKNIFTY1650023APR20PE and Price : 43.6
# Adjustment of CE at 2020-04-17 09:15:00
# Exited SELL Contract : BANKNIFTY1750023APR20PE at Price : 37.3 and NEW BUY Contract : BANKNIFTY1650023APR20PE and Price : 37.3
# Entered New SELL Contract : BANKNIFTY1950023APR20PE at Price : 285.6 and NEW BUY Contract : BANKNIFTY1850023APR20PE and Price : 109.1
# Adjustment of CE at 2020-04-17 10:49:00
# Exited SELL Contract : BANKNIFTY2100023APR20CE at Price : 258.5 and NEW BUY Contract : BANKNIFTY2200023APR20CE and Price : 258.5
# Entered New SELL Contract : BANKNIFTY2040023APR20CE at Price : 447.55 and NEW BUY Contract : BANKNIFTY2160023APR20CE and Price : 153.25
# Adjustment of CE at 2020-04-17 14:50:00
# Exited SELL Contract : BANKNIFTY1950023APR20PE at Price : 276.6 and NEW BUY Contract : BANKNIFTY1850023APR20PE and Price : 276.6
# Entered New SELL Contract : BANKNIFTY2000023APR20PE at Price : 444.65 and NEW BUY Contract : BANKNIFTY1890023APR20PE and Price : 147.55
# Adjustment of CE at 2020-04-17 15:06:00
# Exited SELL Contract : BANKNIFTY2000023APR20PE at Price : 362.9 and NEW BUY Contract : BANKNIFTY1890023APR20PE and Price : 362.9
# Entered New SELL Contract : BANKNIFTY2070023APR20PE at Price : 682.8 and NEW BUY Contract : BANKNIFTY1940023APR20PE and Price : 227.2
# Stoploss Created at 2020-04-17 15:06:00
# StopLoss Hit at 2020-04-17 15:07:00 .Closed Sell CE Contract : BANKNIFTY2040023APR20CE at Price 789.95 .Closed Sell PE Contract : BANKNIFTY2070023APR20PE at Price 656.35
# Closed Buy CE Contract : BANKNIFTY2160023APR20CE at Price 261.15 .Closed Buy PE Contract : BANKNIFTY1940023APR20PE at Price 221.45
#
#
#
#
# 2020-04-23 10:00:00
# APR20
# True
# None
# Data is not available in either PE or CE at Data Preprocessing for 2020-04-23 10:00:00
# 2020-04-30 10:00:00
# 07MAY20
# False
# BANKNIFTY2300007MAY20CE
# Entry at 2020-04-30 10:00:00 at a SP of 21800
# Enter First Sell Series CE Contract : BANKNIFTY2300007MAY20CE Price : 95.5 . PE Contract : BANKNIFTY2040007MAY20PE Price : 96.9
# Enter First Buy Series CE Contract : BANKNIFTY2400007MAY20CE Price : 31.85 . PE Contract : BANKNIFTY1900007MAY20PE Price : 29.75
# Adjustment of CE at 2020-04-30 14:18:00
# Exited SELL Contract : BANKNIFTY2300007MAY20CE at Price : 80.95 and NEW BUY Contract : BANKNIFTY2400007MAY20CE and Price : 80.95
# Entered New SELL Contract : BANKNIFTY2250007MAY20CE at Price : 156.4 and NEW BUY Contract : BANKNIFTY2350007MAY20CE and Price : 45.05
# Adjustment of CE at 2020-05-04 09:15:00
# Exited SELL Contract : BANKNIFTY2250007MAY20CE at Price : 20.15 and NEW BUY Contract : BANKNIFTY2350007MAY20CE and Price : 20.15
# Entered New SELL Contract : BANKNIFTY2060007MAY20CE at Price : 337.35 and NEW BUY Contract : BANKNIFTY2110007MAY20CE and Price : 135.0
# Adjustment of CE at 2020-05-04 09:31:00
# Exited SELL Contract : BANKNIFTY2060007MAY20CE at Price : 342.45 and NEW BUY Contract : BANKNIFTY2110007MAY20CE and Price : 342.45
# Entered New SELL Contract : BANKNIFTY2010007MAY20CE at Price : 613.4 and NEW BUY Contract : BANKNIFTY2110007MAY20CE and Price : 200.0
# Stoploss Created at 2020-05-04 09:31:00
# StopLoss Hit at 2020-05-04 14:46:00 .Closed Sell CE Contract : BANKNIFTY2010007MAY20CE at Price 352.2 .Closed Sell PE Contract : BANKNIFTY2040007MAY20PE at Price 1118.2
# Closed Buy CE Contract : BANKNIFTY2110007MAY20CE at Price 115.9 .Closed Buy PE Contract : BANKNIFTY1900007MAY20PE at Price 367.35
#
#
#
#
# 2020-05-07 10:00:00
# 14MAY20
# False
# BANKNIFTY2150014MAY20CE
# Entry at 2020-05-07 10:00:00 at a SP of 19700
# Enter First Sell Series CE Contract : BANKNIFTY2150014MAY20CE Price : 92.4 . PE Contract : BANKNIFTY1750014MAY20PE Price : 77.4
# Enter First Buy Series CE Contract : BANKNIFTY2250014MAY20CE Price : 30.45 . PE Contract : BANKNIFTY1650014MAY20PE Price : 25.05
# Adjustment of CE at 2020-05-08 09:15:00
# Exited SELL Contract : BANKNIFTY1750014MAY20PE at Price : 30.95 and NEW BUY Contract : BANKNIFTY1650014MAY20PE and Price : 30.95
# Entered New SELL Contract : BANKNIFTY1810014MAY20PE at Price : 68.05 and NEW BUY Contract : BANKNIFTY1710014MAY20PE and Price : 18.85
# Adjustment of CE at 2020-05-08 13:51:00
# Exited SELL Contract : BANKNIFTY2150014MAY20CE at Price : 39.8 and NEW BUY Contract : BANKNIFTY2250014MAY20CE and Price : 39.8
# Entered New SELL Contract : BANKNIFTY2110014MAY20CE at Price : 73.35 and NEW BUY Contract : BANKNIFTY2180014MAY20CE and Price : 26.95
# Adjustment of CE at 2020-05-08 14:41:00
# Exited SELL Contract : BANKNIFTY2110014MAY20CE at Price : 54.8 and NEW BUY Contract : BANKNIFTY2180014MAY20CE and Price : 54.8
# Entered New SELL Contract : BANKNIFTY2070014MAY20CE at Price : 99.1 and NEW BUY Contract : BANKNIFTY2150014MAY20CE and Price : 30.6
# Adjustment of CE at 2020-05-11 09:15:00
# Exited SELL Contract : BANKNIFTY1810014MAY20PE at Price : 51.1 and NEW BUY Contract : BANKNIFTY1710014MAY20PE and Price : 51.1
# Entered New SELL Contract : BANKNIFTY1850014MAY20PE at Price : 138.4 and NEW BUY Contract : BANKNIFTY1780014MAY20PE and Price : 33.9
# Adjustment of CE at 2020-05-11 10:15:00
# Exited SELL Contract : BANKNIFTY2070014MAY20CE at Price : 71.45 and NEW BUY Contract : BANKNIFTY2150014MAY20CE and Price : 71.45
# Entered New SELL Contract : BANKNIFTY2040014MAY20CE at Price : 121.7 and NEW BUY Contract : BANKNIFTY2110014MAY20CE and Price : 37.35
# Adjustment of CE at 2020-05-11 11:40:00
# Exited SELL Contract : BANKNIFTY2040014MAY20CE at Price : 85.95 and NEW BUY Contract : BANKNIFTY2110014MAY20CE and Price : 85.95
# Entered New SELL Contract : BANKNIFTY2010014MAY20CE at Price : 137.8 and NEW BUY Contract : BANKNIFTY2080014MAY20CE and Price : 45.35
# Adjustment of CE at 2020-05-11 14:32:00
# Exited SELL Contract : BANKNIFTY2010014MAY20CE at Price : 97.65 and NEW BUY Contract : BANKNIFTY2080014MAY20CE and Price : 97.65
# Entered New SELL Contract : BANKNIFTY1980014MAY20CE at Price : 152.25 and NEW BUY Contract : BANKNIFTY2050014MAY20CE and Price : 52.4
# Adjustment of CE at 2020-05-12 09:15:00
# Exited SELL Contract : BANKNIFTY1980014MAY20CE at Price : 54.8 and NEW BUY Contract : BANKNIFTY2050014MAY20CE and Price : 54.8
# Entered New SELL Contract : BANKNIFTY1880014MAY20CE at Price : 300.1 and NEW BUY Contract : BANKNIFTY1950014MAY20CE and Price : 112.7
# Adjustment of CE at 2020-05-12 09:47:00
# Exited SELL Contract : BANKNIFTY1880014MAY20CE at Price : 198.25 and NEW BUY Contract : BANKNIFTY1950014MAY20CE and Price : 198.25
# Entered New SELL Contract : BANKNIFTY1850014MAY20CE at Price : 317.75 and NEW BUY Contract : BANKNIFTY1920014MAY20CE and Price : 102.8
# Stoploss Created at 2020-05-12 09:47:00
# StopLoss Hit at 2020-05-12 14:30:00 .Closed Sell CE Contract : BANKNIFTY1850014MAY20CE at Price 563.45 .Closed Sell PE Contract : BANKNIFTY1850014MAY20PE at Price 241.95
# Closed Buy CE Contract : BANKNIFTY1920014MAY20CE at Price 230.15 .Closed Buy PE Contract : BANKNIFTY1780014MAY20PE at Price 70.05
#
#
#
#
# 2020-05-14 10:00:00
# 21MAY20
# False
# BANKNIFTY2100021MAY20CE
# Entry at 2020-05-14 10:00:00 at a SP of 19200
# Enter First Sell Series CE Contract : BANKNIFTY2100021MAY20CE Price : 111.2 . PE Contract : BANKNIFTY1750021MAY20PE Price : 87.0
# Enter First Buy Series CE Contract : BANKNIFTY2200021MAY20CE Price : 38.15 . PE Contract : BANKNIFTY1650021MAY20PE Price : 24.9
# Adjustment of CE at 2020-05-15 09:18:00
# Exited SELL Contract : BANKNIFTY2100021MAY20CE at Price : 47.4 and NEW BUY Contract : BANKNIFTY2200021MAY20CE and Price : 47.4
# Entered New SELL Contract : BANKNIFTY2050021MAY20CE at Price : 89.0 and NEW BUY Contract : BANKNIFTY2140021MAY20CE and Price : 29.0
# Adjustment of CE at 2020-05-18 09:15:00
# Exited SELL Contract : BANKNIFTY2050021MAY20CE at Price : 35.9 and NEW BUY Contract : BANKNIFTY2140021MAY20CE and Price : 35.9
# Entered New SELL Contract : BANKNIFTY1990021MAY20CE at Price : 130.25 and NEW BUY Contract : BANKNIFTY2080021MAY20CE and Price : 39.2
# Adjustment of CE at 2020-05-18 09:35:00
# Exited SELL Contract : BANKNIFTY1990021MAY20CE at Price : 62.55 and NEW BUY Contract : BANKNIFTY2080021MAY20CE and Price : 62.55
# Entered New SELL Contract : BANKNIFTY1940021MAY20CE at Price : 115.75 and NEW BUY Contract : BANKNIFTY2030021MAY20CE and Price : 38.75
# Adjustment of CE at 2020-05-18 09:36:00
# Exited SELL Contract : BANKNIFTY1940021MAY20CE at Price : 108.05 and NEW BUY Contract : BANKNIFTY2030021MAY20CE and Price : 108.05
# Entered New SELL Contract : BANKNIFTY1900021MAY20CE at Price : 185.25 and NEW BUY Contract : BANKNIFTY1990021MAY20CE and Price : 62.05
# Adjustment of CE at 2020-05-18 09:45:00
# Exited SELL Contract : BANKNIFTY1900021MAY20CE at Price : 139.75 and NEW BUY Contract : BANKNIFTY1990021MAY20CE and Price : 139.75
# Entered New SELL Contract : BANKNIFTY1840021MAY20CE at Price : 298.5 and NEW BUY Contract : BANKNIFTY1940021MAY20CE and Price : 98.9
# Adjustment of CE at 2020-05-18 10:55:00
# Exited SELL Contract : BANKNIFTY1840021MAY20CE at Price : 213.5 and NEW BUY Contract : BANKNIFTY1940021MAY20CE and Price : 213.5
# Entered New SELL Contract : BANKNIFTY1790021MAY20CE at Price : 390.5 and NEW BUY Contract : BANKNIFTY1890021MAY20CE and Price : 127.7
# Adjustment of CE at 2020-05-19 10:18:00
# Exited SELL Contract : BANKNIFTY1750021MAY20PE at Price : 217.0 and NEW BUY Contract : BANKNIFTY1650021MAY20PE and Price : 217.0
# Entered New SELL Contract : BANKNIFTY1780021MAY20PE at Price : 341.8 and NEW BUY Contract : BANKNIFTY1710021MAY20PE and Price : 118.45
# Stoploss Created at 2020-05-19 10:18:00
# StopLoss Hit at 2020-05-19 13:41:00 .Closed Sell CE Contract : BANKNIFTY1790021MAY20CE at Price 218.4 .Closed Sell PE Contract : BANKNIFTY1780021MAY20PE at Price 600.15
# Closed Buy CE Contract : BANKNIFTY1890021MAY20CE at Price 41.45 .Closed Buy PE Contract : BANKNIFTY1710021MAY20PE at Price 244.25
#
#
#
#
# 2020-05-21 10:00:00
# MAY20
# True
# None
# Data is not available in either PE or CE at Data Preprocessing for 2020-05-21 10:00:00
# 2020-05-28 10:00:00
# 04JUN20
# False
# BANKNIFTY2020004JUN20CE
# Entry at 2020-05-28 10:00:00 at a SP of 19200
# Enter First Sell Series CE Contract : BANKNIFTY2020004JUN20CE Price : 118.05 . PE Contract : BANKNIFTY1770004JUN20PE Price : 97.55
# Enter First Buy Series CE Contract : BANKNIFTY2100004JUN20CE Price : 41.1 . PE Contract : BANKNIFTY1650004JUN20PE Price : 28.5
# Adjustment of CE at 2020-05-29 09:15:00
# Exited SELL Contract : BANKNIFTY2020004JUN20CE at Price : 65.0 and NEW BUY Contract : BANKNIFTY2100004JUN20CE and Price : 65.0
# Entered New SELL Contract : BANKNIFTY1990004JUN20CE at Price : 138.0 and NEW BUY Contract : BANKNIFTY2050004JUN20CE and Price : 51.95
# Adjustment of CE at 2020-05-29 10:40:00
# Exited SELL Contract : BANKNIFTY1770004JUN20PE at Price : 93.6 and NEW BUY Contract : BANKNIFTY1650004JUN20PE and Price : 93.6
# Entered New SELL Contract : BANKNIFTY1810004JUN20PE at Price : 166.3 and NEW BUY Contract : BANKNIFTY1720004JUN20PE and Price : 56.4
# Adjustment of CE at 2020-05-29 12:04:00
# Exited SELL Contract : BANKNIFTY1990004JUN20CE at Price : 105.65 and NEW BUY Contract : BANKNIFTY2050004JUN20CE and Price : 105.65
# Entered New SELL Contract : BANKNIFTY1960004JUN20CE at Price : 169.7 and NEW BUY Contract : BANKNIFTY2030004JUN20CE and Price : 58.8
# Adjustment of CE at 2020-06-01 09:15:00
# Exited SELL Contract : BANKNIFTY1810004JUN20PE at Price : 33.05 and NEW BUY Contract : BANKNIFTY1720004JUN20PE and Price : 33.05
# Entered New SELL Contract : BANKNIFTY1960004JUN20PE at Price : 370.5 and NEW BUY Contract : BANKNIFTY1890004JUN20PE and Price : 217.2
# Stoploss Created at 2020-06-01 09:15:00
# StopLoss Hit at 2020-06-01 09:16:00 .Closed Sell CE Contract : BANKNIFTY1960004JUN20CE at Price 477.75 .Closed Sell PE Contract : BANKNIFTY1960004JUN20PE at Price 354.35
# Closed Buy CE Contract : BANKNIFTY2030004JUN20CE at Price 210.25 .Closed Buy PE Contract : BANKNIFTY1890004JUN20PE at Price 121.9
#
#
#
#
# 2020-06-04 10:00:00
# 11JUN20
# False
# None
# Data is not available in either PE or CE at Data Preprocessing for 2020-06-04 10:00:00
# 2020-06-11 10:00:00
# 18JUN20
# False
# BANKNIFTY2300018JUN20CE
# Entry at 2020-06-11 10:00:00 at a SP of 21100
# Enter First Sell Series CE Contract : BANKNIFTY2300018JUN20CE Price : 106.75 . PE Contract : BANKNIFTY1900018JUN20PE Price : 95.95
# Enter First Buy Series CE Contract : BANKNIFTY2400018JUN20CE Price : 34.4 . PE Contract : BANKNIFTY1800018JUN20PE Price : 32.8
# Adjustment of CE at 2020-06-11 13:30:00
# Exited SELL Contract : BANKNIFTY2300018JUN20CE at Price : 68.15 and NEW BUY Contract : BANKNIFTY2400018JUN20CE and Price : 68.15
# Entered New SELL Contract : BANKNIFTY2250018JUN20CE at Price : 120.05 and NEW BUY Contract : BANKNIFTY2350018JUN20CE and Price : 40.45
# Adjustment of CE at 2020-06-11 15:16:00
# Exited SELL Contract : BANKNIFTY2250018JUN20CE at Price : 80.45 and NEW BUY Contract : BANKNIFTY2350018JUN20CE and Price : 80.45
# Entered New SELL Contract : BANKNIFTY2210018JUN20CE at Price : 127.85 and NEW BUY Contract : BANKNIFTY2310018JUN20CE and Price : 41.8
# Adjustment of CE at 2020-06-12 09:15:00
# Exited SELL Contract : BANKNIFTY2210018JUN20CE at Price : 60.55 and NEW BUY Contract : BANKNIFTY2310018JUN20CE and Price : 60.55

# %%
Orders
# Out:
#       entry                   type          entry_time            exittime  \
# 0        -1                     PE 2020-01-02 10:00:00 2020-01-02 12:14:00
# 1         1                     PE 2020-01-02 10:00:00 2020-01-02 12:14:00
# 2        -1                     PE 2020-01-02 12:14:00 2020-01-02 14:23:00
# 3         1                     PE 2020-01-02 12:14:00 2020-01-02 14:23:00
# 4        -1                     CE 2020-01-02 10:00:00 2020-01-03 09:30:00
# ...     ...                    ...                 ...                 ...
# 1371      1                     CE 2021-12-24 09:42:00 2021-12-27 09:15:00
# 1372     -1  BANKNIFTY34200DEC21CE 2021-12-27 09:15:00 2021-12-27 09:16:00
# 1373     -1  BANKNIFTY34800DEC21PE 2021-12-24 14:15:00 2021-12-27 09:16:00
# 1374      1  BANKNIFTY34900DEC21CE 2021-12-27 09:15:00 2021-12-27 09:16:00
# 1375      1  BANKNIFTY34000DEC21PE 2021-12-24 14:15:00 2021-12-27 09:16:00
#
#       entry_value  exitvalue exit_type     SP      dd  BasketID  \
# 0           94.90      71.85       Adj  32200   -6.35         1
# 1           30.50      23.45       Adj     UP   -7.25         1
# 2          126.75      92.90       Adj  32200  -13.25         1
# 3           42.20      31.25       Adj     UP  -10.95         1
# 4          108.55     119.00       Adj  32200 -108.45         1
# ...           ...        ...       ...    ...     ...       ...
# 1371        75.20      23.10       Adj     UP  -53.15       101
# 1372       627.15     490.35        SL  35200 -431.25       101
# 1373       249.15     607.55        SL  35200 -431.25       101
# 1374       344.00     158.55        SL  35200 -202.00       101
# 1375        84.70     236.60        SL  35200   78.75       101
#
#                  ContractName  LS
# 0     BANKNIFTY3190009JAN20PE   1
# 1     BANKNIFTY3150009JAN20PE   1
# 2     BANKNIFTY3210009JAN20PE   1
# 3     BANKNIFTY3170009JAN20PE   1
# 4     BANKNIFTY3250009JAN20CE   1
# ...                       ...  ..
# 1371    BANKNIFTY35900DEC21CE   1
# 1372    BANKNIFTY34200DEC21CE   1
# 1373    BANKNIFTY34800DEC21PE   1
# 1374    BANKNIFTY34900DEC21CE   1
# 1375    BANKNIFTY34000DEC21PE   1
#
# [1376 rows x 12 columns]

# %% [markdown]
# ### Base Model Backfilled

# %%
path = r'C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionBackFilled\2020_new'

HolidayList = ['02APR20', '11MAR21',
               '13MAY21', '19AUG21', '04NOV21', '14APR22']
NextHolidayList = ['09APR20', '18MAR21',
                   '20MAY21', '00AUG21', '13NOV21', '21APR22']
OrderBasketID = 0
Orders = pd.DataFrame(columns=['entry', 'type', 'entry_time', 'exittime','entry_value', 'exitvalue', 'exit_type', 'SP', 'dd', 'BasketID','ContractName','LS'])
LotSize = 25

today = datetime(2019, 12, 11, 0, 0, 0)


# Strating Date and Ending Date of the backtest
StartingDate = datetime(2020,1,1,9,30)
tdayTime = StartingDate
ENdTime = datetime(2021, 12, 28, 9, 30, 0)
#NoDataAvailableCt = ['12MAR20' , '19MAR20' , '01APR20','MAR20','04JUN20' , '16APR20']
NoDataAvailableCt = ['19MAR20' , 'MAR20' , '01APR20']

LastTradeEndDate = data.index[0] - timedelta(days=1)

DataMisses = 0

while True:
    IsHoliday = False
    tdayTime = tdayTime + timedelta(minutes=1)



    # Set The Starting Date
    if tdayTime <= StartingDate:
        continue


    # Set the back testing End date
    if tdayTime >= ENdTime:
        break
    
    # if tdayTime.date() in [date(2020,3,12) ] :
    #         continue
        
        
    if (tdayTime + timedelta(days=1)).date() in HolidayDateList and (tdayTime + timedelta(days=1)).weekday() == 3:
        IsHoliday = True
        
    
    if tdayTime.date()  in HolidayDateList:
        continue
    
    


    # To change the file path for different years
    if tdayTime >= datetime(2021, 1, 1, 9, 30, 0):
        path = r'C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionBackFilled\2021_new'
    if tdayTime >= datetime(2022, 1, 1, 9, 30, 0):
        path = r'C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionStrategy\IndianOptionData\2022_new'
        
        
        
        
        
        
    EntryWeekDay = 3
    
    if IsHoliday == True:
        EntryWeekDay = 2
        
    LastThrus = False
    # Enter Only Next Month last contract on this month last thursday
    if ((tdayTime.hour== 10 )and (tdayTime.minute == 00)) and (tdayTime.weekday() == EntryWeekDay):     
        print(tdayTime)
       
            
        

        NextExpiry = tdayTime + timedelta(days = 2)
        NextExpiry = NextExpiry + timedelta((3-NextExpiry.weekday()) % 7)
        #NextExpiry = NextExpiry + timedelta(hours=5.25)
        Expiryyear = NextExpiry.year
        ExpiryMonth = NextExpiry.month
        ExpiryDay = NextExpiry.day
        
        if NextExpiry in HolidayDateList:
            NextExpiry = NextExpiry - timedelta(days=1)
        
        # get the string value of the Expiry
        # if Expiryday is in 1 Digit we will add 0 at first
        if len(str(ExpiryDay)) == 1:
            StrExpiryDay = '0'+str(ExpiryDay)
        else:
            StrExpiryDay = str(ExpiryDay)
        StrExpiryYear = str(Expiryyear)[-2:]
        StrExpiryMonth = numbers_to_strings(ExpiryMonth)
    


        # if the Expiry is the last Expiry of the month we will add 00 at first to find the Contract
        if checkLastThursdayWithExpiry(tdayTime,  NextExpiry):
            StrExpiry = StrExpiryMonth+StrExpiryYear
            LastThrus = True
        else:
            StrExpiry = StrExpiryDay+StrExpiryMonth+StrExpiryYear


        # For Switching the Expiry to Wednesday where Thrusday is a Holiday
        if StrExpiry in HolidayList:
            StrExpiry = HolidaySwitch(StrExpiry)
            NextExpiry = NextExpiry - timedelta(days=1)
            
        
        
        
        CMP = data.loc[tdayTime]['open']
            
       
        
        #Rounding 
        CMP = round(float(CMP)/100)*100
        print(StrExpiry)
        
        if StrExpiry in NoDataAvailableCt:
            continue
        OrderBasketID+=1
        print(LastThrus)
        
        Price = 100
        SELLCEActiveContract , SELLCEActiveContractPrice = getContractBySP_backfilled(Price, tdayTime, StrExpiry,'CE',path , LastThrus)
        SELLPEActiveContract , SELLPEActiveContractPrice = getContractBySP_backfilled(Price, tdayTime, StrExpiry,'PE',path, LastThrus)
        print(SELLCEActiveContract)
        
        BuyPrice = 1/3* (Price)
   
        FirstBuyCEActiveContract , Buy1CEEntryPrice =  getContractBySP_backfilled(BuyPrice, tdayTime, StrExpiry,'CE',path, LastThrus)
        FirstBuyPEActiveContract , Buy1PEEntryPrice =  getContractBySP_backfilled(BuyPrice, tdayTime, StrExpiry,'PE',path, LastThrus)

        
        
        try:
            SellCE1 = pd.read_csv(f'{path}\{SELLCEActiveContract}.csv')
            SellCE1 = data_clean_backfilled(SellCE1)
            SellCE1 = SellCE1.drop(['volume','interest'] , axis =1)
            SellPE1 = pd.read_csv(f'{path}\{SELLPEActiveContract}.csv')
            SellPE1 = data_clean_backfilled(SellPE1)
            SellPE1 = SellPE1.drop(['volume','interest'] , axis =1)
            
            Buy1CE2 = pd.read_csv(f'{path}\{FirstBuyCEActiveContract}.csv')
            Buy1CE2 = data_clean_backfilled(Buy1CE2)
            Buy1CE2 = Buy1CE2.drop(['volume','interest'] , axis =1)
            Buy1PE2 = pd.read_csv(f'{path}\{FirstBuyPEActiveContract}.csv')
            Buy1PE2 = data_clean_backfilled(Buy1PE2)
            Buy1PE2 = Buy1PE2.drop(['volume','interest'] , axis =1)

            
            mdf1 = pd.merge_asof(SellCE1, SellPE1, on='datetime')
            mdf2 = pd.merge_asof(mdf1, Buy1CE2 , on='datetime')
            mdf3 = pd.merge_asof(mdf2, Buy1PE2 , on='datetime')
            CEPEdf = pd.merge_asof(mdf3, data , on='datetime')
            CEPEdf.set_index('datetime', inplace=True)
        except FileNotFoundError:
            print(f'Data is not available in either PE or CE at Data Preprocessing for {tdayTime}')
            continue

        CEPEdf.columns = [f'open{SELLCEActiveContract}', f'high{SELLCEActiveContract}', f'low{SELLCEActiveContract}', f'close{SELLCEActiveContract}',\
            f'open{SELLPEActiveContract}', f'high{SELLPEActiveContract}', f'low{SELLPEActiveContract}', f'close{SELLPEActiveContract}',\
                f'open{FirstBuyCEActiveContract}', f'high{FirstBuyCEActiveContract}',f'low{FirstBuyCEActiveContract}', f'close{FirstBuyCEActiveContract}',\
                    f'open{FirstBuyPEActiveContract}', f'high{FirstBuyPEActiveContract}',f'low{FirstBuyPEActiveContract}', f'close{FirstBuyPEActiveContract}',\
                                'openSpot', 'highSpot' , 'lowSpot' , 'closeSpot' , 'volumeSpot']
        
        
        
        
        # Code To SKip the Baskets where there is Nan Data
        try:
            sample1 = CEPEdf.dropna().loc[tdayTime:]
            if (sample1.index[0] - tdayTime).total_seconds() >= 60 * 60 * 3:
                raise Exception
        except Exception as e:
            print(f'Data is not available in either PE or CE  for {tdayTime}')
            print(f'First Data Available : {CEPEdf.dropna().loc[tdayTime:].index[:5]}')
            print(f'Last Data Available : {CEPEdf.dropna().loc[tdayTime:].index[-5:]}')
            break
            continue
        
        #break
            
        CEPEdf = CEPEdf.loc[tdayTime:]
        CEPEdf = CEPEdf.dropna()
        
        
        
        SELLCEEntryPrice = CEPEdf.iloc[0][f'open{SELLCEActiveContract}']
        SELLPEEntryPrice = CEPEdf.iloc[0][f'open{SELLPEActiveContract}']
        
        Buy1CEEntryPrice = CEPEdf.iloc[0][f'open{FirstBuyCEActiveContract}']
        Buy1PEEntryPrice = CEPEdf.iloc[0][f'open{FirstBuyPEActiveContract}']
        
    
        
        CEEntryTime = CEPEdf.index[0]
        PEEntryTime = CEPEdf.index[0]
        
  
    
        Target = 2500
 
        print(f'Entry at {CEEntryTime} at a SP of {CMP}')
        print(f'Enter First Sell Series CE Contract : {SELLCEActiveContract} Price : {SELLCEEntryPrice} . PE Contract : {SELLPEActiveContract} Price : {SELLPEEntryPrice}')
        print(f'Enter First Buy Series CE Contract : {FirstBuyCEActiveContract} Price : {Buy1CEEntryPrice} . PE Contract : {FirstBuyPEActiveContract} Price : {Buy1PEEntryPrice}')
        
        j = 0
        c = 0
        flagCE = 'NA'
        flagPE = 'NA'
        flag = 0
        
        #break
        while True and j <= len(CEPEdf) -1 :
            
            
            # get The Total Sum Price of all the Open Positions
            SellPnl = 25 * ((SELLCEEntryPrice - CEPEdf.iloc[j][f'close{SELLCEActiveContract}']) + (SELLPEEntryPrice - CEPEdf.iloc[j][f'close{SELLPEActiveContract}']))
            BuyFirstPnl = 25 * ((CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'] - Buy1CEEntryPrice) + (CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'] - Buy1PEEntryPrice) )
            TotalPnl = SellPnl + BuyFirstPnl 
            
            if flag == 1:
                TotalPrice = CEPEdf.iloc[j][f'close{SELLCEActiveContract}'] + CEPEdf.iloc[j][f'close{SELLPEActiveContract}']
                
                if TotalPrice > StopLoss:
                
                    print(f'StopLoss Hit at {CEPEdf.index[j]} .Closed Sell CE Contract : {SELLCEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLCEActiveContract}"]} .Closed Sell PE Contract : {SELLPEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLPEActiveContract}"]}')
                    print(f'Closed Buy CE Contract : {FirstBuyCEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyCEActiveContract}"]} .Closed Buy PE Contract : {FirstBuyPEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyPEActiveContract}"]} \n\n\n\n')
                    
                    # Exit FIrst SELL CE Order
                    try:
                        ddCt = SELLPEEntryPrice - max(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                    except ValueError:
                        ddCt = 0
                    Orders.loc[len(Orders)] = [-1 ,  SELLCEActiveContract,  CEEntryTime, CEPEdf.index[j] ,SELLCEEntryPrice ,CEPEdf.iloc[j][f'close{SELLCEActiveContract}'], 'SL', CMP, ddCt , OrderBasketID, SELLCEActiveContract ,1]
                    
                    # Exit First SELL PE Order
                    try:
                        ddCt = SELLPEEntryPrice - max(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                    except ValueError:
                        ddCt = 0
                    Orders.loc[len(Orders)] = [-1 ,  SELLPEActiveContract,  PEEntryTime, CEPEdf.index[j] ,SELLPEEntryPrice ,CEPEdf.iloc[j][f'close{SELLPEActiveContract}'], 'SL', CMP, ddCt , OrderBasketID, SELLPEActiveContract,1 ]
                    
        
                    
                    # Exit FirstBuy CE Order
                    try:
                        ddCt = min(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'low{FirstBuyCEActiveContract}']) - Buy1CEEntryPrice
                    except ValueError:
                        ddCt = 0
                    Orders.loc[len(Orders)] = [1 ,  FirstBuyCEActiveContract,  CEEntryTime, CEPEdf.index[j] ,Buy1CEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'], 'SL', CMP, ddCt , OrderBasketID, FirstBuyCEActiveContract ,1]
                    
                    
                    # Exit FirstBuy PE Order
                    try:
                        ddCt = min(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'low{FirstBuyPEActiveContract}']) - Buy1PEEntryPrice
                    except ValueError:
                        ddCt = 0
                    Orders.loc[len(Orders)] = [1 ,  FirstBuyPEActiveContract,  PEEntryTime, CEPEdf.index[j] ,Buy1PEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'], 'SL', CMP, ddCt , OrderBasketID, FirstBuyPEActiveContract , 1]
                    
            
                    break
            
            
            
            ## CE Adjustment
            if flag == 0 and (0.5 * CEPEdf.iloc[j][f'close{SELLPEActiveContract}']) >= CEPEdf.iloc[j][f'close{SELLCEActiveContract}']:
                AdjustedSELLPrice = 0.8 * CEPEdf.iloc[j][f'close{SELLPEActiveContract}']
                
                AdjustmentTime = CEPEdf.index[j]
                print(f'Adjustment of CE at {AdjustmentTime}')
                
                 # Updating the Orders Data frame
                 
                # Sell Order
                try:
                    ddCE = (SELLCEEntryPrice - max(CEPEdf.loc[CEEntryTime : AdjustmentTime][f'high{SELLCEActiveContract}']))
                except ValueError:
                    ddCE = 0
                # ['entry', 'type', 'entry_time', 'exittime','entry_value', 'exitvalue', 'exit_type', 'SP', 'dd', 'BasketID','ContractName','LS']
                Orders.loc[len(Orders)] = [-1, 'CE', CEEntryTime, AdjustmentTime,SELLCEEntryPrice ,CEPEdf.iloc[j][f'close{SELLCEActiveContract}'], 'Adj', CMP, ddCE, OrderBasketID ,SELLCEActiveContract , 1 ]
                
                # Buy Order
                try:
                    ddCE = (min(CEPEdf.loc[CEEntryTime : AdjustmentTime][f'low{FirstBuyCEActiveContract}']) - Buy1CEEntryPrice)
                except ValueError:
                    ddCE = 0
                Orders.loc[len(Orders)] = [1, 'CE', CEEntryTime, AdjustmentTime,Buy1CEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'], 'Adj', 'UP', ddCE, OrderBasketID, FirstBuyCEActiveContract, 1]
                print(f"Exited SELL Contract : {SELLCEActiveContract} at Price : {CEPEdf.iloc[j][f'close{SELLCEActiveContract}']} and NEW BUY Contract : {FirstBuyCEActiveContract} and Price : {CEPEdf.iloc[j][f'close{SELLCEActiveContract}']}")
                
                
                
                
                NewSELLCEActiveContract , NewSELLCEActiveContractPrice = getContractBySP_backfilled(AdjustedSELLPrice , AdjustmentTime , StrExpiry , 'CE' , path , LastThrus)
                AdjustedBUYPrice = 1/3 * NewSELLCEActiveContractPrice
                NewFirstBuyCEActiveContract , NewFirstBuyCEActiveContractPrice= getContractBySP_backfilled(AdjustedBUYPrice , AdjustmentTime , StrExpiry , 'CE' , path , LastThrus)
                
                
                NewSELLCEdf = data_clean_backfilled(pd.read_csv(f'{path}\{NewSELLCEActiveContract}.csv'))
                NewSELLCEdf = NewSELLCEdf.drop(['volume','interest'] , axis =1)
                NewBuyCEdf = data_clean_backfilled(pd.read_csv(f'{path}\{NewFirstBuyCEActiveContract}.csv'))
                NewBuyCEdf = NewBuyCEdf.drop(['volume','interest'] , axis =1)
                
                NewColumns = ['datetime'] + list(CEPEdf.columns) + [f'open{NewSELLCEActiveContract}', f'high{NewSELLCEActiveContract}', f'low{NewSELLCEActiveContract}', f'close{NewSELLCEActiveContract}',\
                f'open{NewFirstBuyCEActiveContract}', f'high{NewFirstBuyCEActiveContract}',f'low{NewFirstBuyCEActiveContract}', f'close{NewFirstBuyCEActiveContract}']
                mdf1 = pd.merge_asof(CEPEdf, NewSELLCEdf, on='datetime')
                CEPEdf = pd.merge_asof(mdf1, NewBuyCEdf, on='datetime')
                CEPEdf.columns = NewColumns
                CEPEdf.set_index('datetime' , inplace=True)
                CEPEdf = CEPEdf.loc[:,~CEPEdf.columns.duplicated()]
                
                CEPEdf = CEPEdf.loc[AdjustmentTime:]
                j = 0
                
                SELLCEActiveContract = NewSELLCEActiveContract
                FirstBuyCEActiveContract = NewFirstBuyCEActiveContract
                SELLCEEntryPrice = CEPEdf.iloc[j][f'open{SELLCEActiveContract}']
                Buy1CEEntryPrice = CEPEdf.iloc[j][f'open{FirstBuyCEActiveContract}']
                print(f'Entered New SELL Contract : {SELLCEActiveContract} at Price : {SELLCEEntryPrice} and NEW BUY Contract : {FirstBuyCEActiveContract} and Price : {Buy1CEEntryPrice}')
                
                
                ## Stoploss Activation Condition:
                if (int(SELLPEActiveContract[9:14]) - int(SELLCEActiveContract[9:14])) >= -100:
                    StopLoss = (SELLCEEntryPrice + CEPEdf.iloc[j][f'open{SELLPEActiveContract}']) * 1.1
                    print(f'Stoploss Created at {CEPEdf.index[j]}')
                    
                    flag = 1
                
            
                CEEntryTime = AdjustmentTime
            
            
            
            ## PE Adjustment
            elif flag == 0 and (0.5 * CEPEdf.iloc[j][f'close{SELLCEActiveContract}']) >= CEPEdf.iloc[j][f'close{SELLPEActiveContract}']:
                AdjustedSELLPrice = 0.8 * CEPEdf.iloc[j][f'close{SELLCEActiveContract}']
                
                AdjustmentTime = CEPEdf.index[j]
                print(f'Adjustment of CE at {AdjustmentTime}')
                
                 # Updating the Orders Data frame
                 
                # Sell Order
                try:
                    ddCE = (SELLPEEntryPrice - max(CEPEdf.loc[PEEntryTime : AdjustmentTime][f'high{SELLPEActiveContract}']))
                except ValueError:
                    ddCE = 0
                Orders.loc[len(Orders)] = [-1, 'PE', PEEntryTime, AdjustmentTime,SELLPEEntryPrice ,CEPEdf.iloc[j][f'close{SELLPEActiveContract}'], 'Adj', CMP, ddCE, OrderBasketID ,SELLPEActiveContract , 1 ]
                
                # Buy Order
                try:
                    ddCE = (min(CEPEdf.loc[PEEntryTime : AdjustmentTime][f'low{FirstBuyPEActiveContract}']) - Buy1PEEntryPrice)
                except ValueError:
                    ddCE = 0
                Orders.loc[len(Orders)] = [1, 'PE', PEEntryTime, AdjustmentTime,Buy1PEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'], 'Adj', 'UP', ddCE, OrderBasketID, FirstBuyPEActiveContract, 1]
                print(f"Exited SELL Contract : {SELLPEActiveContract} at Price : {CEPEdf.iloc[j][f'close{SELLPEActiveContract}']} and NEW BUY Contract : {FirstBuyPEActiveContract} and Price : {CEPEdf.iloc[j][f'close{SELLPEActiveContract}']}")
                
                
                
                NewSELLPEActiveContract , NewSELLPEActiveContractPrice = getContractBySP_backfilled(AdjustedSELLPrice , AdjustmentTime , StrExpiry , 'PE' , path , LastThrus)
                AdjustedBUYPrice = 1/3 * NewSELLPEActiveContractPrice
                NewFirstBuyPEActiveContract , NewFirstBuyPEActiveContractPrice= getContractBySP_backfilled(AdjustedBUYPrice , AdjustmentTime , StrExpiry , 'PE' , path , LastThrus)
                
                
                NewSELLPEdf = data_clean_backfilled(pd.read_csv(f'{path}\{NewSELLPEActiveContract}.csv'))
                NewSELLPEdf = NewSELLPEdf.drop(['volume','interest'] , axis =1)
                NewBuyPEdf = data_clean_backfilled(pd.read_csv(f'{path}\{NewFirstBuyPEActiveContract}.csv'))
                NewBuyPEdf = NewBuyPEdf.drop(['volume','interest'] , axis =1)
                
                NewColumns = ['datetime'] + list(CEPEdf.columns) + [f'open{NewSELLPEActiveContract}', f'high{NewSELLPEActiveContract}', f'low{NewSELLPEActiveContract}', f'close{NewSELLPEActiveContract}',\
                f'open{NewFirstBuyPEActiveContract}', f'high{NewFirstBuyPEActiveContract}',f'low{NewFirstBuyPEActiveContract}', f'close{NewFirstBuyPEActiveContract}']
                mdf1 = pd.merge_asof(CEPEdf, NewSELLPEdf, on='datetime')
                CEPEdf = pd.merge_asof(mdf1, NewBuyPEdf, on='datetime')
                CEPEdf.columns = NewColumns
                CEPEdf.set_index('datetime' , inplace=True)
                CEPEdf = CEPEdf.loc[:,~CEPEdf.columns.duplicated()]
                
                CEPEdf = CEPEdf.loc[AdjustmentTime:]
                j = 0
                
                SELLPEActiveContract = NewSELLPEActiveContract
                FirstBuyPEActiveContract = NewFirstBuyPEActiveContract
                SELLPEEntryPrice = CEPEdf.iloc[j][f'open{SELLPEActiveContract}']
                Buy1PEEntryPrice = CEPEdf.iloc[j][f'open{FirstBuyPEActiveContract}']
                print(f'Entered New SELL Contract : {SELLPEActiveContract} at Price : {SELLPEEntryPrice} and NEW BUY Contract : {FirstBuyPEActiveContract} and Price : {Buy1PEEntryPrice}')
                
                
                ## Stoploss Activation Condition:
                if (int(SELLPEActiveContract[9:14]) - int(SELLCEActiveContract[9:14])) >= -100:
                    StopLoss = (SELLCEEntryPrice + CEPEdf.iloc[j][f'open{SELLPEActiveContract}']) * 1.1
                    print(f'Stoploss Created at {CEPEdf.index[j]}')                    
                    flag = 1


                PEEntryTime = AdjustmentTime
            
            
            
            # BreakPoint Above Exit Condition
            if TotalPnl >= Target:
                
                print(f'Target Hit at {CEPEdf.index[j]} .Closed Sell CE Contract : {SELLCEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLCEActiveContract}"]} .Closed Sell PE Contract : {SELLPEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLPEActiveContract}"]}')
                print(f'Closed Buy CE Contract : {FirstBuyCEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyCEActiveContract}"]} .Closed Buy PE Contract : {FirstBuyPEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyPEActiveContract}"]} \n\n\n\n')
                
                # Exit FIrst SELL CE Order
                try:
                    ddCt = SELLPEEntryPrice - max(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [-1 ,  SELLCEActiveContract,  CEEntryTime, CEPEdf.index[j] ,SELLCEEntryPrice ,CEPEdf.iloc[j][f'close{SELLCEActiveContract}'], 'BAExit', CMP, ddCt , OrderBasketID, SELLCEActiveContract ,1]
                
                # Exit First SELL PE Order
                try:
                    ddCt = SELLPEEntryPrice - max(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [-1 ,  SELLPEActiveContract,  PEEntryTime, CEPEdf.index[j] ,SELLPEEntryPrice ,CEPEdf.iloc[j][f'close{SELLPEActiveContract}'], 'BAExit', CMP, ddCt , OrderBasketID, SELLPEActiveContract,1 ]
                
    
                
                # Exit FirstBuy CE Order
                try:
                    ddCt = min(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'low{FirstBuyCEActiveContract}']) - Buy1CEEntryPrice
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [1 ,  FirstBuyCEActiveContract,  CEEntryTime, CEPEdf.index[j] ,Buy1CEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'], 'BAExit', CMP, ddCt , OrderBasketID, FirstBuyCEActiveContract ,1]
                
                
                # Exit FirstBuy PE Order
                try:
                    ddCt = min(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'low{FirstBuyPEActiveContract}']) - Buy1PEEntryPrice
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [1 ,  FirstBuyPEActiveContract,  PEEntryTime, CEPEdf.index[j] ,Buy1PEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'], 'BAExit', CMP, ddCt , OrderBasketID, FirstBuyPEActiveContract , 1]
                
           
                break
            
            
        
            
    
       
            
          
            
            
            # Expiry Exit Condition
            if CEPEdf.index[j] >= NextExpiry:
                print(f'Expiry Exit at {CEPEdf.index[j]} .Closed Sell CE Contract : {SELLCEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLCEActiveContract}"]} .Closed Sell PE Contract : {SELLPEActiveContract} at Price {CEPEdf.iloc[j][f"close{SELLPEActiveContract}"]}')
                print(f'Closed Buy CE Contract : {FirstBuyCEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyCEActiveContract}"]} .Closed Buy PE Contract : {FirstBuyPEActiveContract} at Price {CEPEdf.iloc[j][f"close{FirstBuyPEActiveContract}"]} \n\n\n\n')
                
                # Exit FIrst SELL CE Order
                # Exit FIrst SELL CE Order
                try:
                    ddCt = SELLPEEntryPrice - max(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [-1 ,  SELLCEActiveContract,  CEEntryTime, CEPEdf.index[j] ,SELLCEEntryPrice ,CEPEdf.iloc[j][f'close{SELLCEActiveContract}'], 'Exp', CMP, ddCt , OrderBasketID, SELLCEActiveContract ,1]
                
                # Exit First SELL PE Order
                try:
                    ddCt = SELLPEEntryPrice - max(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'high{SELLPEActiveContract}']) 
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [-1 ,  SELLPEActiveContract,  PEEntryTime, CEPEdf.index[j] ,SELLPEEntryPrice ,CEPEdf.iloc[j][f'close{SELLPEActiveContract}'], 'Exp', CMP, ddCt , OrderBasketID, SELLPEActiveContract,1 ]
                
               
                
                # Exit FirstBuy CE Order
                try:
                    ddCt = min(CEPEdf.loc[CEEntryTime : CEPEdf.index[j]][f'low{FirstBuyCEActiveContract}']) - Buy1CEEntryPrice
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [1 ,  FirstBuyCEActiveContract,  CEEntryTime, CEPEdf.index[j] ,Buy1CEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyCEActiveContract}'], 'Exp', CMP, ddCt , OrderBasketID, FirstBuyCEActiveContract ,1]
                
                
                # Exit FirstBuy PE Order
                try:
                    ddCt = min(CEPEdf.loc[PEEntryTime : CEPEdf.index[j]][f'low{FirstBuyPEActiveContract}']) - Buy1PEEntryPrice
                except ValueError:
                    ddCt = 0
                Orders.loc[len(Orders)] = [1 ,  FirstBuyPEActiveContract,  PEEntryTime, CEPEdf.index[j] ,Buy1PEEntryPrice ,CEPEdf.iloc[j][f'close{FirstBuyPEActiveContract}'], 'Exp', CMP, ddCt , OrderBasketID, FirstBuyPEActiveContract , 1]
              
               
                break
               
            
            
        
        

    
            j+=1
                
        # Break For 1 Trade
        #break
# Out:
# 2020-01-02 10:00:00
# 09JAN20
# False
# BANKNIFTY3250009JAN20CE
# Entry at 2020-01-02 10:00:00 at a SP of 32200
# Enter First Sell Series CE Contract : BANKNIFTY3250009JAN20CE Price : 108.55 . PE Contract : BANKNIFTY3190009JAN20PE Price : 94.9
# Enter First Buy Series CE Contract : BANKNIFTY3290009JAN20CE Price : 28.8 . PE Contract : BANKNIFTY3150009JAN20PE Price : 30.5
# Adjustment of CE at 2020-01-02 12:14:00
# Exited SELL Contract : BANKNIFTY3190009JAN20PE at Price : 71.85 and NEW BUY Contract : BANKNIFTY3150009JAN20PE and Price : 71.85
# Entered New SELL Contract : BANKNIFTY3210009JAN20PE at Price : 126.75 and NEW BUY Contract : BANKNIFTY3170009JAN20PE and Price : 42.2
# Adjustment of CE at 2020-01-02 14:23:00
# Exited SELL Contract : BANKNIFTY3210009JAN20PE at Price : 92.9 and NEW BUY Contract : BANKNIFTY3170009JAN20PE and Price : 92.9
# Entered New SELL Contract : BANKNIFTY3230009JAN20PE at Price : 159.4 and NEW BUY Contract : BANKNIFTY3190009JAN20PE and Price : 56.4
# Adjustment of CE at 2020-01-03 09:30:00
# Exited SELL Contract : BANKNIFTY3250009JAN20CE at Price : 119.0 and NEW BUY Contract : BANKNIFTY3290009JAN20CE and Price : 119.0
# Entered New SELL Contract : BANKNIFTY3230009JAN20CE at Price : 216.6 and NEW BUY Contract : BANKNIFTY3270009JAN20CE and Price : 74.65
# Stoploss Created at 2020-01-03 09:30:00
# StopLoss Hit at 2020-01-03 11:10:00 .Closed Sell CE Contract : BANKNIFTY3230009JAN20CE at Price 162.95 .Closed Sell PE Contract : BANKNIFTY3230009JAN20PE at Price 343.0
# Closed Buy CE Contract : BANKNIFTY3270009JAN20CE at Price 51.05 .Closed Buy PE Contract : BANKNIFTY3190009JAN20PE at Price 154.95
#
#
#
#
# 2020-01-09 10:00:00
# 16JAN20
# False
# BANKNIFTY3240016JAN20CE
# Entry at 2020-01-09 10:00:00 at a SP of 31800
# Enter First Sell Series CE Contract : BANKNIFTY3240016JAN20CE Price : 86.5 . PE Contract : BANKNIFTY3110016JAN20PE Price : 97.85
# Enter First Buy Series CE Contract : BANKNIFTY3280016JAN20CE Price : 32.0 . PE Contract : BANKNIFTY3030016JAN20PE Price : 35.0
# Adjustment of CE at 2020-01-09 12:00:00
# Exited SELL Contract : BANKNIFTY3110016JAN20PE at Price : 65.15 and NEW BUY Contract : BANKNIFTY3030016JAN20PE and Price : 65.15
# Entered New SELL Contract : BANKNIFTY3140016JAN20PE at Price : 105.5 and NEW BUY Contract : BANKNIFTY3070016JAN20PE and Price : 37.15
# Adjustment of CE at 2020-01-09 13:27:00
# Exited SELL Contract : BANKNIFTY3140016JAN20PE at Price : 86.55 and NEW BUY Contract : BANKNIFTY3070016JAN20PE and Price : 86.55
# Entered New SELL Contract : BANKNIFTY3170016JAN20PE at Price : 147.0 and NEW BUY Contract : BANKNIFTY3100016JAN20PE and Price : 49.35
# Adjustment of CE at 2020-01-10 10:28:00
# Exited SELL Contract : BANKNIFTY3170016JAN20PE at Price : 97.65 and NEW BUY Contract : BANKNIFTY3100016JAN20PE and Price : 97.65
# Entered New SELL Contract : BANKNIFTY3200016JAN20PE at Price : 184.45 and NEW BUY Contract : BANKNIFTY3140016JAN20PE and Price : 57.25
# Adjustment of CE at 2020-01-10 14:07:00
# Exited SELL Contract : BANKNIFTY3240016JAN20CE at Price : 123.1 and NEW BUY Contract : BANKNIFTY3280016JAN20CE and Price : 123.1
# Entered New SELL Contract : BANKNIFTY3210016JAN20CE at Price : 245.0 and NEW BUY Contract : BANKNIFTY3260016JAN20CE and Price : 81.55
# Stoploss Created at 2020-01-10 14:07:00
# Target Hit at 2020-01-16 09:15:00 .Closed Sell CE Contract : BANKNIFTY3210016JAN20CE at Price 25.0 .Closed Sell PE Contract : BANKNIFTY3200016JAN20PE at Price 155.7
# Closed Buy CE Contract : BANKNIFTY3260016JAN20CE at Price 1.5 .Closed Buy PE Contract : BANKNIFTY3140016JAN20PE at Price 2.7
#
#
#
#
# 2020-01-16 10:00:00
# 23JAN20
# False
# BANKNIFTY3240023JAN20CE
# Entry at 2020-01-16 10:00:00 at a SP of 31900
# Enter First Sell Series CE Contract : BANKNIFTY3240023JAN20CE Price : 114.5 . PE Contract : BANKNIFTY3140023JAN20PE Price : 90.95
# Enter First Buy Series CE Contract : BANKNIFTY3280023JAN20CE Price : 40.05 . PE Contract : BANKNIFTY3090023JAN20PE Price : 33.5
# Adjustment of CE at 2020-01-16 11:00:00
# Exited SELL Contract : BANKNIFTY3240023JAN20CE at Price : 73.0 and NEW BUY Contract : BANKNIFTY3280023JAN20CE and Price : 73.0
# Entered New SELL Contract : BANKNIFTY3220023JAN20CE at Price : 126.3 and NEW BUY Contract : BANKNIFTY3260023JAN20CE and Price : 43.35
# Adjustment of CE at 2020-01-16 13:58:00
# Exited SELL Contract : BANKNIFTY3140023JAN20PE at Price : 76.65 and NEW BUY Contract : BANKNIFTY3090023JAN20PE and Price : 76.65
# Entered New SELL Contract : BANKNIFTY3160023JAN20PE at Price : 126.85 and NEW BUY Contract : BANKNIFTY3110023JAN20PE and Price : 43.05
# Adjustment of CE at 2020-01-17 09:15:00
# Exited SELL Contract : BANKNIFTY3220023JAN20CE at Price : 64.35 and NEW BUY Contract : BANKNIFTY3260023JAN20CE and Price : 64.35
# Entered New SELL Contract : BANKNIFTY3170023JAN20CE at Price : 230.0 and NEW BUY Contract : BANKNIFTY3220023JAN20CE and Price : 70.05
# Stoploss Created at 2020-01-17 09:15:00
# StopLoss Hit at 2020-01-20 14:24:00 .Closed Sell CE Contract : BANKNIFTY3170023JAN20CE at Price 71.0 .Closed Sell PE Contract : BANKNIFTY3160023JAN20PE at Price 505.4
# Closed Buy CE Contract : BANKNIFTY3220023JAN20CE at Price 19.45 .Closed Buy PE Contract : BANKNIFTY3110023JAN20PE at Price 193.55
#
#
#
#
# 2020-01-23 10:00:00
# JAN20
# True
# BANKNIFTY31500JAN20CE
# Entry at 2020-01-23 10:00:00 at a SP of 30900
# Enter First Sell Series CE Contract : BANKNIFTY31500JAN20CE Price : 91.0 . PE Contract : BANKNIFTY30300JAN20PE Price : 94.85
# Enter First Buy Series CE Contract : BANKNIFTY32000JAN20CE Price : 34.7 . PE Contract : BANKNIFTY29800JAN20PE Price : 35.35
# Adjustment of CE at 2020-01-23 13:00:00
# Exited SELL Contract : BANKNIFTY30300JAN20PE at Price : 61.35 and NEW BUY Contract : BANKNIFTY29800JAN20PE and Price : 61.35
# Entered New SELL Contract : BANKNIFTY30600JAN20PE at Price : 113.75 and NEW BUY Contract : BANKNIFTY30000JAN20PE and Price : 36.55
# Adjustment of CE at 2020-01-24 10:11:00
# Exited SELL Contract : BANKNIFTY30600JAN20PE at Price : 71.85 and NEW BUY Contract : BANKNIFTY30000JAN20PE and Price : 71.85
# Entered New SELL Contract : BANKNIFTY30800JAN20PE at Price : 123.05 and NEW BUY Contract : BANKNIFTY30300JAN20PE and Price : 39.75
# Adjustment of CE at 2020-01-24 10:42:00
# Exited SELL Contract : BANKNIFTY30800JAN20PE at Price : 87.25 and NEW BUY Contract : BANKNIFTY30300JAN20PE and Price : 87.25
# Entered New SELL Contract : BANKNIFTY31100JAN20PE at Price : 171.2 and NEW BUY Contract : BANKNIFTY30600JAN20PE and Price : 61.95
# Adjustment of CE at 2020-01-27 09:15:00
# Exited SELL Contract : BANKNIFTY31500JAN20CE at Price : 84.0 and NEW BUY Contract : BANKNIFTY32000JAN20CE and Price : 84.0
# Entered New SELL Contract : BANKNIFTY31200JAN20CE at Price : 199.95 and NEW BUY Contract : BANKNIFTY31600JAN20CE and Price : 94.0
# Stoploss Created at 2020-01-27 09:15:00
# Expiry Exit at 2020-01-30 10:00:00 .Closed Sell CE Contract : BANKNIFTY31200JAN20CE at Price 3.35 .Closed Sell PE Contract : BANKNIFTY31100JAN20PE at Price 383.65
# Closed Buy CE Contract : BANKNIFTY31600JAN20CE at Price 0.65 .Closed Buy PE Contract : BANKNIFTY30600JAN20PE at Price 42.8
#
#
#
#
# 2020-01-30 10:00:00
# 06FEB20
# False
# BANKNIFTY3200006FEB20CE
# Entry at 2020-01-30 10:00:00 at a SP of 30700
# Enter First Sell Series CE Contract : BANKNIFTY3200006FEB20CE Price : 94.0 . PE Contract : BANKNIFTY2960006FEB20PE Price : 107.1
# Enter First Buy Series CE Contract : BANKNIFTY3270006FEB20CE Price : 30.0 . PE Contract : BANKNIFTY2900006FEB20PE Price : 43.3
# Adjustment of CE at 2020-02-01 13:18:00
# Exited SELL Contract : BANKNIFTY3200006FEB20CE at Price : 63.15 and NEW BUY Contract : BANKNIFTY3270006FEB20CE and Price : 63.15
# Entered New SELL Contract : BANKNIFTY3160006FEB20CE at Price : 118.7 and NEW BUY Contract : BANKNIFTY3240006FEB20CE and Price : 40.8
# Adjustment of CE at 2020-02-01 13:27:00
# Exited SELL Contract : BANKNIFTY3160006FEB20CE at Price : 60.05 and NEW BUY Contract : BANKNIFTY3240006FEB20CE and Price : 60.05
# Entered New SELL Contract : BANKNIFTY3110006FEB20CE at Price : 158.9 and NEW BUY Contract : BANKNIFTY3190006FEB20CE and Price : 52.05
# Adjustment of CE at 2020-02-01 13:43:00
# Exited SELL Contract : BANKNIFTY3110006FEB20CE at Price : 90.6 and NEW BUY Contract : BANKNIFTY3190006FEB20CE and Price : 90.6
# Entered New SELL Contract : BANKNIFTY3070006FEB20CE at Price : 194.4 and NEW BUY Contract : BANKNIFTY3140006FEB20CE and Price : 65.6
# Adjustment of CE at 2020-02-01 14:05:00
# Exited SELL Contract : BANKNIFTY2960006FEB20PE at Price : 113.7 and NEW BUY Contract : BANKNIFTY2900006FEB20PE and Price : 113.7
# Entered New SELL Contract : BANKNIFTY2990006FEB20PE at Price : 210.95 and NEW BUY Contract : BANKNIFTY2930006FEB20PE and Price : 75.0
# Adjustment of CE at 2020-02-01 14:41:00
# Exited SELL Contract : BANKNIFTY3070006FEB20CE at Price : 134.35 and NEW BUY Contract : BANKNIFTY3140006FEB20CE and Price : 134.35
# Entered New SELL Contract : BANKNIFTY3040006FEB20CE at Price : 231.7 and NEW BUY Contract : BANKNIFTY3100006FEB20CE and Price : 83.6
# Adjustment of CE at 2020-02-01 15:00:00
# Exited SELL Contract : BANKNIFTY3040006FEB20CE at Price : 153.05 and NEW BUY Contract : BANKNIFTY3100006FEB20CE and Price : 153.05
# Entered New SELL Contract : BANKNIFTY3000006FEB20CE at Price : 322.3 and NEW BUY Contract : BANKNIFTY3070006FEB20CE and Price : 101.8
# Stoploss Created at 2020-02-01 15:00:00
# StopLoss Hit at 2020-02-04 11:17:00 .Closed Sell CE Contract : BANKNIFTY3000006FEB20CE at Price 726.45 .Closed Sell PE Contract : BANKNIFTY2990006FEB20PE at Price 21.65
# Closed Buy CE Contract : BANKNIFTY3070006FEB20CE at Price 195.0 .Closed Buy PE Contract : BANKNIFTY2930006FEB20PE at Price 8.05
#
#
#
#
# 2020-02-06 10:00:00
# 13FEB20
# False
# BANKNIFTY3160013FEB20CE
# Entry at 2020-02-06 10:00:00 at a SP of 31100
# Enter First Sell Series CE Contract : BANKNIFTY3160013FEB20CE Price : 112.35 . PE Contract : BANKNIFTY3050013FEB20PE Price : 102.15
# Enter First Buy Series CE Contract : BANKNIFTY3200013FEB20CE Price : 44.5 . PE Contract : BANKNIFTY3000013FEB20PE Price : 34.9
# Adjustment of CE at 2020-02-06 11:56:00
# Exited SELL Contract : BANKNIFTY3050013FEB20PE at Price : 73.7 and NEW BUY Contract : BANKNIFTY3000013FEB20PE and Price : 73.7
# Entered New SELL Contract : BANKNIFTY3070013FEB20PE at Price : 115.65 and NEW BUY Contract : BANKNIFTY3020013FEB20PE and Price : 40.2
# Adjustment of CE at 2020-02-06 12:41:00
# Exited SELL Contract : BANKNIFTY3070013FEB20PE at Price : 87.15 and NEW BUY Contract : BANKNIFTY3020013FEB20PE and Price : 87.15
# Entered New SELL Contract : BANKNIFTY3090013FEB20PE at Price : 136.0 and NEW BUY Contract : BANKNIFTY3040013FEB20PE and Price : 49.8
# Adjustment of CE at 2020-02-06 13:21:00
# Exited SELL Contract : BANKNIFTY3090013FEB20PE at Price : 102.15 and NEW BUY Contract : BANKNIFTY3040013FEB20PE and Price : 102.15
# Entered New SELL Contract : BANKNIFTY3110013FEB20PE at Price : 156.65 and NEW BUY Contract : BANKNIFTY3050013FEB20PE and Price : 47.2
# Adjustment of CE at 2020-02-07 09:15:00
# Exited SELL Contract : BANKNIFTY3160013FEB20CE at Price : 117.35 and NEW BUY Contract : BANKNIFTY3200013FEB20CE and Price : 117.35
# Entered New SELL Contract : BANKNIFTY3130013FEB20CE at Price : 284.95 and NEW BUY Contract : BANKNIFTY3180013FEB20CE and Price : 83.05
# Adjustment of CE at 2020-02-10 09:22:00
# Exited SELL Contract : BANKNIFTY3130013FEB20CE at Price : 116.45 and NEW BUY Contract : BANKNIFTY3180013FEB20CE and Price : 116.45
# Entered New SELL Contract : BANKNIFTY3110013FEB20CE at Price : 211.4 and NEW BUY Contract : BANKNIFTY3150013FEB20CE and Price : 72.0
# Stoploss Created at 2020-02-10 09:22:00
# Expiry Exit at 2020-02-13 10:00:00 .Closed Sell CE Contract : BANKNIFTY3110013FEB20CE at Price 210.25 .Closed Sell PE Contract : BANKNIFTY3110013FEB20PE at Price 15.75
# Closed Buy CE Contract : BANKNIFTY3150013FEB20CE at Price 15.2 .Closed Buy PE Contract : BANKNIFTY3050013FEB20PE at Price 0.7
#
#
#
#
# 2020-02-13 10:00:00
# 20FEB20
# False
# BANKNIFTY3170020FEB20CE
# Entry at 2020-02-13 10:00:00 at a SP of 31300
# Enter First Sell Series CE Contract : BANKNIFTY3170020FEB20CE Price : 108.45 . PE Contract : BANKNIFTY3080020FEB20PE Price : 85.8
# Enter First Buy Series CE Contract : BANKNIFTY3210020FEB20CE Price : 33.75 . PE Contract : BANKNIFTY3030020FEB20PE Price : 28.0
# Adjustment of CE at 2020-02-14 09:20:00
# Exited SELL Contract : BANKNIFTY3080020FEB20PE at Price : 54.05 and NEW BUY Contract : BANKNIFTY3030020FEB20PE and Price : 54.05
# Entered New SELL Contract : BANKNIFTY3100020FEB20PE at Price : 98.05 and NEW BUY Contract : BANKNIFTY3060020FEB20PE and Price : 33.65
# Adjustment of CE at 2020-02-14 10:50:00
# Exited SELL Contract : BANKNIFTY3170020FEB20CE at Price : 70.05 and NEW BUY Contract : BANKNIFTY3210020FEB20CE and Price : 70.05
# Entered New SELL Contract : BANKNIFTY3150020FEB20CE at Price : 124.95 and NEW BUY Contract : BANKNIFTY3190020FEB20CE and Price : 36.7
# Adjustment of CE at 2020-02-14 10:52:00
# Exited SELL Contract : BANKNIFTY3150020FEB20CE at Price : 97.05 and NEW BUY Contract : BANKNIFTY3190020FEB20CE and Price : 97.05
# Entered New SELL Contract : BANKNIFTY3130020FEB20CE at Price : 172.2 and NEW BUY Contract : BANKNIFTY3170020FEB20CE and Price : 58.15
# Adjustment of CE at 2020-02-14 10:55:00
# Exited SELL Contract : BANKNIFTY3130020FEB20CE at Price : 92.15 and NEW BUY Contract : BANKNIFTY3170020FEB20CE and Price : 92.15
# Entered New SELL Contract : BANKNIFTY3090020FEB20CE at Price : 337.25 and NEW BUY Contract : BANKNIFTY3130020FEB20CE and Price : 142.2
# Stoploss Created at 2020-02-14 10:55:00
# StopLoss Hit at 2020-02-18 09:30:00 .Closed Sell CE Contract : BANKNIFTY3090020FEB20CE at Price 58.75 .Closed Sell PE Contract : BANKNIFTY3100020FEB20PE at Price 560.15
# Closed Buy CE Contract : BANKNIFTY3130020FEB20CE at Price 19.75 .Closed Buy PE Contract : BANKNIFTY3060020FEB20PE at Price 256.2
#
#
#
#
# 2020-02-20 10:00:00
# FEB20
# True
# BANKNIFTY31300FEB20CE
# Entry at 2020-02-20 10:00:00 at a SP of 30900
# Enter First Sell Series CE Contract : BANKNIFTY31300FEB20CE Price : 95.65 . PE Contract : BANKNIFTY30400FEB20PE Price : 102.05
# Enter First Buy Series CE Contract : BANKNIFTY31700FEB20CE Price : 35.7 . PE Contract : BANKNIFTY29800FEB20PE Price : 28.8
# Adjustment of CE at 2020-02-20 11:13:00
# Exited SELL Contract : BANKNIFTY30400FEB20PE at Price : 64.1 and NEW BUY Contract : BANKNIFTY29800FEB20PE and Price : 64.1
# Entered New SELL Contract : BANKNIFTY30600FEB20PE at Price : 102.6 and NEW BUY Contract : BANKNIFTY30000FEB20PE and Price : 31.0
# Adjustment of CE at 2020-02-24 09:15:00
# Exited SELL Contract : BANKNIFTY31300FEB20CE at Price : 23.0 and NEW BUY Contract : BANKNIFTY31700FEB20CE and Price : 23.0
# Entered New SELL Contract : BANKNIFTY30500FEB20CE at Price : 400.0 and NEW BUY Contract : BANKNIFTY30900FEB20CE and Price : 133.05
# Stoploss Created at 2020-02-24 09:15:00
# Expiry Exit at 2020-02-27 10:00:00 .Closed Sell CE Contract : BANKNIFTY30500FEB20CE at Price 4.05 .Closed Sell PE Contract : BANKNIFTY30600FEB20PE at Price 552.8
# Closed Buy CE Contract : BANKNIFTY30900FEB20CE at Price 1.15 .Closed Buy PE Contract : BANKNIFTY30000FEB20PE at Price 80.1
#
#
#
#
# 2020-02-27 10:00:00
# 05MAR20
# False
# BANKNIFTY3080005MAR20CE
# Entry at 2020-02-27 10:00:00 at a SP of 30000
# Enter First Sell Series CE Contract : BANKNIFTY3080005MAR20CE Price : 104.0 . PE Contract : BANKNIFTY2910005MAR20PE Price : 99.95
# Enter First Buy Series CE Contract : BANKNIFTY3130005MAR20CE Price : 34.7 . PE Contract : BANKNIFTY2850005MAR20PE Price : 39.7
# Adjustment of CE at 2020-02-27 15:02:00
# Exited SELL Contract : BANKNIFTY2910005MAR20PE at Price : 52.15 and NEW BUY Contract : BANKNIFTY2850005MAR20PE and Price : 52.15
# Entered New SELL Contract : BANKNIFTY2940005MAR20PE at Price : 89.45 and NEW BUY Contract : BANKNIFTY2870005MAR20PE and Price : 29.0
# Adjustment of CE at 2020-02-28 09:17:00
# Exited SELL Contract : BANKNIFTY3080005MAR20CE at Price : 24.3 and NEW BUY Contract : BANKNIFTY3130005MAR20CE and Price : 24.3
# Entered New SELL Contract : BANKNIFTY2980005MAR20CE at Price : 302.0 and NEW BUY Contract : BANKNIFTY3030005MAR20CE and Price : 95.95
# Adjustment of CE at 2020-02-28 09:56:00
# Exited SELL Contract : BANKNIFTY2980005MAR20CE at Price : 196.0 and NEW BUY Contract : BANKNIFTY3030005MAR20CE and Price : 196.0
# Entered New SELL Contract : BANKNIFTY2950005MAR20CE at Price : 333.45 and NEW BUY Contract : BANKNIFTY3020005MAR20CE and Price : 106.15
# Stoploss Created at 2020-02-28 09:56:00
# StopLoss Hit at 2020-02-28 12:17:00 .Closed Sell CE Contract : BANKNIFTY2950005MAR20CE at Price 283.95 .Closed Sell PE Contract : BANKNIFTY2940005MAR20PE at Price 543.9
# Closed Buy CE Contract : BANKNIFTY3020005MAR20CE at Price 90.25 .Closed Buy PE Contract : BANKNIFTY2870005MAR20PE at Price 252.2
#
#
#
#
# 2020-03-05 10:00:00
# 12MAR20
# False
# BANKNIFTY2960012MAR20CE
# Entry at 2020-03-05 10:00:00 at a SP of 28600
# Enter First Sell Series CE Contract : BANKNIFTY2960012MAR20CE Price : 97.95 . PE Contract : BANKNIFTY2740012MAR20PE Price : 118.75
# Enter First Buy Series CE Contract : BANKNIFTY3020012MAR20CE Price : 34.2 . PE Contract : BANKNIFTY2650012MAR20PE Price : 37.5
# Adjustment of CE at 2020-03-05 10:46:00
# Exited SELL Contract : BANKNIFTY2740012MAR20PE at Price : 70.0 and NEW BUY Contract : BANKNIFTY2650012MAR20PE and Price : 70.0
# Entered New SELL Contract : BANKNIFTY2780012MAR20PE at Price : 120.0 and NEW BUY Contract : BANKNIFTY2670012MAR20PE and Price : 43.0
# Adjustment of CE at 2020-03-05 11:30:00
# Exited SELL Contract : BANKNIFTY2780012MAR20PE at Price : 100.55 and NEW BUY Contract : BANKNIFTY2670012MAR20PE and Price : 100.55
# Entered New SELL Contract : BANKNIFTY2820012MAR20PE at Price : 168.4 and NEW BUY Contract : BANKNIFTY2740012MAR20PE and Price : 58.05
# Adjustment of CE at 2020-03-05 13:50:00
# Exited SELL Contract : BANKNIFTY2960012MAR20CE at Price : 106.85 and NEW BUY Contract : BANKNIFTY3020012MAR20CE and Price : 106.85
# Entered New SELL Contract : BANKNIFTY2930012MAR20CE at Price : 195.35 and NEW BUY Contract : BANKNIFTY2990012MAR20CE and Price : 63.6
# Adjustment of CE at 2020-03-06 09:17:00
# Exited SELL Contract : BANKNIFTY2930012MAR20CE at Price : 2.55 and NEW BUY Contract : BANKNIFTY2990012MAR20CE and Price : 2.55
# Entered New SELL Contract : BANKNIFTY2730012MAR20CE at Price : 350.0 and NEW BUY Contract : BANKNIFTY2940012MAR20CE and Price : 36.6
# Stoploss Created at 2020-03-06 09:17:00
# StopLoss Hit at 2020-03-06 09:23:00 .Closed Sell CE Contract : BANKNIFTY2730012MAR20CE at Price 450.0 .Closed Sell PE Contract : BANKNIFTY2820012MAR20PE at Price 916.35
# Closed Buy CE Contract : BANKNIFTY2940012MAR20CE at Price 35.45 .Closed Buy PE Contract : BANKNIFTY2740012MAR20PE at Price 85.05
#
#
#
#
# 2020-03-12 10:00:00
# 19MAR20
# 2020-03-19 10:00:00
# MAR20
# 2020-03-26 10:00:00
# 01APR20
# 2020-04-01 10:00:00
# 09APR20
# False
# BANKNIFTY2050009APR20CE
# Entry at 2020-04-01 10:00:00 at a SP of 18600
# Enter First Sell Series CE Contract : BANKNIFTY2050009APR20CE Price : 101.6 . PE Contract : BANKNIFTY1550009APR20PE Price : 89.75
# Enter First Buy Series CE Contract : BANKNIFTY2550009APR20CE Price : 29.8 . PE Contract : BANKNIFTY1400009APR20PE Price : 34.9
# Adjustment of CE at 2020-04-01 11:30:00
# Exited SELL Contract : BANKNIFTY2050009APR20CE at Price : 51.5 and NEW BUY Contract : BANKNIFTY2550009APR20CE and Price : 51.5
# Entered New SELL Contract : BANKNIFTY2000009APR20CE at Price : 92.05 and NEW BUY Contract : BANKNIFTY2100009APR20CE and Price : 34.9
# Adjustment of CE at 2020-04-03 09:15:00
# Exited SELL Contract : BANKNIFTY2000009APR20CE at Price : 51.0 and NEW BUY Contract : BANKNIFTY2100009APR20CE and Price : 51.0
# Entered New SELL Contract : BANKNIFTY1950009APR20CE at Price : 139.45 and NEW BUY Contract : BANKNIFTY2050009APR20CE and Price : 55.0
# Adjustment of CE at 2020-04-03 09:20:00
# Exited SELL Contract : BANKNIFTY1950009APR20CE at Price : 82.15 and NEW BUY Contract : BANKNIFTY2050009APR20CE and Price : 82.15
# Entered New SELL Contract : BANKNIFTY1910009APR20CE at Price : 158.3 and NEW BUY Contract : BANKNIFTY1990009APR20CE and Price : 51.05
# Adjustment of CE at 2020-04-03 14:32:00
# Exited SELL Contract : BANKNIFTY1910009APR20CE at Price : 48.65 and NEW BUY Contract : BANKNIFTY1990009APR20CE and Price : 48.65
# Entered New SELL Contract : BANKNIFTY1860009APR20CE at Price : 85.8 and NEW BUY Contract : BANKNIFTY1960009APR20CE and Price : 28.05
# Adjustment of CE at 2020-04-07 09:22:00
# Exited SELL Contract : BANKNIFTY1550009APR20PE at Price : 27.35 and NEW BUY Contract : BANKNIFTY1400009APR20PE and Price : 27.35
# Entered New SELL Contract : BANKNIFTY1730009APR20PE at Price : 168.85 and NEW BUY Contract : BANKNIFTY1620009APR20PE and Price : 55.15
# Adjustment of CE at 2020-04-07 09:36:00
# Exited SELL Contract : BANKNIFTY1730009APR20PE at Price : 105.55 and NEW BUY Contract : BANKNIFTY1620009APR20PE and Price : 105.55
# Entered New SELL Contract : BANKNIFTY1770009APR20PE at Price : 213.9 and NEW BUY Contract : BANKNIFTY1700009APR20PE and Price : 72.35
# Adjustment of CE at 2020-04-07 10:35:00
# Exited SELL Contract : BANKNIFTY1860009APR20CE at Price : 149.6 and NEW BUY Contract : BANKNIFTY1960009APR20CE and Price : 149.6
# Entered New SELL Contract : BANKNIFTY1820009APR20CE at Price : 290.95 and NEW BUY Contract : BANKNIFTY1890009APR20CE and Price : 100.55
# Adjustment of CE at 2020-04-07 11:25:00
# Exited SELL Contract : BANKNIFTY1770009APR20PE at Price : 197.1 and NEW BUY Contract : BANKNIFTY1700009APR20PE and Price : 197.1
# Entered New SELL Contract : BANKNIFTY1810009APR20PE at Price : 361.75 and NEW BUY Contract : BANKNIFTY1730009APR20PE and Price : 120.1
# Stoploss Created at 2020-04-07 11:25:00
# StopLoss Hit at 2020-04-07 11:26:00 .Closed Sell CE Contract : BANKNIFTY1820009APR20CE at Price 428.95 .Closed Sell PE Contract : BANKNIFTY1810009APR20PE at Price 351.5
# Closed Buy CE Contract : BANKNIFTY1890009APR20CE at Price 154.25 .Closed Buy PE Contract : BANKNIFTY1730009APR20PE at Price 114.0
#
#
#
#
# 2020-04-09 10:00:00
# 16APR20
# False
# BANKNIFTY2250016APR20CE
# Entry at 2020-04-09 10:00:00 at a SP of 19600
# Enter First Sell Series CE Contract : BANKNIFTY2250016APR20CE Price : 85.45 . PE Contract : BANKNIFTY1650016APR20PE Price : 99.0
# Enter First Buy Series CE Contract : BANKNIFTY2400016APR20CE Price : 28.15 . PE Contract : BANKNIFTY1500016APR20PE Price : 33.45
# Adjustment of CE at 2020-04-09 10:59:00
# Exited SELL Contract : BANKNIFTY2250016APR20CE at Price : 53.9 and NEW BUY Contract : BANKNIFTY2400016APR20CE and Price : 53.9
# Entered New SELL Contract : BANKNIFTY2200016APR20CE at Price : 81.75 and NEW BUY Contract : BANKNIFTY2300016APR20CE and Price : 36.25
# Adjustment of CE at 2020-04-09 15:27:00
# Exited SELL Contract : BANKNIFTY1650016APR20PE at Price : 50.15 and NEW BUY Contract : BANKNIFTY1500016APR20PE and Price : 50.15
# Entered New SELL Contract : BANKNIFTY1690016APR20PE at Price : 84.0 and NEW BUY Contract : BANKNIFTY1600016APR20PE and Price : 30.5
# Adjustment of CE at 2020-04-13 09:19:00
# Exited SELL Contract : BANKNIFTY1690016APR20PE at Price : 25.1 and NEW BUY Contract : BANKNIFTY1600016APR20PE and Price : 25.1
# Entered New SELL Contract : BANKNIFTY1740016APR20PE at Price : 73.5 and NEW BUY Contract : BANKNIFTY1650016APR20PE and Price : 22.95
# Adjustment of CE at 2020-04-13 09:23:00
# Exited SELL Contract : BANKNIFTY2200016APR20CE at Price : 46.1 and NEW BUY Contract : BANKNIFTY2300016APR20CE and Price : 46.1
# Entered New SELL Contract : BANKNIFTY2150016APR20CE at Price : 88.45 and NEW BUY Contract : BANKNIFTY2250016APR20CE and Price : 28.5
# Adjustment of CE at 2020-04-13 09:33:00
# Exited SELL Contract : BANKNIFTY2150016APR20CE at Price : 51.8 and NEW BUY Contract : BANKNIFTY2250016APR20CE and Price : 51.8
# Entered New SELL Contract : BANKNIFTY2120016APR20CE at Price : 80.2 and NEW BUY Contract : BANKNIFTY2220016APR20CE and Price : 25.0
# Adjustment of CE at 2020-04-13 11:41:00
# Exited SELL Contract : BANKNIFTY1740016APR20PE at Price : 61.1 and NEW BUY Contract : BANKNIFTY1650016APR20PE and Price : 61.1
# Entered New SELL Contract : BANKNIFTY1780016APR20PE at Price : 102.5 and NEW BUY Contract : BANKNIFTY1700016APR20PE and Price : 36.7
# Adjustment of CE at 2020-04-15 09:15:00
# Exited SELL Contract : BANKNIFTY1780016APR20PE at Price : 30.9 and NEW BUY Contract : BANKNIFTY1700016APR20PE and Price : 30.9
# Entered New SELL Contract : BANKNIFTY1830016APR20PE at Price : 93.0 and NEW BUY Contract : BANKNIFTY1670016APR20PE and Price : 1.85
# Adjustment of CE at 2020-04-15 09:17:00
# Exited SELL Contract : BANKNIFTY1830016APR20PE at Price : 41.8 and NEW BUY Contract : BANKNIFTY1670016APR20PE and Price : 41.8
# Entered New SELL Contract : BANKNIFTY1860016APR20PE at Price : 84.45 and NEW BUY Contract : BANKNIFTY1790016APR20PE and Price : 31.0
# Adjustment of CE at 2020-04-15 12:53:00
# Exited SELL Contract : BANKNIFTY2120016APR20CE at Price : 25.15 and NEW BUY Contract : BANKNIFTY2220016APR20CE and Price : 25.15
# Entered New SELL Contract : BANKNIFTY2100016APR20CE at Price : 44.75 and NEW BUY Contract : BANKNIFTY2140016APR20CE and Price : 16.9
# Adjustment of CE at 2020-04-15 13:16:00
# Exited SELL Contract : BANKNIFTY2100016APR20CE at Price : 28.0 and NEW BUY Contract : BANKNIFTY2140016APR20CE and Price : 28.0
# Entered New SELL Contract : BANKNIFTY2080016APR20CE at Price : 52.15 and NEW BUY Contract : BANKNIFTY2120016APR20CE and Price : 18.75
# Adjustment of CE at 2020-04-15 13:24:00
# Exited SELL Contract : BANKNIFTY2080016APR20CE at Price : 36.55 and NEW BUY Contract : BANKNIFTY2120016APR20CE and Price : 36.55
# Entered New SELL Contract : BANKNIFTY2060016APR20CE at Price : 60.75 and NEW BUY Contract : BANKNIFTY2110016APR20CE and Price : 18.2
# Adjustment of CE at 2020-04-15 13:45:00
# Exited SELL Contract : BANKNIFTY2060016APR20CE at Price : 43.0 and NEW BUY Contract : BANKNIFTY2110016APR20CE and Price : 43.0
# Entered New SELL Contract : BANKNIFTY2030016APR20CE at Price : 91.5 and NEW BUY Contract : BANKNIFTY2080016APR20CE and Price : 28.1
# Adjustment of CE at 2020-04-15 14:05:00
# Exited SELL Contract : BANKNIFTY2030016APR20CE at Price : 57.6 and NEW BUY Contract : BANKNIFTY2080016APR20CE and Price : 57.6
# Entered New SELL Contract : BANKNIFTY2000016APR20CE at Price : 117.0 and NEW BUY Contract : BANKNIFTY2050016APR20CE and Price : 40.5
# Adjustment of CE at 2020-04-15 14:09:00
# Exited SELL Contract : BANKNIFTY2000016APR20CE at Price : 87.55 and NEW BUY Contract : BANKNIFTY2050016APR20CE and Price : 87.55
# Entered New SELL Contract : BANKNIFTY1970016APR20CE at Price : 168.8 and NEW BUY Contract : BANKNIFTY2030016APR20CE and Price : 53.1
# Adjustment of CE at 2020-04-15 14:15:00
# Exited SELL Contract : BANKNIFTY1970016APR20CE at Price : 104.8 and NEW BUY Contract : BANKNIFTY2030016APR20CE and Price : 104.8
# Entered New SELL Contract : BANKNIFTY1930016APR20CE at Price : 243.25 and NEW BUY Contract : BANKNIFTY1990016APR20CE and Price : 85.35
# Adjustment of CE at 2020-04-15 14:23:00
# Exited SELL Contract : BANKNIFTY1930016APR20CE at Price : 155.9 and NEW BUY Contract : BANKNIFTY1990016APR20CE and Price : 155.9
# Entered New SELL Contract : BANKNIFTY1900016APR20CE at Price : 270.0 and NEW BUY Contract : BANKNIFTY1960016APR20CE and Price : 100.1
# Adjustment of CE at 2020-04-15 14:39:00
# Exited SELL Contract : BANKNIFTY1860016APR20PE at Price : 169.65 and NEW BUY Contract : BANKNIFTY1790016APR20PE and Price : 169.65
# Entered New SELL Contract : BANKNIFTY1890016APR20PE at Price : 312.8 and NEW BUY Contract : BANKNIFTY1830016APR20PE and Price : 116.6
# Stoploss Created at 2020-04-15 14:39:00
# Expiry Exit at 2020-04-16 10:00:00 .Closed Sell CE Contract : BANKNIFTY1900016APR20CE at Price 124.15 .Closed Sell PE Contract : BANKNIFTY1890016APR20PE at Price 265.0
# Closed Buy CE Contract : BANKNIFTY1960016APR20CE at Price 12.65 .Closed Buy PE Contract : BANKNIFTY1830016APR20PE at Price 54.25
#
#
#
#
# 2020-04-16 10:00:00
# 23APR20
# False
# BANKNIFTY2100023APR20CE
# Entry at 2020-04-16 10:00:00 at a SP of 18900
# Enter First Sell Series CE Contract : BANKNIFTY2100023APR20CE Price : 88.05 . PE Contract : BANKNIFTY1650023APR20PE Price : 85.0
# Enter First Buy Series CE Contract : BANKNIFTY2200023APR20CE Price : 28.0 . PE Contract : BANKNIFTY1550023APR20PE Price : 26.8
# Adjustment of CE at 2020-04-16 11:15:00
# Exited SELL Contract : BANKNIFTY1650023APR20PE at Price : 51.0 and NEW BUY Contract : BANKNIFTY1550023APR20PE and Price : 51.0
# Entered New SELL Contract : BANKNIFTY1700023APR20PE at Price : 97.05 and NEW BUY Contract : BANKNIFTY1600023APR20PE and Price : 30.65
# Adjustment of CE at 2020-04-16 12:24:00
# Exited SELL Contract : BANKNIFTY1700023APR20PE at Price : 73.5 and NEW BUY Contract : BANKNIFTY1600023APR20PE and Price : 73.5
# Entered New SELL Contract : BANKNIFTY1680023APR20PE at Price : 115.0 and NEW BUY Contract : BANKNIFTY1650023APR20PE and Price : 43.6
# Adjustment of CE at 2020-04-16 13:38:00
# Exited SELL Contract : BANKNIFTY1680023APR20PE at Price : 65.0 and NEW BUY Contract : BANKNIFTY1650023APR20PE and Price : 65.0
# Entered New SELL Contract : BANKNIFTY1750023APR20PE at Price : 132.5 and NEW BUY Contract : BANKNIFTY1650023APR20PE and Price : 44.6
# Adjustment of CE at 2020-04-17 09:15:00
# Exited SELL Contract : BANKNIFTY1750023APR20PE at Price : 37.3 and NEW BUY Contract : BANKNIFTY1650023APR20PE and Price : 37.3
# Entered New SELL Contract : BANKNIFTY1950023APR20PE at Price : 285.6 and NEW BUY Contract : BANKNIFTY1850023APR20PE and Price : 109.1
# Adjustment of CE at 2020-04-17 10:49:00
# Exited SELL Contract : BANKNIFTY2100023APR20CE at Price : 258.5 and NEW BUY Contract : BANKNIFTY2200023APR20CE and Price : 258.5
# Entered New SELL Contract : BANKNIFTY2040023APR20CE at Price : 447.55 and NEW BUY Contract : BANKNIFTY2160023APR20CE and Price : 153.25
# Adjustment of CE at 2020-04-17 14:50:00
# Exited SELL Contract : BANKNIFTY1950023APR20PE at Price : 276.6 and NEW BUY Contract : BANKNIFTY1850023APR20PE and Price : 276.6
# Entered New SELL Contract : BANKNIFTY2000023APR20PE at Price : 444.65 and NEW BUY Contract : BANKNIFTY1890023APR20PE and Price : 147.55
# Adjustment of CE at 2020-04-17 15:06:00
# Exited SELL Contract : BANKNIFTY2000023APR20PE at Price : 362.9 and NEW BUY Contract : BANKNIFTY1890023APR20PE and Price : 362.9
# Entered New SELL Contract : BANKNIFTY2070023APR20PE at Price : 682.8 and NEW BUY Contract : BANKNIFTY1940023APR20PE and Price : 227.2
# Stoploss Created at 2020-04-17 15:06:00
# StopLoss Hit at 2020-04-17 15:07:00 .Closed Sell CE Contract : BANKNIFTY2040023APR20CE at Price 789.95 .Closed Sell PE Contract : BANKNIFTY2070023APR20PE at Price 656.35
# Closed Buy CE Contract : BANKNIFTY2160023APR20CE at Price 261.15 .Closed Buy PE Contract : BANKNIFTY1940023APR20PE at Price 221.45
#
#
#
#
# 2020-04-23 10:00:00
# APR20
# True
# BANKNIFTY21800APR20CE
# Entry at 2020-04-23 10:00:00 at a SP of 19900
# Enter First Sell Series CE Contract : BANKNIFTY21800APR20CE Price : 99.3 . PE Contract : BANKNIFTY17600APR20PE Price : 111.65
# Enter First Buy Series CE Contract : BANKNIFTY23000APR20CE Price : 33.2 . PE Contract : BANKNIFTY16500APR20PE Price : 30.05
# Adjustment of CE at 2020-04-23 12:22:00
# Exited SELL Contract : BANKNIFTY17600APR20PE at Price : 56.1 and NEW BUY Contract : BANKNIFTY16500APR20PE and Price : 56.1
# Entered New SELL Contract : BANKNIFTY17900APR20PE at Price : 89.1 and NEW BUY Contract : BANKNIFTY16600APR20PE and Price : 25.7
# Adjustment of CE at 2020-04-23 14:59:00
# Exited SELL Contract : BANKNIFTY17900APR20PE at Price : 58.2 and NEW BUY Contract : BANKNIFTY16600APR20PE and Price : 58.2
# Entered New SELL Contract : BANKNIFTY18300APR20PE at Price : 90.25 and NEW BUY Contract : BANKNIFTY17200APR20PE and Price : 30.5
# Adjustment of CE at 2020-04-24 09:15:00
# Exited SELL Contract : BANKNIFTY21800APR20CE at Price : 52.35 and NEW BUY Contract : BANKNIFTY23000APR20CE and Price : 52.35
# Entered New SELL Contract : BANKNIFTY21100APR20CE at Price : 120.05 and NEW BUY Contract : BANKNIFTY22600APR20CE and Price : 38.0
# Adjustment of CE at 2020-04-24 09:25:00
# Exited SELL Contract : BANKNIFTY21100APR20CE at Price : 94.0 and NEW BUY Contract : BANKNIFTY22600APR20CE and Price : 94.0
# Entered New SELL Contract : BANKNIFTY20700APR20CE at Price : 169.3 and NEW BUY Contract : BANKNIFTY21500APR20CE and Price : 60.65
# Adjustment of CE at 2020-04-27 09:15:00
# Exited SELL Contract : BANKNIFTY18300APR20PE at Price : 64.3 and NEW BUY Contract : BANKNIFTY17200APR20PE and Price : 64.3
# Entered New SELL Contract : BANKNIFTY18800APR20PE at Price : 169.55 and NEW BUY Contract : BANKNIFTY18100APR20PE and Price : 51.6
# Adjustment of CE at 2020-04-27 09:30:00
# Exited SELL Contract : BANKNIFTY18800APR20PE at Price : 94.55 and NEW BUY Contract : BANKNIFTY18100APR20PE and Price : 94.55
# Entered New SELL Contract : BANKNIFTY19100APR20PE at Price : 155.3 and NEW BUY Contract : BANKNIFTY18400APR20PE and Price : 54.35
# Adjustment of CE at 2020-04-27 10:43:00
# Exited SELL Contract : BANKNIFTY19100APR20PE at Price : 114.3 and NEW BUY Contract : BANKNIFTY18400APR20PE and Price : 114.3
# Entered New SELL Contract : BANKNIFTY19500APR20PE at Price : 197.3 and NEW BUY Contract : BANKNIFTY18700APR20PE and Price : 66.8
# Adjustment of CE at 2020-04-28 09:15:00
# Exited SELL Contract : BANKNIFTY19500APR20PE at Price : 95.2 and NEW BUY Contract : BANKNIFTY18700APR20PE and Price : 95.2
# Entered New SELL Contract : BANKNIFTY19900APR20PE at Price : 198.2 and NEW BUY Contract : BANKNIFTY19200APR20PE and Price : 60.0
# Adjustment of CE at 2020-04-28 13:17:00
# Exited SELL Contract : BANKNIFTY19900APR20PE at Price : 109.05 and NEW BUY Contract : BANKNIFTY19200APR20PE and Price : 109.05
# Entered New SELL Contract : BANKNIFTY20200APR20PE at Price : 188.2 and NEW BUY Contract : BANKNIFTY19600APR20PE and Price : 67.85
# Adjustment of CE at 2020-04-28 15:11:00
# Exited SELL Contract : BANKNIFTY20200APR20PE at Price : 131.65 and NEW BUY Contract : BANKNIFTY19600APR20PE and Price : 131.65
# Entered New SELL Contract : BANKNIFTY20500APR20PE at Price : 233.95 and NEW BUY Contract : BANKNIFTY19900APR20PE and Price : 81.05
# Adjustment of CE at 2020-04-29 11:17:00
# Exited SELL Contract : BANKNIFTY20500APR20PE at Price : 137.3 and NEW BUY Contract : BANKNIFTY19900APR20PE and Price : 137.3
# Entered New SELL Contract : BANKNIFTY20700APR20PE at Price : 213.65 and NEW BUY Contract : BANKNIFTY20200APR20PE and Price : 67.05
# Stoploss Created at 2020-04-29 11:17:00
# StopLoss Hit at 2020-04-29 11:18:00 .Closed Sell CE Contract : BANKNIFTY20700APR20CE at Price 287.3 .Closed Sell PE Contract : BANKNIFTY20700APR20PE at Price 205.35
# Closed Buy CE Contract : BANKNIFTY21500APR20CE at Price 27.35 .Closed Buy PE Contract : BANKNIFTY20200APR20PE at Price 63.85
#
#
#
#
# 2020-04-30 10:00:00
# 07MAY20
# False
# BANKNIFTY2310007MAY20CE
# Entry at 2020-04-30 10:00:00 at a SP of 21800
# Enter First Sell Series CE Contract : BANKNIFTY2310007MAY20CE Price : 98.0 . PE Contract : BANKNIFTY2040007MAY20PE Price : 96.9
# Enter First Buy Series CE Contract : BANKNIFTY2400007MAY20CE Price : 31.85 . PE Contract : BANKNIFTY1920007MAY20PE Price : 35.0
# Adjustment of CE at 2020-04-30 13:10:00
# Exited SELL Contract : BANKNIFTY2310007MAY20CE at Price : 81.05 and NEW BUY Contract : BANKNIFTY2400007MAY20CE and Price : 81.05
# Entered New SELL Contract : BANKNIFTY2250007MAY20CE at Price : 155.25 and NEW BUY Contract : BANKNIFTY2350007MAY20CE and Price : 48.6
# Adjustment of CE at 2020-05-04 09:22:00
# Exited SELL Contract : BANKNIFTY2250007MAY20CE at Price : 25.55 and NEW BUY Contract : BANKNIFTY2350007MAY20CE and Price : 25.55
# Entered New SELL Contract : BANKNIFTY2020007MAY20CE at Price : 581.4 and NEW BUY Contract : BANKNIFTY2120007MAY20CE and Price : 187.45
# Stoploss Created at 2020-05-04 09:22:00
# StopLoss Hit at 2020-05-04 14:06:00 .Closed Sell CE Contract : BANKNIFTY2020007MAY20CE at Price 382.0 .Closed Sell PE Contract : BANKNIFTY2040007MAY20PE at Price 1032.75
# Closed Buy CE Contract : BANKNIFTY2120007MAY20CE at Price 125.5 .Closed Buy PE Contract : BANKNIFTY1920007MAY20PE at Price 403.95
#
#
#
#
# 2020-05-07 10:00:00
# 14MAY20
# False
# BANKNIFTY2150014MAY20CE
# Entry at 2020-05-07 10:00:00 at a SP of 19700
# Enter First Sell Series CE Contract : BANKNIFTY2150014MAY20CE Price : 92.4 . PE Contract : BANKNIFTY1750014MAY20PE Price : 77.4
# Enter First Buy Series CE Contract : BANKNIFTY2250014MAY20CE Price : 30.45 . PE Contract : BANKNIFTY1650014MAY20PE Price : 25.05
# Adjustment of CE at 2020-05-08 09:15:00
# Exited SELL Contract : BANKNIFTY1750014MAY20PE at Price : 30.95 and NEW BUY Contract : BANKNIFTY1650014MAY20PE and Price : 30.95
# Entered New SELL Contract : BANKNIFTY1810014MAY20PE at Price : 68.05 and NEW BUY Contract : BANKNIFTY1710014MAY20PE and Price : 18.85
# Adjustment of CE at 2020-05-08 13:51:00
# Exited SELL Contract : BANKNIFTY2150014MAY20CE at Price : 39.8 and NEW BUY Contract : BANKNIFTY2250014MAY20CE and Price : 39.8
# Entered New SELL Contract : BANKNIFTY2110014MAY20CE at Price : 73.35 and NEW BUY Contract : BANKNIFTY2180014MAY20CE and Price : 26.95
# Adjustment of CE at 2020-05-08 14:41:00
# Exited SELL Contract : BANKNIFTY2110014MAY20CE at Price : 54.8 and NEW BUY Contract : BANKNIFTY2180014MAY20CE and Price : 54.8
# Entered New SELL Contract : BANKNIFTY2070014MAY20CE at Price : 99.1 and NEW BUY Contract : BANKNIFTY2150014MAY20CE and Price : 30.6
# Adjustment of CE at 2020-05-11 09:15:00
# Exited SELL Contract : BANKNIFTY1810014MAY20PE at Price : 51.1 and NEW BUY Contract : BANKNIFTY1710014MAY20PE and Price : 51.1
# Entered New SELL Contract : BANKNIFTY1850014MAY20PE at Price : 138.4 and NEW BUY Contract : BANKNIFTY1780014MAY20PE and Price : 33.9
# Adjustment of CE at 2020-05-11 10:15:00
# Exited SELL Contract : BANKNIFTY2070014MAY20CE at Price : 71.45 and NEW BUY Contract : BANKNIFTY2150014MAY20CE and Price : 71.45
# Entered New SELL Contract : BANKNIFTY2040014MAY20CE at Price : 121.7 and NEW BUY Contract : BANKNIFTY2110014MAY20CE and Price : 37.35
# Adjustment of CE at 2020-05-11 11:40:00
# Exited SELL Contract : BANKNIFTY2040014MAY20CE at Price : 85.95 and NEW BUY Contract : BANKNIFTY2110014MAY20CE and Price : 85.95
# Entered New SELL Contract : BANKNIFTY2010014MAY20CE at Price : 137.8 and NEW BUY Contract : BANKNIFTY2080014MAY20CE and Price : 45.35
# Adjustment of CE at 2020-05-11 14:32:00
# Exited SELL Contract : BANKNIFTY2010014MAY20CE at Price : 97.65 and NEW BUY Contract : BANKNIFTY2080014MAY20CE and Price : 97.65
# Entered New SELL Contract : BANKNIFTY1980014MAY20CE at Price : 152.25 and NEW BUY Contract : BANKNIFTY2050014MAY20CE and Price : 52.4
# Adjustment of CE at 2020-05-12 09:15:00
# Exited SELL Contract : BANKNIFTY1980014MAY20CE at Price : 54.8 and NEW BUY Contract : BANKNIFTY2050014MAY20CE and Price : 54.8
# Entered New SELL Contract : BANKNIFTY1880014MAY20CE at Price : 300.1 and NEW BUY Contract : BANKNIFTY1950014MAY20CE and Price : 112.7
# Adjustment of CE at 2020-05-12 09:47:00
# Exited SELL Contract : BANKNIFTY1880014MAY20CE at Price : 198.25 and NEW BUY Contract : BANKNIFTY1950014MAY20CE and Price : 198.25
# Entered New SELL Contract : BANKNIFTY1850014MAY20CE at Price : 317.75 and NEW BUY Contract : BANKNIFTY1920014MAY20CE and Price : 102.8
# Stoploss Created at 2020-05-12 09:47:00
# StopLoss Hit at 2020-05-12 14:30:00 .Closed Sell CE Contract : BANKNIFTY1850014MAY20CE at Price 563.45 .Closed Sell PE Contract : BANKNIFTY1850014MAY20PE at Price 241.95
# Closed Buy CE Contract : BANKNIFTY1920014MAY20CE at Price 230.15 .Closed Buy PE Contract : BANKNIFTY1780014MAY20PE at Price 70.05
#
#
#
#
# 2020-05-14 10:00:00
# 21MAY20
# False
# BANKNIFTY2120021MAY20CE
# Entry at 2020-05-14 10:00:00 at a SP of 19200
# Enter First Sell Series CE Contract : BANKNIFTY2120021MAY20CE Price : 92.5 . PE Contract : BANKNIFTY1750021MAY20PE Price : 87.0
# Enter First Buy Series CE Contract : BANKNIFTY2200021MAY20CE Price : 38.15 . PE Contract : BANKNIFTY1650021MAY20PE Price : 24.9
# Adjustment of CE at 2020-05-15 09:15:00
# Exited SELL Contract : BANKNIFTY2120021MAY20CE at Price : 39.5 and NEW BUY Contract : BANKNIFTY2200021MAY20CE and Price : 39.5
# Entered New SELL Contract : BANKNIFTY2060021MAY20CE at Price : 134.85 and NEW BUY Contract : BANKNIFTY2150021MAY20CE and Price : 52.5
# Adjustment of CE at 2020-05-18 09:15:00
# Exited SELL Contract : BANKNIFTY2060021MAY20CE at Price : 31.8 and NEW BUY Contract : BANKNIFTY2150021MAY20CE and Price : 31.8
# Entered New SELL Contract : BANKNIFTY1990021MAY20CE at Price : 130.25 and NEW BUY Contract : BANKNIFTY2080021MAY20CE and Price : 39.2
# Adjustment of CE at 2020-05-18 09:35:00
# Exited SELL Contract : BANKNIFTY1990021MAY20CE at Price : 62.55 and NEW BUY Contract : BANKNIFTY2080021MAY20CE and Price : 62.55
# Entered New SELL Contract : BANKNIFTY1940021MAY20CE at Price : 115.75 and NEW BUY Contract : BANKNIFTY2030021MAY20CE and Price : 38.75
# Adjustment of CE at 2020-05-18 09:36:00
# Exited SELL Contract : BANKNIFTY1940021MAY20CE at Price : 108.05 and NEW BUY Contract : BANKNIFTY2030021MAY20CE and Price : 108.05
# Entered New SELL Contract : BANKNIFTY1900021MAY20CE at Price : 185.25 and NEW BUY Contract : BANKNIFTY1990021MAY20CE and Price : 62.05
# Adjustment of CE at 2020-05-18 09:45:00
# Exited SELL Contract : BANKNIFTY1900021MAY20CE at Price : 139.75 and NEW BUY Contract : BANKNIFTY1990021MAY20CE and Price : 139.75
# Entered New SELL Contract : BANKNIFTY1840021MAY20CE at Price : 298.5 and NEW BUY Contract : BANKNIFTY1940021MAY20CE and Price : 98.9
# Adjustment of CE at 2020-05-18 10:55:00
# Exited SELL Contract : BANKNIFTY1840021MAY20CE at Price : 213.5 and NEW BUY Contract : BANKNIFTY1940021MAY20CE and Price : 213.5
# Entered New SELL Contract : BANKNIFTY1790021MAY20CE at Price : 390.5 and NEW BUY Contract : BANKNIFTY1890021MAY20CE and Price : 127.7
# Adjustment of CE at 2020-05-19 10:18:00
# Exited SELL Contract : BANKNIFTY1750021MAY20PE at Price : 217.0 and NEW BUY Contract : BANKNIFTY1650021MAY20PE and Price : 217.0
# Entered New SELL Contract : BANKNIFTY1780021MAY20PE at Price : 341.8 and NEW BUY Contract : BANKNIFTY1710021MAY20PE and Price : 118.45
# Stoploss Created at 2020-05-19 10:18:00
# StopLoss Hit at 2020-05-19 13:41:00 .Closed Sell CE Contract : BANKNIFTY1790021MAY20CE at Price 218.4 .Closed Sell PE Contract : BANKNIFTY1780021MAY20PE at Price 600.15
# Closed Buy CE Contract : BANKNIFTY1890021MAY20CE at Price 41.45 .Closed Buy PE Contract : BANKNIFTY1710021MAY20PE at Price 244.25
#
#
#
#
# 2020-05-21 10:00:00
# MAY20
# True
# BANKNIFTY19200MAY20CE
# Entry at 2020-05-21 10:00:00 at a SP of 18100
# Enter First Sell Series CE Contract : BANKNIFTY19200MAY20CE Price : 102.45 . PE Contract : BANKNIFTY16900MAY20PE Price : 95.6
# Enter First Buy Series CE Contract : BANKNIFTY20100MAY20CE Price : 30.65 . PE Contract : BANKNIFTY16200MAY20PE Price : 33.4
# Adjustment of CE at 2020-05-21 14:16:00
# Exited SELL Contract : BANKNIFTY19200MAY20CE at Price : 60.55 and NEW BUY Contract : BANKNIFTY20100MAY20CE and Price : 60.55
# Entered New SELL Contract : BANKNIFTY18800MAY20CE at Price : 119.0 and NEW BUY Contract : BANKNIFTY19600MAY20CE and Price : 38.05
# Adjustment of CE at 2020-05-21 14:47:00
# Exited SELL Contract : BANKNIFTY18800MAY20CE at Price : 83.5 and NEW BUY Contract : BANKNIFTY19600MAY20CE and Price : 83.5
# Entered New SELL Contract : BANKNIFTY18400MAY20CE at Price : 152.65 and NEW BUY Contract : BANKNIFTY19200MAY20CE and Price : 51.85
# Adjustment of CE at 2020-05-22 10:30:00
# Exited SELL Contract : BANKNIFTY18400MAY20CE at Price : 113.55 and NEW BUY Contract : BANKNIFTY19200MAY20CE and Price : 113.55
# Entered New SELL Contract : BANKNIFTY17800MAY20CE at Price : 278.8 and NEW BUY Contract : BANKNIFTY18600MAY20CE and Price : 95.65
# Adjustment of CE at 2020-05-22 13:24:00
# Exited SELL Contract : BANKNIFTY17800MAY20CE at Price : 169.0 and NEW BUY Contract : BANKNIFTY18600MAY20CE and Price : 169.0
# Entered New SELL Contract : BANKNIFTY17400MAY20CE at Price : 284.0 and NEW BUY Contract : BANKNIFTY18300MAY20CE and Price : 88.75
# Adjustment of CE at 2020-05-26 09:15:00
# Exited SELL Contract : BANKNIFTY16900MAY20PE at Price : 87.6 and NEW BUY Contract : BANKNIFTY16200MAY20PE and Price : 87.6
# Entered New SELL Contract : BANKNIFTY17600MAY20PE at Price : 420.0 and NEW BUY Contract : BANKNIFTY17000MAY20PE and Price : 160.2
# Stoploss Created at 2020-05-26 09:15:00
# StopLoss Hit at 2020-05-27 13:31:00 .Closed Sell CE Contract : BANKNIFTY17400MAY20CE at Price 726.7 .Closed Sell PE Contract : BANKNIFTY17600MAY20PE at Price 59.75
# Closed Buy CE Contract : BANKNIFTY18300MAY20CE at Price 105.8 .Closed Buy PE Contract : BANKNIFTY17000MAY20PE at Price 15.6
#
#
#
#
# 2020-05-28 10:00:00
# 04JUN20
# False
# BANKNIFTY2030004JUN20CE
# Entry at 2020-05-28 10:00:00 at a SP of 19200
# Enter First Sell Series CE Contract : BANKNIFTY2030004JUN20CE Price : 158.95 . PE Contract : BANKNIFTY1770004JUN20PE Price : 97.55
# Enter First Buy Series CE Contract : BANKNIFTY2100004JUN20CE Price : 41.1 . PE Contract : BANKNIFTY1660004JUN20PE Price : 33.45
# Adjustment of CE at 2020-05-29 09:15:00
# Exited SELL Contract : BANKNIFTY2030004JUN20CE at Price : 56.1 and NEW BUY Contract : BANKNIFTY2100004JUN20CE and Price : 56.1
# Entered New SELL Contract : BANKNIFTY1990004JUN20CE at Price : 138.0 and NEW BUY Contract : BANKNIFTY2050004JUN20CE and Price : 51.95
# Adjustment of CE at 2020-05-29 10:40:00
# Exited SELL Contract : BANKNIFTY1770004JUN20PE at Price : 93.6 and NEW BUY Contract : BANKNIFTY1660004JUN20PE and Price : 93.6
# Entered New SELL Contract : BANKNIFTY1810004JUN20PE at Price : 166.3 and NEW BUY Contract : BANKNIFTY1720004JUN20PE and Price : 56.4
# Adjustment of CE at 2020-05-29 12:04:00
# Exited SELL Contract : BANKNIFTY1990004JUN20CE at Price : 105.65 and NEW BUY Contract : BANKNIFTY2050004JUN20CE and Price : 105.65
# Entered New SELL Contract : BANKNIFTY1960004JUN20CE at Price : 169.7 and NEW BUY Contract : BANKNIFTY2030004JUN20CE and Price : 58.8
# Adjustment of CE at 2020-06-01 09:15:00
# Exited SELL Contract : BANKNIFTY1810004JUN20PE at Price : 33.05 and NEW BUY Contract : BANKNIFTY1720004JUN20PE and Price : 33.05
# Entered New SELL Contract : BANKNIFTY1960004JUN20PE at Price : 370.5 and NEW BUY Contract : BANKNIFTY1890004JUN20PE and Price : 217.2
# Stoploss Created at 2020-06-01 09:15:00
# StopLoss Hit at 2020-06-01 09:16:00 .Closed Sell CE Contract : BANKNIFTY1960004JUN20CE at Price 477.75 .Closed Sell PE Contract : BANKNIFTY1960004JUN20PE at Price 354.35
# Closed Buy CE Contract : BANKNIFTY2030004JUN20CE at Price 210.25 .Closed Buy PE Contract : BANKNIFTY1890004JUN20PE at Price 121.9
#
#
#
#
# 2020-06-04 10:00:00
# 11JUN20
# False
# None
# Data is not available in either PE or CE at Data Preprocessing for 2020-06-04 10:00:00
# 2020-06-11 10:00:00
# 18JUN20
# False
# BANKNIFTY2300018JUN20CE
# Entry at 2020-06-11 10:00:00 at a SP of 21100
# Enter First Sell Series CE Contract : BANKNIFTY2300018JUN20CE Price : 106.75 . PE Contract : BANKNIFTY1900018JUN20PE Price : 95.95
# Enter First Buy Series CE Contract : BANKNIFTY2400018JUN20CE Price : 34.4 . PE Contract : BANKNIFTY1800018JUN20PE Price : 32.8
# Adjustment of CE at 2020-06-11 13:30:00
# Exited SELL Contract : BANKNIFTY2300018JUN20CE at Price : 68.15 and NEW BUY Contract : BANKNIFTY2400018JUN20CE and Price : 68.15
# Entered New SELL Contract : BANKNIFTY2250018JUN20CE at Price : 120.05 and NEW BUY Contract : BANKNIFTY2350018JUN20CE and Price : 40.45
# Adjustment of CE at 2020-06-11 15:16:00
# Exited SELL Contract : BANKNIFTY2250018JUN20CE at Price : 80.45 and NEW BUY Contract : BANKNIFTY2350018JUN20CE and Price : 80.45
# Entered New SELL Contract : BANKNIFTY2210018JUN20CE at Price : 127.85 and NEW BUY Contract : BANKNIFTY2310018JUN20CE and Price : 41.8
# Adjustment of CE at 2020-06-12 09:15:00
# Exited SELL Contract : BANKNIFTY2210018JUN20CE at Price : 60.55 and NEW BUY Contract : BANKNIFTY2310018JUN20CE and Price : 60.55
# Entered New SELL Contract : BANKNIFTY2060018JUN20CE at Price : 299.95 and NEW BUY Contract : BANKNIFTY2170018JUN20CE and Price : 55.1
# Adjustment of CE at 2020-06-12 11:25:00
# Exited SELL Contract : BANKNIFTY1900018JUN20PE at Price : 230.0 and NEW BUY Contract : BANKNIFTY1800018JUN20PE and Price : 230.0
# Entered New SELL Contract : BANKNIFTY1960018JUN20PE at Price : 394.45 and NEW BUY Contract : BANKNIFTY1840018JUN20PE and Price : 144.45
# Adjustment of CE at 2020-06-12 14:45:00
# Exited SELL Contract : BANKNIFTY1960018JUN20PE at Price : 246.4 and NEW BUY Contract : BANKNIFTY1840018JUN20PE and Price : 246.4
# Entered New SELL Contract : BANKNIFTY2020018JUN20PE at Price : 462.55 and NEW BUY Contract : BANKNIFTY1900018JUN20PE and Price : 151.45
# Adjustment of CE at 2020-06-15 10:00:00
# ...
# Adjustment of CE at 2021-11-16 14:24:00
# Exited SELL Contract : BANKNIFTY3860018NOV21CE at Price : 142.15 and NEW BUY Contract : BANKNIFTY3910018NOV21CE and Price : 142.15
# Entered New SELL Contract : BANKNIFTY3840018NOV21CE at Price : 240.9 and NEW BUY Contract : BANKNIFTY3890018NOV21CE and Price : 77.65
# Stoploss Created at 2021-11-16 14:24:00
# StopLoss Hit at 2021-11-16 15:27:00 .Closed Sell CE Contract : BANKNIFTY3840018NOV21CE at Price 215.65 .Closed Sell PE Contract : BANKNIFTY3840018NOV21PE at Price 338.0
# Closed Buy CE Contract : BANKNIFTY3890018NOV21CE at Price 73.45 .Closed Buy PE Contract : BANKNIFTY3790018NOV21PE at Price 125.4
#
#
#
#
# 2021-11-18 10:00:00
# NOV21
# True
# BANKNIFTY39100NOV21CE
# Entry at 2021-11-18 10:00:00 at a SP of 38100
# Enter First Sell Series CE Contract : BANKNIFTY39100NOV21CE Price : 99.75 . PE Contract : BANKNIFTY37100NOV21PE Price : 104.15
# Enter First Buy Series CE Contract : BANKNIFTY39900NOV21CE Price : 34.9 . PE Contract : BANKNIFTY36200NOV21PE Price : 34.2
# Adjustment of CE at 2021-11-18 10:39:00
# Exited SELL Contract : BANKNIFTY39100NOV21CE at Price : 75.65 and NEW BUY Contract : BANKNIFTY39900NOV21CE and Price : 75.65
# Entered New SELL Contract : BANKNIFTY38700NOV21CE at Price : 143.15 and NEW BUY Contract : BANKNIFTY39500NOV21CE and Price : 48.5
# Adjustment of CE at 2021-11-18 14:57:00
# Exited SELL Contract : BANKNIFTY37100NOV21PE at Price : 55.55 and NEW BUY Contract : BANKNIFTY36200NOV21PE and Price : 55.55
# Entered New SELL Contract : BANKNIFTY37500NOV21PE at Price : 142.85 and NEW BUY Contract : BANKNIFTY36900NOV21PE and Price : 51.25
# Adjustment of CE at 2021-11-22 09:20:00
# Exited SELL Contract : BANKNIFTY38700NOV21CE at Price : 87.0 and NEW BUY Contract : BANKNIFTY39500NOV21CE and Price : 87.0
# Entered New SELL Contract : BANKNIFTY38400NOV21CE at Price : 176.9 and NEW BUY Contract : BANKNIFTY39000NOV21CE and Price : 57.9
# Adjustment of CE at 2021-11-22 09:39:00
# Exited SELL Contract : BANKNIFTY38400NOV21CE at Price : 115.5 and NEW BUY Contract : BANKNIFTY39000NOV21CE and Price : 115.5
# Entered New SELL Contract : BANKNIFTY38100NOV21CE at Price : 218.9 and NEW BUY Contract : BANKNIFTY38700NOV21CE and Price : 72.2
# Adjustment of CE at 2021-11-22 10:34:00
# Exited SELL Contract : BANKNIFTY38100NOV21CE at Price : 145.4 and NEW BUY Contract : BANKNIFTY38700NOV21CE and Price : 145.4
# Entered New SELL Contract : BANKNIFTY37800NOV21CE at Price : 254.25 and NEW BUY Contract : BANKNIFTY38400NOV21CE and Price : 88.6
# Adjustment of CE at 2021-11-22 11:14:00
# Exited SELL Contract : BANKNIFTY37800NOV21CE at Price : 191.6 and NEW BUY Contract : BANKNIFTY38400NOV21CE and Price : 191.6
# Entered New SELL Contract : BANKNIFTY37400NOV21CE at Price : 371.3 and NEW BUY Contract : BANKNIFTY38100NOV21CE and Price : 122.6
# Stoploss Created at 2021-11-22 11:14:00
# StopLoss Hit at 2021-11-22 12:09:00 .Closed Sell CE Contract : BANKNIFTY37400NOV21CE at Price 259.9 .Closed Sell PE Contract : BANKNIFTY37500NOV21PE at Price 678.3
# Closed Buy CE Contract : BANKNIFTY38100NOV21CE at Price 92.15 .Closed Buy PE Contract : BANKNIFTY36900NOV21PE at Price 335.65
#
#
#
#
# 2021-11-25 10:00:00
# 02DEC21
# False
# BANKNIFTY3820002DEC21CE
# Entry at 2021-11-25 10:00:00 at a SP of 37200
# Enter First Sell Series CE Contract : BANKNIFTY3820002DEC21CE Price : 107.6 . PE Contract : BANKNIFTY3620002DEC21PE Price : 105.45
# Enter First Buy Series CE Contract : BANKNIFTY3900002DEC21CE Price : 32.9 . PE Contract : BANKNIFTY3530002DEC21PE Price : 34.65
# Adjustment of CE at 2021-11-25 11:32:00
# Exited SELL Contract : BANKNIFTY3620002DEC21PE at Price : 70.15 and NEW BUY Contract : BANKNIFTY3530002DEC21PE and Price : 70.15
# Entered New SELL Contract : BANKNIFTY3660002DEC21PE at Price : 132.3 and NEW BUY Contract : BANKNIFTY3570002DEC21PE and Price : 42.2
# Adjustment of CE at 2021-11-26 09:15:00
# Exited SELL Contract : BANKNIFTY3820002DEC21CE at Price : 48.2 and NEW BUY Contract : BANKNIFTY3900002DEC21CE and Price : 48.2
# Entered New SELL Contract : BANKNIFTY3720002DEC21CE at Price : 400.0 and NEW BUY Contract : BANKNIFTY3790002DEC21CE and Price : 68.0
# Adjustment of CE at 2021-11-26 09:52:00
# Exited SELL Contract : BANKNIFTY3720002DEC21CE at Price : 185.55 and NEW BUY Contract : BANKNIFTY3790002DEC21CE and Price : 185.55
# Entered New SELL Contract : BANKNIFTY3690002DEC21CE at Price : 300.35 and NEW BUY Contract : BANKNIFTY3760002DEC21CE and Price : 93.95
# Adjustment of CE at 2021-11-26 10:22:00
# Exited SELL Contract : BANKNIFTY3690002DEC21CE at Price : 236.55 and NEW BUY Contract : BANKNIFTY3760002DEC21CE and Price : 236.55
# Entered New SELL Contract : BANKNIFTY3650002DEC21CE at Price : 419.0 and NEW BUY Contract : BANKNIFTY3730002DEC21CE and Price : 130.0
# Stoploss Created at 2021-11-26 10:22:00
# StopLoss Hit at 2021-11-26 10:55:00 .Closed Sell CE Contract : BANKNIFTY3650002DEC21CE at Price 366.3 .Closed Sell PE Contract : BANKNIFTY3660002DEC21PE at Price 619.55
# Closed Buy CE Contract : BANKNIFTY3730002DEC21CE at Price 115.0 .Closed Buy PE Contract : BANKNIFTY3570002DEC21PE at Price 246.1
#
#
#
#
# 2021-12-02 10:00:00
# 09DEC21
# False
# BANKNIFTY3750009DEC21CE
# Entry at 2021-12-02 10:00:00 at a SP of 36300
# Enter First Sell Series CE Contract : BANKNIFTY3750009DEC21CE Price : 108.0 . PE Contract : BANKNIFTY3460009DEC21PE Price : 97.05
# Enter First Buy Series CE Contract : BANKNIFTY3820009DEC21CE Price : 35.3 . PE Contract : BANKNIFTY3310009DEC21PE Price : 30.9
# Adjustment of CE at 2021-12-02 15:01:00
# Exited SELL Contract : BANKNIFTY3460009DEC21PE at Price : 50.0 and NEW BUY Contract : BANKNIFTY3310009DEC21PE and Price : 50.0
# Entered New SELL Contract : BANKNIFTY3510009DEC21PE at Price : 86.55 and NEW BUY Contract : BANKNIFTY3390009DEC21PE and Price : 27.7
# Adjustment of CE at 2021-12-03 09:16:00
# Exited SELL Contract : BANKNIFTY3510009DEC21PE at Price : 68.55 and NEW BUY Contract : BANKNIFTY3390009DEC21PE and Price : 68.55
# Entered New SELL Contract : BANKNIFTY3550009DEC21PE at Price : 116.5 and NEW BUY Contract : BANKNIFTY3450009DEC21PE and Price : 38.0
# Adjustment of CE at 2021-12-03 13:13:00
# Exited SELL Contract : BANKNIFTY3750009DEC21CE at Price : 66.6 and NEW BUY Contract : BANKNIFTY3820009DEC21CE and Price : 66.6
# Entered New SELL Contract : BANKNIFTY3720009DEC21CE at Price : 117.2 and NEW BUY Contract : BANKNIFTY3780009DEC21CE and Price : 40.1
# Adjustment of CE at 2021-12-03 14:16:00
# Exited SELL Contract : BANKNIFTY3720009DEC21CE at Price : 82.05 and NEW BUY Contract : BANKNIFTY3780009DEC21CE and Price : 82.05
# Entered New SELL Contract : BANKNIFTY3690009DEC21CE at Price : 149.1 and NEW BUY Contract : BANKNIFTY3750009DEC21CE and Price : 49.4
# Adjustment of CE at 2021-12-06 09:15:00
# Exited SELL Contract : BANKNIFTY3690009DEC21CE at Price : 103.2 and NEW BUY Contract : BANKNIFTY3750009DEC21CE and Price : 103.2
# Entered New SELL Contract : BANKNIFTY3660009DEC21CE at Price : 280.0 and NEW BUY Contract : BANKNIFTY3720009DEC21CE and Price : 75.3
# Adjustment of CE at 2021-12-06 10:44:00
# Exited SELL Contract : BANKNIFTY3550009DEC21PE at Price : 122.6 and NEW BUY Contract : BANKNIFTY3450009DEC21PE and Price : 122.6
# Entered New SELL Contract : BANKNIFTY3590009DEC21PE at Price : 215.15 and NEW BUY Contract : BANKNIFTY3500009DEC21PE and Price : 68.75
# Adjustment of CE at 2021-12-06 12:23:00
# Exited SELL Contract : BANKNIFTY3660009DEC21CE at Price : 145.75 and NEW BUY Contract : BANKNIFTY3720009DEC21CE and Price : 145.75
# Entered New SELL Contract : BANKNIFTY3630009DEC21CE at Price : 256.9 and NEW BUY Contract : BANKNIFTY3690009DEC21CE and Price : 79.9
# Adjustment of CE at 2021-12-06 14:30:00
# Exited SELL Contract : BANKNIFTY3630009DEC21CE at Price : 177.1 and NEW BUY Contract : BANKNIFTY3690009DEC21CE and Price : 177.1
# Entered New SELL Contract : BANKNIFTY3600009DEC21CE at Price : 304.7 and NEW BUY Contract : BANKNIFTY3660009DEC21CE and Price : 100.6
# Stoploss Created at 2021-12-06 14:30:00
# StopLoss Hit at 2021-12-07 10:42:00 .Closed Sell CE Contract : BANKNIFTY3600009DEC21CE at Price 605.0 .Closed Sell PE Contract : BANKNIFTY3590009DEC21PE at Price 128.9
# Closed Buy CE Contract : BANKNIFTY3660009DEC21CE at Price 236.65 .Closed Buy PE Contract : BANKNIFTY3500009DEC21PE at Price 32.4
#
#
#
#
# 2021-12-09 10:00:00
# 16DEC21
# False
# BANKNIFTY3800016DEC21CE
# Entry at 2021-12-09 10:00:00 at a SP of 37000
# Enter First Sell Series CE Contract : BANKNIFTY3800016DEC21CE Price : 104.15 . PE Contract : BANKNIFTY3580016DEC21PE Price : 95.0
# Enter First Buy Series CE Contract : BANKNIFTY3870016DEC21CE Price : 31.2 . PE Contract : BANKNIFTY3480016DEC21PE Price : 31.3
# Adjustment of CE at 2021-12-09 12:57:00
# Exited SELL Contract : BANKNIFTY3580016DEC21PE at Price : 63.35 and NEW BUY Contract : BANKNIFTY3480016DEC21PE and Price : 63.35
# Entered New SELL Contract : BANKNIFTY3620016DEC21PE at Price : 103.6 and NEW BUY Contract : BANKNIFTY3520016DEC21PE and Price : 32.7
# Adjustment of CE at 2021-12-10 09:15:00
# Exited SELL Contract : BANKNIFTY3800016DEC21CE at Price : 66.9 and NEW BUY Contract : BANKNIFTY3870016DEC21CE and Price : 66.9
# Entered New SELL Contract : BANKNIFTY3760016DEC21CE at Price : 190.0 and NEW BUY Contract : BANKNIFTY3820016DEC21CE and Price : 60.0
# Adjustment of CE at 2021-12-10 14:46:00
# Exited SELL Contract : BANKNIFTY3620016DEC21PE at Price : 84.55 and NEW BUY Contract : BANKNIFTY3520016DEC21PE and Price : 84.55
# Entered New SELL Contract : BANKNIFTY3650016DEC21PE at Price : 138.65 and NEW BUY Contract : BANKNIFTY3580016DEC21PE and Price : 47.55
# Adjustment of CE at 2021-12-13 09:15:00
# Exited SELL Contract : BANKNIFTY3650016DEC21PE at Price : 71.9 and NEW BUY Contract : BANKNIFTY3580016DEC21PE and Price : 71.9
# Entered New SELL Contract : BANKNIFTY3710016DEC21PE at Price : 259.0 and NEW BUY Contract : BANKNIFTY3650016DEC21PE and Price : 97.55
# Adjustment of CE at 2021-12-13 09:43:00
# Exited SELL Contract : BANKNIFTY3710016DEC21PE at Price : 145.15 and NEW BUY Contract : BANKNIFTY3650016DEC21PE and Price : 145.15
# Entered New SELL Contract : BANKNIFTY3740016DEC21PE at Price : 269.0 and NEW BUY Contract : BANKNIFTY3680016DEC21PE and Price : 92.7
# Adjustment of CE at 2021-12-13 12:24:00
# Exited SELL Contract : BANKNIFTY3760016DEC21CE at Price : 190.75 and NEW BUY Contract : BANKNIFTY3820016DEC21CE and Price : 190.75
# Entered New SELL Contract : BANKNIFTY3730016DEC21CE at Price : 323.35 and NEW BUY Contract : BANKNIFTY3790016DEC21CE and Price : 103.3
# Stoploss Created at 2021-12-13 12:24:00
# StopLoss Hit at 2021-12-13 15:04:00 .Closed Sell CE Contract : BANKNIFTY3730016DEC21CE at Price 178.2 .Closed Sell PE Contract : BANKNIFTY3740016DEC21PE at Price 597.7
# Closed Buy CE Contract : BANKNIFTY3790016DEC21CE at Price 50.95 .Closed Buy PE Contract : BANKNIFTY3680016DEC21PE at Price 263.25
#
#
#
#
# 2021-12-16 10:00:00
# 23DEC21
# False
# BANKNIFTY3790023DEC21CE
# Entry at 2021-12-16 10:00:00 at a SP of 36900
# Enter First Sell Series CE Contract : BANKNIFTY3790023DEC21CE Price : 104.9 . PE Contract : BANKNIFTY3580023DEC21PE Price : 100.55
# Enter First Buy Series CE Contract : BANKNIFTY3860023DEC21CE Price : 31.15 . PE Contract : BANKNIFTY3490023DEC21PE Price : 32.7
# Adjustment of CE at 2021-12-16 11:59:00
# Exited SELL Contract : BANKNIFTY3790023DEC21CE at Price : 71.0 and NEW BUY Contract : BANKNIFTY3860023DEC21CE and Price : 71.0
# Entered New SELL Contract : BANKNIFTY3760023DEC21CE at Price : 118.05 and NEW BUY Contract : BANKNIFTY3830023DEC21CE and Price : 38.0
# Adjustment of CE at 2021-12-16 14:38:00
# Exited SELL Contract : BANKNIFTY3760023DEC21CE at Price : 82.05 and NEW BUY Contract : BANKNIFTY3830023DEC21CE and Price : 82.05
# Entered New SELL Contract : BANKNIFTY3730023DEC21CE at Price : 141.45 and NEW BUY Contract : BANKNIFTY3800023DEC21CE and Price : 43.2
# Adjustment of CE at 2021-12-17 09:15:00
# Exited SELL Contract : BANKNIFTY3730023DEC21CE at Price : 88.8 and NEW BUY Contract : BANKNIFTY3800023DEC21CE and Price : 88.8
# Entered New SELL Contract : BANKNIFTY3700023DEC21CE at Price : 239.95 and NEW BUY Contract : BANKNIFTY3760023DEC21CE and Price : 89.45
# Adjustment of CE at 2021-12-17 09:28:00
# Exited SELL Contract : BANKNIFTY3700023DEC21CE at Price : 110.0 and NEW BUY Contract : BANKNIFTY3760023DEC21CE and Price : 110.0
# Entered New SELL Contract : BANKNIFTY3670023DEC21CE at Price : 186.7 and NEW BUY Contract : BANKNIFTY3730023DEC21CE and Price : 67.0
# Adjustment of CE at 2021-12-17 09:56:00
# Exited SELL Contract : BANKNIFTY3670023DEC21CE at Price : 148.95 and NEW BUY Contract : BANKNIFTY3730023DEC21CE and Price : 148.95
# Entered New SELL Contract : BANKNIFTY3630023DEC21CE at Price : 289.8 and NEW BUY Contract : BANKNIFTY3700023DEC21CE and Price : 94.6
# Adjustment of CE at 2021-12-17 12:09:00
# Exited SELL Contract : BANKNIFTY3630023DEC21CE at Price : 193.55 and NEW BUY Contract : BANKNIFTY3700023DEC21CE and Price : 193.55
# Entered New SELL Contract : BANKNIFTY3600023DEC21CE at Price : 321.6 and NEW BUY Contract : BANKNIFTY3670023DEC21CE and Price : 108.4
# Adjustment of CE at 2021-12-17 15:01:00
# Exited SELL Contract : BANKNIFTY3600023DEC21CE at Price : 242.65 and NEW BUY Contract : BANKNIFTY3670023DEC21CE and Price : 242.65
# Entered New SELL Contract : BANKNIFTY3560023DEC21CE at Price : 437.0 and NEW BUY Contract : BANKNIFTY3640023DEC21CE and Price : 142.85
# Stoploss Created at 2021-12-17 15:01:00
# StopLoss Hit at 2021-12-20 09:15:00 .Closed Sell CE Contract : BANKNIFTY3560023DEC21CE at Price 180.25 .Closed Sell PE Contract : BANKNIFTY3580023DEC21PE at Price 866.05
# Closed Buy CE Contract : BANKNIFTY3640023DEC21CE at Price 44.0 .Closed Buy PE Contract : BANKNIFTY3490023DEC21PE at Price 349.3
#
#
#
#
# 2021-12-23 10:00:00
# DEC21
# True
# BANKNIFTY36100DEC21CE
# Entry at 2021-12-23 10:00:00 at a SP of 35200
# Enter First Sell Series CE Contract : BANKNIFTY36100DEC21CE Price : 104.0 . PE Contract : BANKNIFTY34100DEC21PE Price : 99.55
# Enter First Buy Series CE Contract : BANKNIFTY36900DEC21CE Price : 33.45 . PE Contract : BANKNIFTY33200DEC21PE Price : 33.25
# Adjustment of CE at 2021-12-23 12:31:00
# Exited SELL Contract : BANKNIFTY34100DEC21PE at Price : 70.25 and NEW BUY Contract : BANKNIFTY33200DEC21PE and Price : 70.25
# Entered New SELL Contract : BANKNIFTY34500DEC21PE at Price : 118.85 and NEW BUY Contract : BANKNIFTY33600DEC21PE and Price : 42.1
# Adjustment of CE at 2021-12-23 15:23:00
# Exited SELL Contract : BANKNIFTY36100DEC21CE at Price : 71.2 and NEW BUY Contract : BANKNIFTY36900DEC21CE and Price : 71.2
# Entered New SELL Contract : BANKNIFTY35800DEC21CE at Price : 136.6 and NEW BUY Contract : BANKNIFTY36400DEC21CE and Price : 43.6
# Adjustment of CE at 2021-12-24 09:33:00
# Exited SELL Contract : BANKNIFTY35800DEC21CE at Price : 103.4 and NEW BUY Contract : BANKNIFTY36400DEC21CE and Price : 103.4
# Entered New SELL Contract : BANKNIFTY35500DEC21CE at Price : 184.45 and NEW BUY Contract : BANKNIFTY36100DEC21CE and Price : 60.0
# Adjustment of CE at 2021-12-24 09:42:00
# Exited SELL Contract : BANKNIFTY35500DEC21CE at Price : 145.45 and NEW BUY Contract : BANKNIFTY36100DEC21CE and Price : 145.45
# Entered New SELL Contract : BANKNIFTY35200DEC21CE at Price : 247.05 and NEW BUY Contract : BANKNIFTY35900DEC21CE and Price : 75.2
# Adjustment of CE at 2021-12-24 14:15:00
# Exited SELL Contract : BANKNIFTY34500DEC21PE at Price : 155.65 and NEW BUY Contract : BANKNIFTY33600DEC21PE and Price : 155.65
# Entered New SELL Contract : BANKNIFTY34800DEC21PE at Price : 249.15 and NEW BUY Contract : BANKNIFTY34000DEC21PE and Price : 84.7
# Adjustment of CE at 2021-12-27 09:15:00
# Exited SELL Contract : BANKNIFTY35200DEC21CE at Price : 86.15 and NEW BUY Contract : BANKNIFTY35900DEC21CE and Price : 86.15
# Entered New SELL Contract : BANKNIFTY34200DEC21CE at Price : 627.15 and NEW BUY Contract : BANKNIFTY34900DEC21CE and Price : 344.0
# Stoploss Created at 2021-12-27 09:15:00
# StopLoss Hit at 2021-12-27 09:16:00 .Closed Sell CE Contract : BANKNIFTY34200DEC21CE at Price 490.35 .Closed Sell PE Contract : BANKNIFTY34800DEC21PE at Price 607.55
# Closed Buy CE Contract : BANKNIFTY34900DEC21CE at Price 158.55 .Closed Buy PE Contract : BANKNIFTY34000DEC21PE at Price 236.6

# %%
FirstBuyCEActiveContract
# Out:
# 'BANKNIFTY34900DEC21CE'

# %%
(tdayTime + timedelta(days=1)).date() in HolidayDateList
# Out:
# False

# %%
Orders
# Out:
#       entry                   type          entry_time            exittime  \
# 0        -1                     PE 2020-01-02 10:00:00 2020-01-02 12:14:00
# 1         1                     PE 2020-01-02 10:00:00 2020-01-02 12:14:00
# 2        -1                     PE 2020-01-02 12:14:00 2020-01-02 14:23:00
# 3         1                     PE 2020-01-02 12:14:00 2020-01-02 14:23:00
# 4        -1                     CE 2020-01-02 10:00:00 2020-01-03 09:30:00
# ...     ...                    ...                 ...                 ...
# 1643      1                     CE 2021-12-24 09:42:00 2021-12-27 09:15:00
# 1644     -1  BANKNIFTY34200DEC21CE 2021-12-27 09:15:00 2021-12-27 09:16:00
# 1645     -1  BANKNIFTY34800DEC21PE 2021-12-24 14:15:00 2021-12-27 09:16:00
# 1646      1  BANKNIFTY34900DEC21CE 2021-12-27 09:15:00 2021-12-27 09:16:00
# 1647      1  BANKNIFTY34000DEC21PE 2021-12-24 14:15:00 2021-12-27 09:16:00
#
#       entry_value  exitvalue exit_type     SP      dd  BasketID  \
# 0           94.90      71.85       Adj  32200   -6.35         1
# 1           30.50      23.45       Adj     UP   -7.25         1
# 2          126.75      92.90       Adj  32200  -13.25         1
# 3           42.20      31.25       Adj     UP  -10.95         1
# 4          108.55     119.00       Adj  32200 -108.45         1
# ...           ...        ...       ...    ...     ...       ...
# 1643        75.20      23.10       Adj     UP  -53.15       101
# 1644       627.15     490.35        SL  35200 -431.25       101
# 1645       249.15     607.55        SL  35200 -431.25       101
# 1646       344.00     158.55        SL  35200 -202.00       101
# 1647        84.70     236.60        SL  35200   78.75       101
#
#                  ContractName  LS
# 0     BANKNIFTY3190009JAN20PE   1
# 1     BANKNIFTY3150009JAN20PE   1
# 2     BANKNIFTY3210009JAN20PE   1
# 3     BANKNIFTY3170009JAN20PE   1
# 4     BANKNIFTY3250009JAN20CE   1
# ...                       ...  ..
# 1643    BANKNIFTY35900DEC21CE   1
# 1644    BANKNIFTY34200DEC21CE   1
# 1645    BANKNIFTY34800DEC21PE   1
# 1646    BANKNIFTY34900DEC21CE   1
# 1647    BANKNIFTY34000DEC21PE   1
#
# [1648 rows x 12 columns]

# %%
EntryWeekDay
# Out:
# 2

# %%
checkLastThrusday(tdayTime,  NextExpiry)
# Out:
# True

# %%
tdayTime
# Out:
# datetime.datetime(2020, 4, 23, 10, 0)

# %%
tdayTime
# Out:
# datetime.datetime(2020, 4, 15, 10, 0)

# %%
StrExpiry
# Out:
# '23APR20'

# %%
# Out:
# BANKNIFTY2350019MAR20PE 199.0
# BANKNIFTY2400019MAR20PE 187.60000000000002

# %%
SELLPEActiveContract
# Out:
# 'BANKNIFTY2400019MAR20PE'

# %%
SELLPEActiveContractPrice
# Out:
# 287.6

# %%
data.loc[:tdayTime]
# Out:
#                          open      high       low     close volume
# datetime
# 2019-11-18 09:15:00  31036.80  31138.75  31036.25  31133.70      0
# 2019-11-18 09:16:00  31123.95  31143.10  31117.50  31140.65      0
# 2019-11-18 09:17:00  31139.90  31152.50  31132.45  31141.10      0
# 2019-11-18 09:18:00  31140.75  31161.25  31116.80  31149.25      0
# 2019-11-18 09:19:00  31144.15  31158.70  31134.60  31140.40      0
# ...                       ...       ...       ...       ...    ...
# 2020-04-15 09:56:00  19969.35  19969.35  19906.05  19915.35      0
# 2020-04-15 09:57:00  19915.45  19938.55  19911.15  19923.70      0
# 2020-04-15 09:58:00  19922.55  19954.90  19920.30  19950.40      0
# 2020-04-15 09:59:00  19950.70  19978.80  19944.30  19971.30      0
# 2020-04-15 10:00:00  19973.50  20007.30  19971.75  20001.95      0
#
# [37919 rows x 5 columns]

# %%
SELLPEActiveContract , SELLPEActiveContractPrice = getContractBySP_backfilled(Price, tdayTime, StrExpiry,'PE',path, LastThrus)
# Out:
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2350019MAR20PE.csv
# BANKNIFTY2350019MAR20PE 199.0
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2450019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2480019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2500019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2530019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2550019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2570019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2580019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2590019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2600019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2610019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2620019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2630019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2640019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2650019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2660019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2670019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2690019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2700019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2720019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2750019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2790019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2800019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2850019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2860019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2880019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2900019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY2950019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY3000019MAR20PE.csv
# C:\Users\soura\Documents\PythonTrading\BacktestResult\OptionSrategy\IndianOptionBackFilled\2020_new\BANKNIFTY3050019MAR20PE.csv

# %%
SELLPEActiveContract
# Out:
# 'BANKNIFTY2400019MAR20PE'

# %%
list(CEPEdf.columns) + [f'open{NewSELLCEActiveContract}', f'high{NewSELLCEActiveContract}', f'low{NewSELLCEActiveContract}', f'close{NewSELLCEActiveContract}',\
f'open{NewFirstBuyCEActiveContract}', f'high{NewFirstBuyCEActiveContract}',f'low{NewFirstBuyCEActiveContract}', f'close{NewFirstBuyCEActiveContract}']
# Out:
# ['datetime',
#  'openBANKNIFTY3310014JAN21CE',
#  'highBANKNIFTY3310014JAN21CE',
#  'lowBANKNIFTY3310014JAN21CE',
#  'closeBANKNIFTY3310014JAN21CE',
#  'openBANKNIFTY3100014JAN21PE',
#  'highBANKNIFTY3100014JAN21PE',
#  'lowBANKNIFTY3100014JAN21PE',
#  'closeBANKNIFTY3100014JAN21PE',
#  'openBANKNIFTY3380014JAN21CE',
#  'highBANKNIFTY3380014JAN21CE',
#  'lowBANKNIFTY3380014JAN21CE',
#  'closeBANKNIFTY3380014JAN21CE',
#  'openBANKNIFTY3010014JAN21PE',
#  'highBANKNIFTY3010014JAN21PE',
#  'lowBANKNIFTY3010014JAN21PE',
#  'closeBANKNIFTY3010014JAN21PE',
#  'openSpot',
#  'highSpot',
#  'lowSpot',
#  'closeSpot',
#  'volumeSpot',
#  'open_x',
#  'high_x',
#  'low_x',
#  'close_x',
#  'open_y',
#  'high_y',
#  'low_y',
#  'close_y',
#  'openBANKNIFTY3290014JAN21CE',
#  'highBANKNIFTY3290014JAN21CE',
#  'lowBANKNIFTY3290014JAN21CE',
#  'closeBANKNIFTY3290014JAN21CE',
#  'openBANKNIFTY3340014JAN21CE',
#  'highBANKNIFTY3340014JAN21CE',
#  'lowBANKNIFTY3340014JAN21CE',
#  'closeBANKNIFTY3340014JAN21CE']

# %%
CEPEdf
# Out:
#                 datetime  openBANKNIFTY3310014JAN21CE  \
# 0    2021-01-07 10:00:00                        99.40
# 1    2021-01-07 10:01:00                        99.50
# 2    2021-01-07 10:03:00                        99.85
# 3    2021-01-07 10:04:00                        98.00
# 4    2021-01-07 10:06:00                        93.00
# ...                  ...                          ...
# 2086 2021-01-14 15:25:00                         0.15
# 2087 2021-01-14 15:26:00                         0.20
# 2088 2021-01-14 15:27:00                         0.15
# 2089 2021-01-14 15:28:00                         0.15
# 2090 2021-01-14 15:29:00                         0.20
#
#       highBANKNIFTY3310014JAN21CE  lowBANKNIFTY3310014JAN21CE  \
# 0                          100.00                       99.40
# 1                          100.60                       99.50
# 2                           99.85                       99.60
# 3                           98.00                       95.70
# 4                           94.50                       92.85
# ...                           ...                         ...
# 2086                         0.20                        0.10
# 2087                         0.20                        0.10
# 2088                         0.15                        0.10
# 2089                         0.15                        0.10
# 2090                         0.20                        0.10
#
#       closeBANKNIFTY3310014JAN21CE  openBANKNIFTY3100014JAN21PE  \
# 0                           100.00                       105.05
# 1                            99.85                       101.85
# 2                            99.60                       103.00
# 3                            96.10                       101.85
# 4                            94.00                       105.40
# ...                            ...                          ...
# 2086                          0.15                         0.10
# 2087                          0.10                         0.05
# 2088                          0.15                         0.10
# 2089                          0.10                         0.10
# 2090                          0.10                         0.05
#
#       highBANKNIFTY3100014JAN21PE  lowBANKNIFTY3100014JAN21PE  \
# 0                          105.10                      101.50
# 1                          103.00                      101.60
# 2                          103.00                      100.15
# 3                          105.00                      101.35
# 4                          108.00                      105.00
# ...                           ...                         ...
# 2086                         0.20                        0.05
# 2087                         0.15                        0.05
# 2088                         0.15                        0.05
# 2089                         0.15                        0.05
# 2090                         0.10                        0.05
#
#       closeBANKNIFTY3100014JAN21PE  openBANKNIFTY3380014JAN21CE  ...  \
# 0                           101.50                        33.35  ...
# 1                           101.85                        33.50  ...
# 2                           101.80                        32.75  ...
# 3                           103.15                        32.55  ...
# 4                           106.35                        31.00  ...
# ...                            ...                          ...  ...
# 2086                          0.10                         0.10  ...
# 2087                          0.10                         0.10  ...
# 2088                          0.05                         0.15  ...
# 2089                          0.05                         0.10  ...
# 2090                          0.05                         0.10  ...
#
#       closeSpot  volumeSpot  open_x  high_x   low_x  close_x  open_y  high_y  \
# 0      32051.20           0  138.95  138.95  138.95   138.95   59.95   59.95
# 1      32052.25           0  137.80  137.80  137.80   137.80   59.70   60.15
# 2      32044.20           0  138.00  138.00  136.60   136.60   60.20   60.20
# 3      32016.50           0  135.00  135.40  135.00   135.40   59.05   59.25
# 4      31994.75           0  130.00  131.40  129.15   129.75   57.50   57.75
# ...         ...         ...     ...     ...     ...      ...     ...     ...
# 2086   32553.50           0    0.10    0.15    0.05     0.05    0.05    0.15
# 2087   32555.15           0    0.05    0.15    0.05     0.05    0.05    0.15
# 2088   32566.75           0    0.10    0.10    0.05     0.05    0.10    0.10
# 2089   32560.70           0    0.05    0.05    0.05     0.05    0.15    0.15
# 2090   32569.60           0    0.10    0.10    0.05     0.05    0.05    0.15
#
#       low_y  close_y
# 0     59.55    59.55
# 1     59.70    60.15
# 2     59.70    59.70
# 3     57.65    57.65
# 4     56.00    56.60
# ...     ...      ...
# 2086   0.05     0.15
# 2087   0.05     0.15
# 2088   0.05     0.05
# 2089   0.05     0.05
# 2090   0.05     0.10
#
# [2091 rows x 30 columns]

# %% [markdown]
# ## Performance Metrics

# %%
class backtesting_final_per_pos:
    
    def __init__(self, ticker, df,lotsize,commstr, filename,size):
        self.filename = filename


        
        self.symbol = ticker
        self.df = df
        self.per = lotsize
        self.str = commstr   # Yes for commission and no without commission
        #self.pip , self.qty = self.DataAcessPipQuantityDropBox(self.symbol)
        self.size = size
        self.pip , self.qty = 1,15
        self.trades = self.df.copy()
        #self.trades.to_csv('cc.csv')
        #self.trades = self.trades.dropna()
        #self.trades = self.trades.sort_values(by='entry_time')
        self.td = self.analysis(self.trades)
        self.longwinper = self.long_win()
        self.sharpe = self.sharperatio()
        #self.backtest_reports_local()
        self.run()
        

    def run(self):
        fig1 = self.backtest_reports_local()
        trades = self.finalreport()
        with open(f'{self.filename}_{self.symbol}_Performance.txt', 'r') as txt_file:
            txt_content = txt_file.read()
            
        html_content = f"<pre>{txt_content}</pre>"
        #fig2 = self.RandomTradesShuffleSimultion()
        #fig3 = self.RandomTradesRemovalSimulation(0.2)
        fig4 = self.HoldingTimeScatterPlot()
        fig5 , fig6 = self.Hour_Day_Analysis()
        #fig7 = self.Monthlyreturns()
        trades_html = trades.to_html(index=False)

        with open(f'{self.filename}_{self.symbol}_Performance.html', 'a') as f:
            f.write("<h2>Performance of The Strategy</h2>\n")
            f.write(html_content)
            f.write("<h2>Metrics of The Strategy</h2>\n")
            f.write(fig1.to_html(full_html=False, include_plotlyjs='cdn'))
            #f.write(fig2.to_html(full_html=False, include_plotlyjs='cdn'))
            #f.write(fig3.to_html(full_html=False, include_plotlyjs='cdn'))
            f.write(fig4.to_html(full_html=False, include_plotlyjs='cdn'))
            f.write(fig5.to_html(full_html=False, include_plotlyjs='cdn'))
            f.write(fig6.to_html(full_html=False, include_plotlyjs='cdn'))
            f.write("<h2>Trades Data</h2>\n")  # Add a heading for the CSV data (optional)
            f.write(trades_html)
            #f.write(fig7.to_html(full_html=False, include_plotlyjs='cdn'))
    
    def DataAcessPipQuantityDropBox(self,symbol ):
        print('step2')
        # Access Pip and Quantity
       
        df_cal = pd.read_csv('https://www.dropbox.com/s/r4f8cmb9jkv6g6n/PipVAlue.csv?dl=1',encoding = 'utf-8')
        import ast
        for i in range(len(df_cal)):
            if df_cal.iloc[i]['Links'].find('nan') < 0:
                df_cal['Links'][i] = ast.literal_eval(df_cal['Links'][i].replace('[','').replace(']',''))

        PIP = df_cal['PipValue'].where(df_cal['INS_Name'] == symbol).dropna()
        PIP = PIP[PIP.index[0]]

        Quant = df_cal['Quantity'].where(df_cal['INS_Name'] == symbol).dropna()
        Quant = Quant[Quant.index[0]]

        return PIP , Quant

        
        
        
    
       
    def analysis(self , trades):
        
        #print(trades)
        
        #print(trades)
        trades["returns"] = None
        trades['returns_abs'] = None
        trades['returns_dd'] = None
        trades['per_dd'] = None
        trades['lot_size'] = 1
        trades['pips'] = None
        trades['commision'] = 0
        trades['MarginRequired'] = 0
        trades.reset_index(drop=True,inplace=True)
        #print(trades)
        #trades['returns'].values[0] = 100
        #print(trades['returns'].values[0])
       
        
        for i in range(len(trades)):
            #print(trades.iloc[i])
            #commission 
            if self.str == 'Yes':
                commision = 2
                MarginRequired = trades.iloc[i]["entry_value"] * self.per
                if i == 0:
                    
                    trades['lot_size'].values[i] = self.per
                    if(trades['entry'].values[i] == 1):
                        trades.loc[i,"returns"]=(trades.iloc[i]["exitvalue"] - trades.iloc[i]["entry_value"])* self.pip * trades.iloc[i]['lot_size'] * self.qty  - commision
                        trades.loc[i,"pips"]=(trades.iloc[i]["exitvalue"] - trades.iloc[i]["entry_value"])
                        
                    else:
                        trades.loc[i,"returns"]=(trades.iloc[i]["entry_value"] - trades.iloc[i]["exitvalue"])* self.pip * trades.iloc[i]['lot_size'] * self.qty   - commision
                        trades.loc[i,"pips"]=(trades.iloc[i]["entry_value"] - trades.iloc[i]["exitvalue"])
                    trades.loc[i,'returns_abs'] = self.size + trades.iloc[i]["returns"]
                    trades.loc[i , 'commision'] = commision
                    trades.loc[i , 'MarginRequired'] = MarginRequired
                else:
                    trades['lot_size'].values[i] = self.per
                    if(trades['entry'].values[i] == 1):
                        trades.loc[i,"returns"]=(trades.iloc[i]["exitvalue"] - trades.iloc[i]["entry_value"])* self.pip * trades.iloc[i]['lot_size'] * self.qty  - commision
                        trades.loc[i,"pips"]=(trades.iloc[i]["exitvalue"] - trades.iloc[i]["entry_value"])
                    else:
                        trades.loc[i,"returns"]=(trades.iloc[i]["entry_value"] - trades.iloc[i]["exitvalue"])* self.pip * trades.iloc[i]['lot_size'] * self.qty  - commision
                        trades.loc[i,"pips"]=(trades.iloc[i]["entry_value"] - trades.iloc[i]["exitvalue"])
                    trades.loc[i,'returns_abs'] = trades.iloc[i-1]['returns_abs'] + trades.iloc[i]['returns']
                    trades.loc[i , 'commision'] = commision
                    trades.loc[i , 'MarginRequired'] = MarginRequired

            
           #without comissiom
            elif self.str == 'No':
                #commision = calculate_stock_holding_commision(trades.iloc[i]["entry_value"] , trades.iloc[i]["exitvalue"], self.per)
                commision = 60
                MarginRequired = trades.iloc[i]["entry_value"] * self.per * self.qty
                if i == 0:
                    
                    
                    trades['lot_size'].values[i] = self.per
                    if(trades['entry'].values[i] == 1):
                        trades.loc[i,"returns"]=(trades.iloc[i]["exitvalue"] - trades.iloc[i]["entry_value"])* self.pip * trades.iloc[i]['lot_size'] * self.qty  - commision
                        trades.loc[i,"pips"]=(trades.iloc[i]["exitvalue"] - trades.iloc[i]["entry_value"])
                        
                    else:
                        trades.loc[i,"returns"]=(trades.iloc[i]["entry_value"] - trades.iloc[i]["exitvalue"])* self.pip * trades.iloc[i]['lot_size'] * self.qty   - commision
                        trades.loc[i,"pips"]=(trades.iloc[i]["entry_value"] - trades.iloc[i]["exitvalue"])
                    trades.loc[i,'returns_abs'] = self.size + trades.iloc[i]["returns"]
                    trades.loc[i , 'commision'] = commision
                    trades.loc[i , 'MarginRequired'] = MarginRequired
                else:
                    trades['lot_size'].values[i] = self.per
                    if(trades['entry'].values[i] == 1):
                        trades.loc[i,"returns"]=(trades.iloc[i]["exitvalue"] - trades.iloc[i]["entry_value"])* self.pip * trades.iloc[i]['lot_size'] * self.qty  - commision
                        trades.loc[i,"pips"]=(trades.iloc[i]["exitvalue"] - trades.iloc[i]["entry_value"])
                    else:
                        trades.loc[i,"returns"]=(trades.iloc[i]["entry_value"] - trades.iloc[i]["exitvalue"])* self.pip * trades.iloc[i]['lot_size'] * self.qty  - commision
                        trades.loc[i,"pips"]=(trades.iloc[i]["entry_value"] - trades.iloc[i]["exitvalue"])
                    trades.loc[i,'returns_abs'] = trades.iloc[i-1]['returns_abs'] + trades.iloc[i]['returns']
                    trades.loc[i , 'commision'] = commision
                    trades.loc[i , 'MarginRequired'] = MarginRequired
        
        


        

        trades.loc[0,'returns_dd'] = abs(trades.iloc[0]["dd"]* self.pip * trades.iloc[0]['lot_size'] *self.qty)
        for i in range(1,len(trades)):

            trades.loc[i,'returns_dd'] = abs(trades.iloc[i]['dd']* self.pip * trades.iloc[i]['lot_size'] *self.qty)

        trades.loc[0,'per_dd'] = (trades.iloc[0]["returns_dd"]/self.size )*100
        for i in range(1,len(trades)):

            trades.loc[i,'per_dd'] = (trades.iloc[i]["returns_dd"]/trades.iloc[i-1]["returns_abs"])*100 


        trades['dd'] = trades['dd']*self.qty * trades['lot_size']
        #trades['Duration'] = trades.iloc[:]['exittime'] - trades.iloc[:]['entry_time']
    
        return trades
        


    def long_win(self):
    
        long_df = self.td[self.td['entry'] == 1]
        long_df
        #print(long_df[long_df.returns>0]['returns'].count()/long_df['entry'].count())
        return(round((long_df[long_df.returns>0]['returns'].count()/long_df['entry'].count()) * 100,2))
    
    
    def finalreport(self):
        
        trades = self.td[['type','entry_time','exittime','entry_value','exitvalue','entry','lot_size','pips','returns','returns_abs','exit_type','SP','dd','per_dd','ContractName','BasketID','commision','MarginRequired']].copy()

        trades.rename(columns = {'entry_value':'Entryvalue'}, inplace = True)
        trades.rename(columns = {'returns':'PnL'}, inplace = True)
        trades.rename(columns = {'returns_abs':'Equity'}, inplace = True)

        trades['entry'] = trades['entry'].replace([1,-1],['Long','Short'])
        #trades['dd'] = trades['dd'] * self.qty
        trades['Duration'] = trades['exittime'] - trades['entry_time']
        trades.to_csv(f'{self.filename}_{self.symbol}_trades.csv',index = False)

        return trades#.to_string(index=False)
    
    # Assume an average annual risk-free rate is 1%
    def sharperatio(self):
        risk_free_rate = 0.05/252

        sharpe_ratio = (np.mean(self.td.returns) -
                           (risk_free_rate))/np.std(self.td.returns)
        return sharpe_ratio
    


    def backtest_reports_local(self):
        df_summary = self.td.copy()

        basketReturns = pd.DataFrame(columns=['returns' , 'Orders'])
        for i in df_summary.BasketID.unique():
            Bdf = df_summary[df_summary.BasketID == i]
            
            basketReturns.loc[i, 'returns'] = Bdf.returns.sum()
            basketReturns.loc[i, 'Orders'] = Bdf.returns.count() -2
            exitType = Bdf.exit_type.unique()
            for j in exitType:
                if j == 'DEAdj':
                    continue
                else:
                    exitValue = j
                    
            
            basketReturns.loc[i, 'ExitType'] = exitValue
            
            #print('\n')
            
            #print(Bdf.iloc[-1])

        BasketWinPer = (len(basketReturns[basketReturns.returns >0]) / len(basketReturns)) * 100
        BasketAvgWin = basketReturns[basketReturns.returns >0].returns.mean()
        BasketAvgLoss = basketReturns[basketReturns.returns <0].returns.mean()
        AvgAdjustetment = basketReturns.Orders.mean()
        MaxAdjustment = basketReturns.Orders.max()

        TPExitwinPer = (len(basketReturns[basketReturns.ExitType == 'TP']) / len(basketReturns)) * 100
        BBExitwinPer = (len(basketReturns[basketReturns.ExitType == 'BBExit']) / len(basketReturns)) * 100
        BAExitwinPer = (len(basketReturns[basketReturns.ExitType == 'BAExit']) / len(basketReturns)) * 100
        EXPExitwinPer = (len(basketReturns[basketReturns.ExitType == 'Exp']) / len(basketReturns)) * 100
        df_summary.set_index('entry_time', inplace=True)
  
        
        #print(df_summary)
        print("Number of trades: ", df_summary['entry'].count())
        print(f"Total No of Basket : {len(basketReturns)}")
        #print("Number of positions: ", len(df_summary[df_summary['exittype'] == 'SL']))
        #print(f'Total No of Basket : {TotalBakset}')
        print("Win percentage: ", round((df_summary[df_summary.returns>0]['returns'].count()/df_summary['entry'].count()) * 100,2))
        print(f'Win Percentage of Bakset {BasketWinPer} ')
        print(f"TP Exit  Percentage : {TPExitwinPer}")
        print(f"BreakPoint Above Exit Percentage : {BAExitwinPer}")
        print(f"BreakPoint Below Exit Percentage : {BBExitwinPer}")
        print(f"Expiry Exit Percentage : {EXPExitwinPer}")
        #print(f"Basket Win Percentage : {round( (winTradesCount/(winTradesCount+lossTradesCount)) * 100,2  ) }")
        print("Net PnL: ", round(df_summary['returns'].sum(),2))
        #print("Average PnL: ", round(df_summary['returns'].mean(),2))
        print("No of winning trades: ", df_summary[df_summary.returns>0]['returns'].count())
        #print(f'No of Winning Basket : {winTradesCount}')
        print("No of losing trades:", df_summary[df_summary.returns<0]['returns'].count())
        #print(f"No of Losing Basket : {lossTradesCount}")

        print("Win % of Long trades: ", self.longwinper)
        
        short_df = df_summary[df_summary['entry'] == -1]
        #print("Number of short trades: ", df_summary[df_summary.entry == -1]['entry'].count())
        print("Win % of Short trades: ",round((short_df[short_df.returns>0]['returns'].count()/short_df['entry'].count()) * 100,2))

        print("Final Balance($): ", round(df_summary['returns_abs'].values[-1],2))
        print("Average_gain(pips): ", round(df_summary[df_summary.pips>0]['pips'].mean(),2))
        print("Average_loss(pips): ", round(df_summary[df_summary.pips<0]['pips'].mean(),2))
        print("Average_gain($): ", round(df_summary[df_summary.returns>0]['returns'].mean(),2))
        print("Average_loss($): ", round(df_summary[df_summary.returns<0]['returns'].mean(),2))
        print(f"Avergain Gain of a Basket : {BasketAvgWin} ")
        print(f"Avergain Loss of a Basket : {BasketAvgLoss} ")
        
        print(f"Avg Adjustment of the Basket : {AvgAdjustetment}")
        print(f"Max Adjustment of the Basket : {MaxAdjustment}")
        print("Profit factor: ", abs(round((df_summary[df_summary.returns>0]['returns'].sum())/(df_summary[df_summary.returns<0]['returns'].sum()),2)))
        print("Sharpe ratio: ", round(self.sharpe,2))
        with open(f'{self.filename}_{self.symbol}_Performance.txt', 'a') as f:
            f.write(f"Number of trades : {df_summary['entry'].count()}\n")
            f.write(f"Total No of Basket : {len(basketReturns)}\n")
            #f.write(f'Total No of Basket : {TotalBakset}\n')
            f.write(f"Win percentage : { round((df_summary[df_summary.returns>0]['returns'].count()/df_summary['entry'].count()) * 100,2)}\n")
            f.write(f'Win Percentage of Bakset {BasketWinPer} \n')
            f.write(f"TP Exit  Percentage : {TPExitwinPer} \n")
            f.write(f"BreakPoint Above Exit Percentage : {BAExitwinPer} \n")
            f.write(f"BreakPoint Below Exit Percentage : {BBExitwinPer} \n")
            f.write(f"Expiry Exit Percentage : {EXPExitwinPer} \n")
            #f.write(f"Basket Win Percentage : {round( (winTradesCount/(winTradesCount+lossTradesCount)) * 100,2  ) }\n")
            f.write(f"Net PnL : {round(df_summary['returns'].sum(),2)}\n")
            f.write(f"No of winning trades : {df_summary[df_summary.returns>0]['returns'].count()}\n")
            #f.write(f'No of Winning Basket : {winTradesCount}\n')
            f.write(f"No of losing trades : {df_summary[df_summary.returns<0]['returns'].count()}\n")
            #f.write(f"No of Losing Basket : {lossTradesCount}\n")
            f.write(f"Win % of Long trades : {self.longwinper}\n")
            f.write(f"Win % of Short trades : {round((short_df[short_df.returns>0]['returns'].count()/short_df['entry'].count()) * 100,2)}\n")
            f.write(f"Final Balance($) : {round(df_summary['returns_abs'].values[-1],2)}\n")
            f.write(f"Average_gain(pips) : { round(df_summary[df_summary.returns>0]['returns'].mean(),2)}\n")
            f.write(f"Average_loss(pip) : { round(df_summary[df_summary.returns<0]['returns'].mean(),2)}\n")
            f.write(f"Average_gain($) : {round(df_summary[df_summary.pips<0]['pips'].mean(),2)}\n")
            f.write(f"Average_loss($) : {round(df_summary[df_summary.returns<0]['returns'].mean(),2)}\n")
            f.write(f"Avergain Gain of a Basket : {BasketAvgWin} \n")
            f.write(f"Avergain Loss of a Basket : {BasketAvgLoss} \n")
            #f.write(f"Avg Adjustment of the Basket : {AvgAdjustetment}\n")
            f.write(f"Max Adjustment of the Basket : {MaxAdjustment}\n")
            f.write(f"Profit factor : {abs(round((df_summary[df_summary.returns>0]['returns'].sum())/(df_summary[df_summary.returns<0]['returns'].sum()),2))}\n")
            f.write(f"Sharpe ratio : {round(self.sharpe,2)}\n")
        
        fig1 = px.line(df_summary , y='returns_abs',x = df_summary['exittime'] , labels=['PnL'] , title= 'Equity Graph' ,template='plotly_dark' )
        fig1.show()
        return fig1
    def RandomTradesRemovalSimulation(self , frac):
       
        trades = self.trades.copy()
        #print(trades)
        #trades.reset_index(drop = True, inplace = True)
        #print(trades)
        randomDf = pd.DataFrame()
        for i in range(int(len(trades)/2)):
            df = trades.sample(frac = 1-frac )
            df.reset_index(drop = True, inplace = True)
            #print(df)
            td = self.analysis(df)
            #print(td)
            # if i == 0:
            #     randomDf = td
            # else :

            #     randomDf.append(td)

            # randomDf[f'R_{i}'] = td['returns']
            randomDf[i] = td['returns_abs'].to_list()

        fig1 = px.line(randomDf , y=list(randomDf.columns) , title='RandomTradesRemovalSimulation' ,template='plotly_dark' )
        #fig1.show()
        #return random
        # Df
        return fig1

    def RandomTradesShuffleSimultion(self):
        trades = self.trades.copy()
        all_td = []
        randomDf = pd.DataFrame()
        randomDf['original'] = self.analysis(trades)['returns_abs'].to_list()
        for i in range(int(len(trades)/2)):
            df = trades.sample(frac = 1)
            df.reset_index(drop = True, inplace = True)
            td = self.analysis(df)
            all_td.append(td)

            randomDf[f'R_{i}'] = td['returns_abs'].to_list()
            #randomDf[i] = td['returns_abs'].to_list()
        fig1 = px.line(randomDf , y=list(randomDf.columns) , title='RandomTradesShuffleSimulation' ,template='plotly_dark' )
        #fig1.show()
        return fig1
        #return randomDf

    def Hour_Day_Analysis(self):

        trades = self.trades.copy()
        trades['Hour'] = list(i.hour for i in trades['entry_time'])
        trades['Day'] = list(i.weekday() for i in trades['entry_time'])
        

        df_win = trades.query('returns > 0')
        HourWin = df_win.groupby('Hour').returns.agg({'count'})['count'].to_list()
        Hours = df_win.groupby('Hour').returns.agg({'count'}).index.to_list()
        DayWin = df_win.groupby('Day').returns.agg({'count'})['count'].to_list()
        Day = df_win.groupby('Day').returns.agg({'count'}).index.to_list()


        df_loose = trades.query('returns < 0')
        HourLoose = df_loose.groupby('Hour').returns.agg({'count'})['count'].to_list()
        DayLoose = df_loose.groupby('Day').returns.agg({'count'})['count'].to_list()

        HourDf = pd.DataFrame( data=list(zip(HourWin, HourLoose)), columns=['Win','Loss'])

        fig1 = px.bar(HourDf ,title='HourAnalysis' ,template='plotly_dark' )
        #fig1.show()

        DayLoose = df_loose.groupby('Day').returns.agg({'count'})['count'].to_list()

        DayDf = pd.DataFrame( data=list(zip(DayWin, DayLoose)), columns=['Win','Loss'])
        fig2 = px.bar(DayDf  , title='DayAnalysis' ,template='plotly_dark' )
        #fig2.show()
        return fig1,fig2

        #return HourDf

    def HoldingTimeScatterPlot(self ):
        import plotly.express as px
        trades = self.finalreport()
        hdf = trades[['Duration' , 'PnL','exit_type']].copy()
        
        hdf.reset_index(inplace=True,drop=True)
        hdf['Duration'] = list((i.total_seconds()/60) for i in hdf['Duration'])
        fig = px.scatter(hdf , y = 'PnL',x='Duration' , color='exit_type',width = 1000,height = 500)
        fig.update_traces(marker_size=8)
        #fig.show()

        return fig
    
    def Monthlyreturns(self):
        td = self.trades.copy()
        td.set_index('entry_time',inplace = True)
        mrdf = pd.DataFrame(td.returns.groupby(pd.Grouper(freq="M")).sum())

        df20 = mrdf[mrdf.index.year == 2020]
        df21 = mrdf[mrdf.index.year == 2021]
        df22 = mrdf[mrdf.index.year == 2022]
        
        
        fdf = pd.DataFrame()
        fdf['2020'] = list(df20.returns)
        fdf['2021'] = list(df21.returns)
        fdf['2022'] = list(df22.returns)

        fig1 = px.line(fdf, title='Monthly Returns' ,template='plotly_dark' )

        return fig1

# %%
filename = 'IronCondorBaseBackfilled'
res_pos1 = backtesting_final_per_pos('', Orders.sort_values(by='exittime').reset_index(drop=True),1,'No', filename,500000)
# Out:
# Number of trades:  1648
# Total No of Basket : 99
# Win percentage:  47.21
# Win Percentage of Bakset 39.39393939393939
# TP Exit  Percentage : 0.0
# BreakPoint Above Exit Percentage : 10.1010101010101
# BreakPoint Below Exit Percentage : 0.0
# Expiry Exit Percentage : 13.131313131313133
# Net PnL:  -30855.0
# No of winning trades:  778
# No of losing trades: 869
# Win % of Long trades:  12.62
# Win % of Short trades:  81.8
# Final Balance($):  469145.0
# Average_gain(pips):  66.76
# Average_loss(pips):  -58.0
# Average_gain($):  971.51
# Average_loss($):  -905.28
# Avergain Gain of a Basket : 1675.4807692307693
# Avergain Loss of a Basket : -1603.3125
# Avg Adjustment of the Basket : 14.646464646464647
# Max Adjustment of the Basket : 36
# Profit factor:  0.96
# Sharpe ratio:  -0.01

# %%
Orders
# Out:
#       entry                   type          entry_time            exittime  \
# 0        -1                     PE 2020-01-02 10:00:00 2020-01-02 12:14:00
# 1         1                     PE 2020-01-02 10:00:00 2020-01-02 12:14:00
# 2        -1                     PE 2020-01-02 12:14:00 2020-01-02 14:23:00
# 3         1                     PE 2020-01-02 12:14:00 2020-01-02 14:23:00
# 4        -1                     CE 2020-01-02 10:00:00 2020-01-03 09:30:00
# ...     ...                    ...                 ...                 ...
# 1371      1                     CE 2021-12-24 09:42:00 2021-12-27 09:15:00
# 1372     -1  BANKNIFTY34200DEC21CE 2021-12-27 09:15:00 2021-12-27 09:16:00
# 1373     -1  BANKNIFTY34800DEC21PE 2021-12-24 14:15:00 2021-12-27 09:16:00
# 1374      1  BANKNIFTY34900DEC21CE 2021-12-27 09:15:00 2021-12-27 09:16:00
# 1375      1  BANKNIFTY34000DEC21PE 2021-12-24 14:15:00 2021-12-27 09:16:00
#
#       entry_value  exitvalue exit_type     SP      dd  BasketID  \
# 0           94.90      71.85       Adj  32200   -6.35         1
# 1           30.50      23.45       Adj     UP   -7.25         1
# 2          126.75      92.90       Adj  32200  -13.25         1
# 3           42.20      31.25       Adj     UP  -10.95         1
# 4          108.55     119.00       Adj  32200 -108.45         1
# ...           ...        ...       ...    ...     ...       ...
# 1371        75.20      23.10       Adj     UP  -53.15       101
# 1372       627.15     490.35        SL  35200 -431.25       101
# 1373       249.15     607.55        SL  35200 -431.25       101
# 1374       344.00     158.55        SL  35200 -202.00       101
# 1375        84.70     236.60        SL  35200   78.75       101
#
#                  ContractName  LS
# 0     BANKNIFTY3190009JAN20PE   1
# 1     BANKNIFTY3150009JAN20PE   1
# 2     BANKNIFTY3210009JAN20PE   1
# 3     BANKNIFTY3170009JAN20PE   1
# 4     BANKNIFTY3250009JAN20CE   1
# ...                       ...  ..
# 1371    BANKNIFTY35900DEC21CE   1
# 1372    BANKNIFTY34200DEC21CE   1
# 1373    BANKNIFTY34800DEC21PE   1
# 1374    BANKNIFTY34900DEC21CE   1
# 1375    BANKNIFTY34000DEC21PE   1
#
# [1376 rows x 12 columns]

# %%
Orders
# Out:
#     entry                     type          entry_time            exittime  \
# 0      -1    BANKNIFTY35700JUL21CE 2021-07-22 10:00:00 2021-07-28 15:18:00
# 1      -1    BANKNIFTY34100JUL21PE 2021-07-22 10:00:00 2021-07-28 15:18:00
# 2       1    BANKNIFTY36400JUL21CE 2021-07-22 10:00:00 2021-07-28 15:18:00
# 3       1    BANKNIFTY33300JUL21PE 2021-07-22 10:00:00 2021-07-28 15:18:00
# 4      -1  BANKNIFTY3550005AUG21CE 2021-07-29 10:00:00 2021-08-03 09:35:00
# ..    ...                      ...                 ...                 ...
# 87      1  BANKNIFTY3450023DEC21PE 2021-12-15 10:00:00 2021-12-23 10:00:00
# 88     -1    BANKNIFTY36100DEC21CE 2021-12-22 10:00:00 2021-12-29 09:15:00
# 89     -1    BANKNIFTY33600DEC21PE 2021-12-22 10:00:00 2021-12-29 09:15:00
# 90      1    BANKNIFTY37000DEC21CE 2021-12-22 10:00:00 2021-12-29 09:15:00
# 91      1    BANKNIFTY31200DEC21PE 2021-12-22 10:00:00 2021-12-29 09:15:00
#
#     entry_value  exitvalue exit_type     SP      dd  BasketID  \
# 0        105.15       5.95    BAExit  34900 -195.10         1
# 1         93.00      30.15    BAExit  34900 -195.10         1
# 2         34.90       3.05    BAExit  34900  -34.80         1
# 3         34.20       4.30    BAExit  34900  -30.40         1
# 4         92.40      21.00    BAExit  34600  -45.95         2
# ..          ...        ...       ...    ...     ...       ...
# 87        34.15       7.70       Exp  36900  -27.70        22
# 88        90.25      18.70    BAExit  34900  -62.15        23
# 89       110.05      17.00    BAExit  34900  -62.15        23
# 90        31.65       4.50    BAExit  34900  -27.65        23
# 91        33.40       2.15    BAExit  34900  -32.10        23
#
#                ContractName  LS
# 0     BANKNIFTY35700JUL21CE   2
# 1     BANKNIFTY34100JUL21PE   2
# 2     BANKNIFTY36400JUL21CE   1
# 3     BANKNIFTY33300JUL21PE   1
# 4   BANKNIFTY3550005AUG21CE   2
# ..                      ...  ..
# 87  BANKNIFTY3450023DEC21PE   1
# 88    BANKNIFTY36100DEC21CE   2
# 89    BANKNIFTY33600DEC21PE   2
# 90    BANKNIFTY37000DEC21CE   1
# 91    BANKNIFTY31200DEC21PE   1
#
# [92 rows x 12 columns]
